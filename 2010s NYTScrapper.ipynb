# %%
import pandas as pd
import newspaper
from newspaper import Article

# %%
#Ladera Ranch
url1='http://www.nytimes.com/2013/02/20/us/shooting-spree-in-california.html'
Nyt_LR =pd.DataFrame()
a=Article(url1, language='en')
a.download()
a.parse()
Nyt_LR= Nyt_LR.append([[a.title, a.text]], ignore_index=True)
Nyt_LR.columns=['Title','Article']
Nyt_LR['Incident Name'] = 'Ladera Ranch'
Nyt_LR
# Out:
#                                      Title  \
# 0  At Least 4 Dead in California Shootings
#
#                                              Article Incident Name
# 0  As the man drove through the parking lot to es...  Ladera Ranch

# %%
#University of Alabama Huntsville 
url2='http://www.nytimes.com/2010/02/14/us/14alabama.html'
url3='http://www.nytimes.com/2010/02/15/us/15alabama.html'
url4='http://www.nytimes.com/2010/02/17/us/17alabama.html'
urls=[url2,url3,url4]
Nyt_UAH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_UAH= Nyt_UAH.append([[a.title, a.text]], ignore_index=True)
Nyt_UAH.columns=['Title','Article']
Nyt_UAH['Incident Name'] = 'University of Alabama Huntsville'
Nyt_UAH
# Out:
#                                                Title  \
# 0  A Previous Shooting Death at the Hands of Alab...
# 1  A Previous Shooting Death at the Hands of Alab...
# 2        New Look at Killing of Amy Bishop’s Brother
#
#                                              Article  \
# 0  HUNTSVILLE, Ala.  The neurobiologist accused ...
# 1  HUNTSVILLE, Ala.  On Friday, this city of roc...
# 2  As the district attorney’s office noted in its...
#
#                       Incident Name
# 0  University of Alabama Huntsville
# 1  University of Alabama Huntsville
# 2  University of Alabama Huntsville

# %%
# #Hartford Beer Company
url5='http://www.nytimes.com/2010/08/04/nyregion/04shooting.html'
url6='http://www.nytimes.com/2010/08/04/nyregion/04gunman.html'
url7='http://www.nytimes.com/2010/08/05/nyregion/05shooting.html'
url8='http://www.nytimes.com/2010/08/05/nyregion/05vics.html'
urls=[url5, url6,url7,url8]
Nyt_HBC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HBC= Nyt_HBC.append([[a.title, a.text]], ignore_index=True)
Nyt_HBC.columns=['Title','Article']
Nyt_HBC['Incident Name'] = 'Hartford Beer Company'
Nyt_HBC
# Out:
#                                                Title  \
# 0              9 Reported Dead in Workplace Shooting
# 1             Gunman in Mass Shooting Had Bumpy Life
# 2  Gunman Came Prepared to Connecticut Workplace ...
# 3  Remembering the Lives Lost in a Warehouse Rampage
#
#                                              Article          Incident Name
# 0  The rampage, the latest in a series of America...  Hartford Beer Company
# 1  He was bankrupt by age 24, when, court filings...  Hartford Beer Company
# 2  When Omar S. Thornton came to the Hartford Dis...  Hartford Beer Company
# 3  Mr. Pepin, who was 60, had driven beer trucks ...  Hartford Beer Company

# %%
#Gabby Giffords Shooting URLS
url9='http://www.nytimes.com/2011/01/09/us/politics/09giffords.html'
url10='http://www.nytimes.com/2011/01/09/us/politics/09profileweb.html'
url11='http://www.nytimes.com/2011/01/09/us/politics/09capital.html'
url12='http://www.nytimes.com/2011/01/09/us/09judge.html'
url13='http://www.nytimes.com/2011/01/09/us/politics/09shooter.html'
url14='http://www.nytimes.com/2011/01/09/us/politics/09bai.html'
url15='http://www.nytimes.com/2011/01/10/us/10giffords.html'
url16='https://thecaucus.blogs.nytimes.com/2011/01/09/live-blog-latest-developments-on-arizona-shooting/?_r=0'
url17='http://www.nytimes.com/2011/01/10/us/politics/10capital.html'
url18='http://www.nytimes.com/2011/01/10/us/10religious.html'
url19='http://www.nytimes.com/2011/01/10/us/10arizona.html'
url20='http://www.nytimes.com/2011/01/10/opinion/10mon1.html'
url21='http://www.nytimes.com/2011/01/10/us/10iht-letter10.html'
url22='https://learning.blogs.nytimes.com/2011/01/09/will-the-arizona-shootings-change-our-political-culture/'
url23='https://learning.blogs.nytimes.com/2011/01/09/ways-to-teach-about-the-arizona-shootings/'
url24='http://www.nytimes.com/2011/01/10/us/politics/10security.html'
url25='http://www.nytimes.com/2011/01/10/sports/10shoot.html'
url26='http://www.nytimes.com/2011/01/10/us/10judge.html'
url27='http://www.nytimes.com/2011/01/10/us/10reconstruct.html'
url28='http://www.nytimes.com/2011/01/10/us/politics/10politics.html'
url29='http://www.nytimes.com/2011/01/10/us/10staff.html'
url30='http://www.nytimes.com/2011/01/10/health/10medical.html'
url31='http://www.nytimes.com/2011/01/10/opinion/10collins.html'
url32='http://www.nytimes.com/2011/01/10/opinion/10krugman.html'
url33='http://www.nytimes.com/2011/01/10/opinion/l10arizona.html'
url34='https://query.nytimes.com/gst/fullpage.html?res=9404E2DD123DF933A25752C0A9679D8B63'
url35='https://thecaucus.blogs.nytimes.com/2011/01/10/the-early-word-processing-the-shooting/'
url36='http://www.nytimes.com/2011/01/11/us/11giffords.html'
url37='http://www.nytimes.com/2011/01/11/us/11radio.html'
url38='https://thecaucus.blogs.nytimes.com/2011/01/10/with-e-mail-palin-and-beck-discuss-the-arizona-shootings/'
url39='https://thecaucus.blogs.nytimes.com/2011/01/10/obama-avoiding-fingerpointing/'
url40='http://www.nytimes.com/2011/01/11/us/11guns.html'
url41='http://www.nytimes.com/2011/01/11/opinion/l11arizona.html'
url42='http://www.nytimes.com/2011/01/11/opinion/11sheehan.html'
url43='https://thecaucus.blogs.nytimes.com/2011/01/10/obama-to-go-to-tucson/'
url44='http://www.nytimes.com/2011/01/11/us/politics/11palin.html'
url45='http://www.nytimes.com/2011/01/11/us/11district.html'
url46='http://www.nytimes.com/2011/01/11/us/11security.html'
url47='http://www.nytimes.com/2011/01/11/us/11mental.html'
url48='http://www.nytimes.com/2011/01/11/opinion/11tue1.html'
url49='https://query.nytimes.com/gst/fullpage.html?res=9405E2DC1E3DF932A25752C0A9679D8B63'
url50='https://thecaucus.blogs.nytimes.com/2011/01/11/house-resolution-to-reaffirm-democratic-principles/'
url51='http://www.nytimes.com/2011/01/12/us/politics/12boehner.html'
url52='http://www.nytimes.com/2011/01/12/opinion/l12arizona.html'
url53='http://www.nytimes.com/2011/01/12/us/12legal.html'
url54='http://www.nytimes.com/2011/01/12/us/12brewer.html'
url55='http://www.nytimes.com/2011/01/12/opinion/12wed2.html'
url56='https://query.nytimes.com/gst/fullpage.html?res=9E0CE4DD143CF931A25752C0A9679D8B63'
url57='http://www.nytimes.com/2011/01/12/us/12security.html'
url58='https://thecaucus.blogs.nytimes.com/2011/01/12/the-early-word-assessing-and-regrouping/'
url59='https://thecaucus.blogs.nytimes.com/2011/01/12/after-arizona-how-to-return-to-politics-and-when/'
url60='http://www.nytimes.com/2011/01/13/opinion/13iht-edletters13.html'
url61='https://thecaucus.blogs.nytimes.com/2011/01/12/palin-calls-criticism-blood-libel/'
url62='https://thecaucus.blogs.nytimes.com/2011/01/12/boehner-shows-emotion-in-house-remarks-on-tucson-violence/'
url63='http://www.nytimes.com/2011/01/13/us/politics/13giffords.html'
url64='http://www.nytimes.com/2011/01/13/us/13guns.html'
url65='https://thecaucus.blogs.nytimes.com/2011/01/12/obama-to-visit-giffords-in-hospital/'
url66='https://thecaucus.blogs.nytimes.com/2011/01/12/obama-urges-civility-in-public-discourse/'
url67='https://thecaucus.blogs.nytimes.com/2011/01/12/amid-sadness-applause-and-cheers/'
url68='http://www.nytimes.com/2011/01/13/opinion/l13arizona.html'
url69='http://www.nytimes.com/2011/01/13/us/13rhee.html'
url70='http://www.nytimes.com/2011/01/13/us/13obama.html'
url71='http://www.nytimes.com/2011/01/13/us/13assess.html'
url72='https://thecaucus.blogs.nytimes.com/2011/01/12/pelosi-on-hand-when-giffords-opens-eyes/'
url73='http://www.nytimes.com/2011/01/13/opinion/13kristof.html'
url74='https://thecaucus.blogs.nytimes.com/2011/01/13/rep-gabrielle-giffordss-friends-narrate-the-moment-she-opened-her-eye/'
url75='https://parenting.blogs.nytimes.com/2011/01/13/what-to-tell-children-about-tucson/'
url76='http://www.nytimes.com/2011/01/14/us/14college.html'
url77='http://www.nytimes.com/2011/01/14/us/14funeral.html'
url78='http://www.nytimes.com/2011/01/14/us/14judge.html'
url79='http://www.nytimes.com/2011/01/14/opinion/l14arizona.html'
url80='http://www.nytimes.com/2011/01/14/us/14guns.html'
url81='http://www.nytimes.com/2011/01/14/us/14legal.html'
url82='http://www.nytimes.com/2011/01/14/us/14obama.html'
url83='http://www.nytimes.com/2011/01/14/us/14women.html'
url84='http://www.nytimes.com/2011/01/14/health/policy/14cong.html'
url85='https://learning.blogs.nytimes.com/2011/01/14/our-hearts-are-full-of-hope/'
url86='https://schott.blogs.nytimes.com/2011/01/14/lock-and-load-politics-blood-libel/'
url87='https://opinionator.blogs.nytimes.com/2011/01/14/theres-a-new-sheriff-in-politics/'
url88='http://www.nytimes.com/2011/01/15/business/15glock.html'
url89='http://www.nytimes.com/2011/01/15/us/15medical.html'
url90='http://www.nytimes.com/2011/01/15/us/15profile.html'
url91='http://www.nytimes.com/2011/01/15/us/15meet.html'

# %%
urls=[url9,url10,url11,url12,url13,url14,url15,url16,url17,url18,url19,url20,url21,url22,url23,url24,url25,url26, 
      url27,url28,url29, url30,url31,url32,url33, url34,url35,url36,url37,url38,url39,url40, url41,url42,url43,
      url44,url45, url46,url47, url48, url49,url50,url51,url52, url53,url54,url55,url56,url57,url58,url59,url60,
      url61,url62,url63,url64,url65,url66,url67,url68,url69,url70,url71,url72,url73,url74,url75,url76, url77
      , url78,url79,url80, url81,url82,url83,url84,url85,url86,url87,url88,url89,url90,url91]
Nyt_AZGG =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AZGG= Nyt_AZGG.append([[a.title, a.text]], ignore_index=True)
Nyt_AZGG.columns=['Title','Article']
Nyt_AZGG['Incident Name'] = 'Tucscon, Arizona - Gabby Giffords'
Nyt_AZGG
# Out:
#                                                 Title  \
# 0   Representative Gabrielle Giffords and 18 Shot ...
# 1   Giffords Noted as a Friend to Colleagues, Bike...
# 2   Bloodshed in Arizona Shooting Puts New Focus o...
# 3          Judge John M. Roll Had Faced Death Threats
# 4   Arizona Suspect’s Recent Acts Offer Hints of A...
# 5   The End of an Era of Intolerance, or Just the ...
# 6   Federal Charges in Giffords Shooting Cite Assa...
# 7   Live Blog: Latest Developments on Arizona Shoo...
# 8   After Attack, Focus in Washington on Civility ...
# 9       At Giffords’s Synagogue, Prayers for Recovery
# 10  Arizona Shooting Casts a Harsh Light on the State
# 11                 Bloodshed and Invective in Arizona
# 12                        America and Guns, Once More
# 13  Will the Arizona Shootings Change Our Politica...
# 14          Ways to Teach About the Arizona Shootings
# 15  Security for Congress, After Arizona Shooting,...
# ...

# %%
#Youngstown State University
url92='http://www.nytimes.com/2011/02/07/us/07frat.html'
Nyt_YSU =pd.DataFrame() 
a=Article(url92, language='en')
a.download()
a.parse()
Nyt_YSU= Nyt_YSU.append([[a.title, a.text]], ignore_index=True)
Nyt_YSU.columns=['Title','Article']
Nyt_YSU['Incident Name'] = 'Youngstown State University'
Nyt_YSU
# Out:
#                                                Title  \
# 0  Shootings at Youngstown State Kill One, Injure 11
#
#                                              Article  \
# 0  YOUNGSTOWN, Ohio (AP) — Two men have been arre...
#
#                  Incident Name
# 0  Youngstown State University

# %%
#Southern Union State Community College
url93='http://www.nytimes.com/2011/04/07/us/07alabama.html'
Nyt_SUSCC =pd.DataFrame() 
a=Article(url93, language='en')
a.download()
a.parse()
Nyt_SUSCC= Nyt_SUSCC.append([[a.title, a.text]], ignore_index=True)
Nyt_SUSCC.columns=['Title','Article']
Nyt_SUSCC['Incident Name'] = 'Southern Union State Community College'
Nyt_SUSCC
# Out:
#                                                Title  \
# 0  Shooting at College in Alabama Kills a Woman a...
#
#                                              Article  \
# 0  ATLANTA — A woman was killed and three other p...
#
#                             Incident Name
# 0  Southern Union State Community College

# %%
#Grand Rapids
url94='http://www.nytimes.com/2011/07/08/us/08gunman.html'
Nyt_GR =pd.DataFrame() 
a=Article(url94, language='en')
a.download()
a.parse()
Nyt_GR= Nyt_GR.append([[a.title, a.text]], ignore_index=True)
Nyt_GR.columns=['Title','Article']
Nyt_GR['Incident Name'] = 'Grand Rapids, MI'
Nyt_GR
# Out:
#                                                Title  \
# 0  Michigan Man Suspected in 7 Deaths Kills Himse...
#
#                                              Article     Incident Name
# 0  DETROIT — A hostage standoff in Grand Rapids, ...  Grand Rapids, MI

# %%
#Nevada IHOP
url95='http://www.nytimes.com/2011/09/08/us/08shooting.html'
url96='http://www.nytimes.com/2011/09/07/us/07shooting.html'
urls=[url95,url96]
Nyt_NIHOP =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NIHOP= Nyt_NIHOP.append([[a.title, a.text]], ignore_index=True)
Nyt_NIHOP.columns=['Title','Article']
Nyt_NIHOP['Incident Name'] = 'Nevada IHOP'
Nyt_NIHOP
# Out:
#                                             Title  \
# 0                 Nevada Shootings Seen as Random
# 1  5 Die, Including Gunman, in Nevada IHOP Attack
#
#                                              Article Incident Name
# 0  The question of who Mr. Sencion was and what e...   Nevada IHOP
# 1  Photo\n\nLOS ANGELES — A man armed with an AK-...   Nevada IHOP

# %%
#Salon Meritage
url97='http://www.nytimes.com/2011/10/13/us/8-killed-in-shooting-at-hair-salon-in-seal-beach-california.html'
url98='http://www.nytimes.com/2011/10/14/us/suspect-in-california-salon-killings-was-in-bitter-custody-battle-victims-kin-say.html'
urls=[url97,url98]
Nyt_SS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SS= Nyt_SS.append([[a.title, a.text]], ignore_index=True)
Nyt_SS.columns=['Title','Article']
Nyt_SS['Incident Name'] = 'Salon Meritage'
Nyt_SS
# Out:
#                                                Title  \
# 0  8 Killed in Shooting at Hair Salon in Seal Bea...
# 1  Suspect in California Salon Killings Was in Bi...
#
#                                              Article   Incident Name
# 0  SEAL BEACH, Calif. — A gunman burst into a bea...  Salon Meritage
# 1  LOS ANGELES — The gunman who killed eight peop...  Salon Meritage

# %%
#Su Jung Health Sauna
url99='http://www.nytimes.com/2012/02/23/us/georgia-five-dead-in-shooting-at-spa.html'
Nyt_SJHS =pd.DataFrame() 
a=Article(url99, language='en')
a.download()
a.parse()
Nyt_SJHS= Nyt_SJHS.append([[a.title, a.text]], ignore_index=True)
Nyt_SJHS.columns=['Title','Article']
Nyt_SJHS['Incident Name'] = 'Su Jung Health Sauna'
Nyt_SJHS
# Out:
#                                    Title  \
# 0  Georgia: Five Dead in Shooting at Spa
#
#                                              Article         Incident Name
# 0  The police are investigating a shooting at a K...  Su Jung Health Sauna

# %%
#Chardon High School
url100='https://thelede.blogs.nytimes.com/2012/02/27/ohio-high-school-shooting-leaves-1-student-dead-and-4-wounded/'
url101='https://parenting.blogs.nytimes.com/2012/02/27/school-shooting-is-another-opening-to-talk-about-guns/'
url102='http://www.nytimes.com/2012/02/28/us/fatal-school-shooting-in-chardon-ohio-suspect-is-arrested.html'
url103='https://thelede.blogs.nytimes.com/2012/02/28/few-clues-on-motive-in-school-shooting/'
url104='http://www.nytimes.com/2012/02/29/us/ohio-school-shooting-suspect-confesses-prosecutor-says.html'
url105='http://www.nytimes.com/2012/03/01/us/school-shooting-suspect-was-accused-of-earlier-assault.html'
url106='https://parenting.blogs.nytimes.com/2012/03/01/quandary-considered-talking-with-teenagers-and-their-parents-about-guns/'
url107='http://www.nytimes.com/2012/03/02/us/teenager-charged-as-juvenile-in-ohio-school-shooting.html'
url108='http://www.nytimes.com/2012/03/02/us/origin-of-gun-in-ohio-school-shooting-described.html'
urls=[url100,url101,url102,url103,url104,url105,url106,url107,url108]
Nyt_CHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CHS= Nyt_CHS.append([[a.title, a.text]], ignore_index=True)
Nyt_CHS.columns=['Title','Article']
Nyt_CHS['Incident Name'] = 'Chardon High School'
Nyt_CHS
# Out:
#                                                Title  \
# 0  Ohio High School Shooting Leaves 1 Student Dea...
# 1  Shootings in Ohio School Provide Another Openi...
# 2  Shooting at Chardon High School Kills One and ...
# 3             Few Clues on Motive in School Shooting
# 4  Ohio School Shooting Suspect Confesses, Prosec...
# 5  School Shooting Suspect Was Accused of Earlier...
# 6  Quandary Considered: Talking With Teenagers (a...
# 7    Teenager Is Charged in Killing of 3 at a School
# 8    Origin of Gun in Ohio School Shooting Described
#
#                                              Article        Incident Name
# 0  A 16-year-old student died of gunshot wounds a...  Chardon High School
# 1  A gunman, believed to be a student, opened fir...  Chardon High School
# 2  A teenager opened fire on a group of students ...  Chardon High School
# 3  From Facebook\n\nIt was just after 7:30 a.m. o...  Chardon High School
# ...

# %%
#Oikos Shooting
url109='http://www.nytimes.com/2012/04/04/us/oikos-university-gunman-lined-up-victims.html'
url110='http://www.nytimes.com/2012/04/03/us/fatal-shootings-at-oikos-university-in-oakland-calif.html'
url111='https://thelede.blogs.nytimes.com/2012/04/02/suspect-in-oakland-school-shooting-is-former-nursing-student-at-oikos-university/'
urls=[url109,url110,url111]
Nyt_OU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_OU= Nyt_OU.append([[a.title, a.text]], ignore_index=True)
Nyt_OU.columns=['Title','Article']
Nyt_OU['Incident Name'] = 'Chardon High School'
Nyt_OU
# Out:
#                                                Title  \
# 0  Troubled History Emerges for Suspect in Oaklan...
# 1  Fatal Shootings at Oikos University in Oakland...
# 2  Suspect in Oakland School Shooting Is Former N...
#
#                                              Article        Incident Name
# 0  A block from the school, at the office of The ...  Chardon High School
# 1  Mr. Goh had been a nursing student at the coll...  Chardon High School
# 2  Possible Suspect in custody.No imminent public...  Chardon High School

# %%
#North Tulsa
url112='http://www.nytimes.com/2012/04/08/us/police-seek-suspect-in-tulsa-shootings.html'
url113='http://www.nytimes.com/2012/04/09/us/tulsa-police-arrest-2-men-in-shootings.html'
url114='http://www.nytimes.com/2012/04/10/us/tulsa-murder-suspects-have-bail-set-at-9-1-million.html'
url115='http://www.nytimes.com/2012/04/12/us/tulsa-shootings-came-in-struggling-neighborhoods.html'
url116='https://query.nytimes.com/gst/fullpage.html?res=9503EFDD1231F931A25757C0A9649D8B63'
url117='http://www.nytimes.com/2012/04/14/us/3-tulsa-strangers-familiar-to-struggle-met-same-fate.html'
urls=[url112,url113,url114,url115,url116,url117]
Nyt_NT =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NT= Nyt_NT.append([[a.title, a.text]], ignore_index=True)
Nyt_NT.columns=['Title','Article']
Nyt_NT['Incident Name'] = 'North Tulsa, Oklahoma'
Nyt_NT
# Out:
#                                                Title  \
# 0             Police Seek Suspect in Tulsa Shootings
# 1             Tulsa Police Arrest 2 Men in Shootings
# 2          Two Suspects Confessed in Tulsa Shootings
# 3   Tulsa Shootings Came in Struggling Neighborhoods
# 4      Death Comes to the Vacant Lots of North Tulsa
# 5  One Fate in Tulsa for 3 Strangers Familiar Wit...
#
#                                              Article          Incident Name
# 0  The authorities in Tulsa, Okla., were scrambli...  North Tulsa, Oklahoma
# 1  “You can look at the facts of the case and cer...  North Tulsa, Oklahoma
# 2  At a brief court hearing Monday morning, Speci...  North Tulsa, Oklahoma
# 3  “I’m not a bit surprised at any of the violenc...  North Tulsa, Oklahoma
# 4  TULSA, Okla. -- In the minutes after a shootin...  North Tulsa, Oklahoma
# 5  The shootings unfolded the day after Mr. Engla...  North Tulsa, Oklahoma

# %%
#Seattle Cafe
url118='http://www.nytimes.com/2012/05/31/us/washington-at-least-3-die-in-seattle-cafe-shooting.html'
url119='http://www.nytimes.com/2012/06/01/us/washington-man-in-cafe-called-a-hero-during-shooting.html'
urls=[url118,url119]
Nyt_SC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SC= Nyt_SC.append([[a.title, a.text]], ignore_index=True)
Nyt_SC.columns=['Title','Article']
Nyt_SC['Incident Name'] = 'Cafe in Seattle'
Nyt_SC
# Out:
#                                                Title  \
# 0  Washington: At Least 3 Die in Seattle Cafe Sho...
# 1  Washington: Man In Cafe Called a Hero During S...
#
#                                              Article    Incident Name
# 0  A gunman killed five people in Seattle on Wedn...  Cafe in Seattle
# 1  Someone inside the Seattle cafe where a gunman...  Cafe in Seattle

# %%
#Auburn Univeristy
url120='http://www.nytimes.com/2012/06/11/us/report-of-a-multiple-shooting-near-auburn-university.html'
url121='http://www.nytimes.com/2012/06/12/us/alabama-two-arrested-in-auburn-triple-killing.html'
url122='http://www.nytimes.com/2012/06/13/us/alabama-slaying-suspect-got-away-police-say.html'
urls=[url120,url121,url122]
Nyt_AU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AU= Nyt_AU.append([[a.title, a.text]], ignore_index=True)
Nyt_AU.columns=['Title','Article']
Nyt_AU['Incident Name'] = 'University Heights Apartments in Auburn'
Nyt_AU
# Out:
#                                                Title  \
# 0  Auburn Shooting Kills Three, Including Two Ex-...
# 1       Alabama: House Swarmed in Search for Suspect
# 2            Alabama: Suspect In Killings Surrenders
#
#                                              Article  \
# 0  Chief Tommy Dawson of the City of Auburn Polic...
# 1  Law officers on Monday surrounded and shot tea...
# 2  A defense lawyer said Tuesday night that a man...
#
#                              Incident Name
# 0  University Heights Apartments in Auburn
# 1  University Heights Apartments in Auburn
# 2  University Heights Apartments in Auburn

# %%
#Aurora URLS
url124='http://www.nytimes.com/2012/07/21/us/shooting-at-colorado-theater-showing-batman-movie.html'
url125='https://thelede.blogs.nytimes.com/2012/07/20/live-updates-on-movie-theater-shooting-in-colorado/'
url126='https://thecaucus.blogs.nytimes.com/2012/07/20/obama-cuts-short-florida-campaign-trip/'
url127='https://mediadecoder.blogs.nytimes.com/2012/07/20/a-statement-from-warner-bros-on-colorado-shooting/'
url128='https://learning.blogs.nytimes.com/2012/07/20/addressing-the-colorado-shootings-with-students/'
url129='http://www.nytimes.com/2012/07/21/opinion/the-massacre-in-a-movie-theater.html'
url130='https://cityroom.blogs.nytimes.com/2012/07/20/police-dept-is-sending-officers-to-dark-knight-theaters/'
url131='https://takingnote.blogs.nytimes.com/2012/07/20/the-shooting-in-aurora/'
url132='https://thecaucus.blogs.nytimes.com/2012/07/20/after-killings-at-theater-campaigns-suspend-their-ads-in-colorado/'
url133='https://mediadecoder.blogs.nytimes.com/2012/07/20/warner-brothers-assesses-potential-responses-on-dark-knight/'
url134='https://thecaucus.blogs.nytimes.com/2012/07/20/romney-reacts-to-colorado-shooting/'
url135='https://mediadecoder.blogs.nytimes.com/2012/07/20/a-misstep-on-gma-as-networks-rush-to-cover-shooting/'
url136='https://parenting.blogs.nytimes.com/2012/07/20/aurora-and-a-mothers-memories-of-columbine/'
url137='http://www.nytimes.com/2012/07/21/opinion/weve-seen-this-movie-before.html'
url138='https://bits.blogs.nytimes.com/2012/07/20/online-colorado-suspect-seems-a-phantom/'
url139='http://www.nytimes.com/2012/07/21/sports/olympics/swimming-star-missy-franklin-shaken-by-colorado-shooting.html'
url140='http://www.nytimes.com/2012/07/21/opinion/the-shootings-in-colorado.html'
url141='http://www.nytimes.com/2012/07/21/opinion/guns-and-the-slog.html'
url142='http://www.nytimes.com/2012/07/21/us/colorado-gun-laws-remain-lax-despite-changes-after-columbine.html'
url143='http://www.nytimes.com/2012/07/21/opinion/blow-mourning-and-mulling.html'
url144='http://www.nytimes.com/2012/07/22/us/colorado-movie-theater-shooting-james-holmes.html'
url145='https://query.nytimes.com/gst/fullpage.html?res=9505EFDE123EF932A15754C0A9649D8B63'
url146='http://www.nytimes.com/2012/07/22/us/colorado-movie-theater-shooting-james-holmes.html'
url147='http://www.nytimes.com/2012/07/22/opinion/sunday/douthat-the-way-we-fear-now.html'
url148='https://thelede.blogs.nytimes.com/2012/07/21/the-risky-business-of-the-bomb-squad/'
url149='http://www.nytimes.com/2012/07/22/opinion/sunday/the-unknown-why-in-the-aurora-killings.html'
url150='http://www.nytimes.com/2012/07/22/us/in-darkened-movie-theater-heroes-in-life-and-in-death.html'
url151='http://www.nytimes.com/2012/07/22/us/pain-and-puzzles-in-wake-of-deadly-colorado-attack.html'
url152='http://www.nytimes.com/2012/07/22/us/aurora-an-all-america-city-left-to-search-for-answers.html'
url153='http://www.nytimes.com/2012/07/23/movies/dark-knight-leads-at-box-office-in-the-shadow-of-massacre.html'
url154='http://www.nytimes.com/2012/07/23/us/colorado-movie-theater-shooting-james-holmes.html'
url155='https://thelede.blogs.nytimes.com/2012/07/22/remembering-the-victims-of-colorado-shooting/'
url156='https://thelede.blogs.nytimes.com/2012/07/22/aurora-residents-return-home-after-evacuation/'
url157='http://www.nytimes.com/2012/07/23/us/online-ammunition-sales-highlighted-by-aurora-shootings.html'
url158='https://mediadecoder.blogs.nytimes.com/2012/07/23/in-aurora-a-sadly-familiar-template-kicks-in-for-the-news-media/'
url159='http://www.nytimes.com/2012/07/24/us/suspect-in-colorado-shooting-in-court.html'
url160='https://bits.blogs.nytimes.com/2012/07/23/reddit-aurora-shooter-aff/'
url161='https://takingnote.blogs.nytimes.com/2012/07/23/a-gun-for-every-person/'
url162='https://www.nytimes.com/roomfordebate/2012/07/23/where-is-the-leadership-on-gun-control/'
url163='http://www.nytimes.com/2012/07/24/us/politics/president-criticizes-romney-over-foreign-policy.html'
url164='http://www.nytimes.com/2012/07/24/opinion/brooks-more-treatment-programs.html'
url165='http://www.nytimes.com/2012/07/24/opinion/after-aurora-grief-and-questions.html'
url166='http://www.nytimes.com/2012/07/24/opinion/6000-bullets-in-colorado.html'
url167='http://www.nytimes.com/2012/07/24/us/politics/obama-and-romney-dont-heed-new-call-for-gun-laws.html'
url168='http://www.nytimes.com/2012/07/24/us/aurora-gunmans-lethal-arsenal.html'
url169='https://cityroom.blogs.nytimes.com/2012/07/24/for-mayor-the-time-to-discuss-gun-control-is-now/'
url170='http://www.nytimes.com/2012/07/25/us/other-states-and-other-times-would-have-posed-obstacles-for-gunman.html'
url171='https://thelede.blogs.nytimes.com/2012/07/24/christian-bale-visits-shooting-victims-in-colorado/'
url172='http://www.nytimes.com/2012/07/25/opinion/a-way-out-of-the-gun-madness.html'
url173='http://www.nytimes.com/2012/07/25/world/americas/in-mexico-a-restrictive-approach-to-gun-laws.html'
url174='https://campaignstops.blogs.nytimes.com/2012/07/24/the-gun-rights-tilt/'
url175='https://opinionator.blogs.nytimes.com/2012/07/25/what-we-talk-about-when-we-talk-about-guns/'
url176='https://artsbeat.blogs.nytimes.com/2012/07/25/dc-postpones-release-of-batman-comic/'
url177='https://thecaucus.blogs.nytimes.com/2012/07/25/romney-says-country-doesnt-need-new-gun-laws/'
url178='http://www.nytimes.com/2012/07/26/opinion/an-arms-race-we-cant-win.html'
url179='http://www.nytimes.com/2012/07/26/opinion/kristof-safe-from-fire-but-not-gone.html'
url180='http://www.nytimes.com/2012/07/26/opinion/armed-but-not-so-safe.html'
url181='https://artsbeat.blogs.nytimes.com/2012/07/26/discoverys-american-guns-after-aurora/'
url182='https://douthat.blogs.nytimes.com/2012/07/26/on-gun-control-and-prohibition/'
url183='https://thecaucus.blogs.nytimes.com/2012/07/26/gun-control-group-calls-on-presidential-candidates-to-outline-plans/'
url184='https://mediadecoder.blogs.nytimes.com/2012/07/26/stern-talk-with-reporter-over-mistaken-tea-party-link-to-shooting-abc-says/'
url185='http://www.nytimes.com/2012/07/27/opinion/candidates-cower-on-gun-control.html'
url186='http://www.nytimes.com/2012/07/27/opinion/dont-blame-the-movie-for-the-aurora-shootings.html'
url187='http://www.nytimes.com/2012/07/27/us/colorado-judge-bans-release-of-school-records-in-shooting.html'
url188='https://query.nytimes.com/gst/fullpage.html?res=9801E6DB1231F934A15754C0A9649D8B63'
url189='https://query.nytimes.com/gst/fullpage.html?res=9C0CE2DF1031F934A15754C0A9649D8B63'
url190='https://query.nytimes.com/gst/fullpage.html?res=9E00E4DB1331F934A15754C0A9649D8B63'

# %%
#Movie Theater in Aurora 
urls=[url124,url125,url126,url127,url128,url129,url130,url131,url132,url132,url133,url134,url135,url136,url137,url138,
      url139,url140,url141,url142,url143,url144,url145,url146,url147,url148,url149,url150,url151,url152,url153,url154,
      url155,url156,url57,url158,url159,url160,url161,url162,url163,url163,url164,url165,url166,url167,url168,url169,
      url170,url171,url172,url173,url174,url175,url176,url177,url178,url179,url180,url181,url182,url183,url184,url185,url186,
      url187,url188,url189,url190]
Nyt_Aurora =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Aurora= Nyt_Aurora.append([[a.title, a.text]], ignore_index=True)
Nyt_Aurora.columns=['Title','Article']
Nyt_Aurora['Incident Name'] = 'Movie Theater in Aurora'
Nyt_Aurora
# Out:
#                                                 Title  \
# 0   12 Are Killed at Showing of Batman Movie in Co...
# 1   Live Updates on Movie Theater Shooting in Colo...
# 2              Obama Cuts Short Florida Campaign Trip
# 3     Warner Bros. 'Saddened' After Colorado Shooting
# 4     Addressing the Colorado Shootings With Students
# 5                     The Massacre in a Movie Theater
# 6   Police Dept. Is Sending Officers to 'Dark Knig...
# 7   Aurora Dark Knight Shooting--Will There Be a G...
# 8   After Killings at Theater, Campaigns Suspend T...
# 9   After Killings at Theater, Campaigns Suspend T...
# 10  Hollywood Struggles for Proper Response to Sho...
# 11            Romney Reacts to Aurora, Colo. Shooting
# 12  A Misstep on 'GMA' as Networks Rush to Cover S...
# 13        Aurora and a Mother's Memories of Columbine
# 14            Aurora Shooting: We’ve Seen This Before
# 15           Online, Colorado Suspect Seems a Phantom
# ...

# %%
#Sikh Temple URLS
url191='http://www.nytimes.com/2012/08/06/us/shooting-reported-at-temple-in-wisconsin.html'
url192='https://thecaucus.blogs.nytimes.com/2012/08/05/candidates-react-to-shooting-at-sikh-temple/'
url193='http://www.nytimes.com/2012/06/13/us/alabama-slaying-suspect-got-away-police-say.html'
url194='https://thelede.blogs.nytimes.com/2012/08/05/reports-from-the-scene-of-shooting-at-sikh-temple/'
url195='https://india.blogs.nytimes.com/2012/08/06/gunman-kills-6-in-wisconsin-before-dying-in-shootout/'
url196='https://india.blogs.nytimes.com/2012/08/06/for-many-sikhs-wisconsin-attack-has-troubling-echoes/'
url197='http://www.nytimes.com/2012/08/07/us/army-veteran-identified-as-suspect-in-wisconsin-shooting.html'
url198='https://thelede.blogs.nytimes.com/2012/08/07/myspace-page-gunman-belonged-to-white-supremacist-band/'
url199='http://www.nytimes.com/2012/08/07/us/army-veteran-identified-as-suspect-in-wisconsin-shooting.html?hp&pagewanted=all'
url200='http://www.nytimes.com/2012/08/07/opinion/the-shooting-at-the-sikh-temple.html'
url201='http://www.nytimes.com/2012/08/07/us/sikhs-mourn-victims-and-lament-post-9-11-targeting.html'
url202='https://india.blogs.nytimes.com/2012/08/07/wisconsin-killer-was-fueled-by-hate-driven-music/'
url203='https://india.blogs.nytimes.com/2012/08/07/being-sikh-in-america/'
url204='https://takingnote.blogs.nytimes.com/2012/08/07/gun-control-of-paranoia-and-bromides/'
url205='http://www.nytimes.com/2012/08/08/opinion/a-sikh-temples-proud-history.html'
url206='http://www.nytimes.com/2012/08/08/us/hatecore-music-is-called-white-supremacist-recruiting-tool.html'
url207='https://thecaucus.blogs.nytimes.com/2012/08/07/in-slip-romney-refers-to-sheik-temple-tragedy/'
url208='http://www.nytimes.com/2012/08/08/us/politics/polls-find-opposition-to-stricter-gun-laws.html'
url209='https://india.blogs.nytimes.com/2012/08/08/wisconsin-shooting-exposes-the-angry-music-of-hatecore/'
url210='https://india.blogs.nytimes.com/2012/08/08/mourning-victims-sikhs-lament-being-mistaken-for-radicals-or-militants/'
url211='https://india.blogs.nytimes.com/2012/08/08/recollections-of-the-first-gurdwara-in-the-u-s/'
url212='http://www.nytimes.com/2012/08/09/opinion/the-sikh-temple-killers-music-of-hate.html'
url213='http://www.nytimes.com/2012/08/09/us/wisconsin-gunman-killed-himself-authorities-say.html'
url214='http://www.nytimes.com/2012/08/09/world/asia/victim-in-sikh-temple-shooting-endured-separation-to-support-family.html'
url215='https://cityroom.blogs.nytimes.com/2012/08/08/mourning-wisconsin-shooting-victims-in-new-york/'
url216='https://query.nytimes.com/gst/fullpage.html?res=9C0DE5DC1738F93AA3575BC0A9649D8B63'
url217='https://india.blogs.nytimes.com/2012/08/09/for-victim-in-sikh-temple-shooting-a-life-of-separation-2/'
url218='http://www.nytimes.com/2012/08/10/us/wisconsin-community-promotes-tolerance-after-shooting.html'
url219='https://thelede.blogs.nytimes.com/2012/08/10/memorial-service-for-victims-of-the-sikh-temple-shooting/'
url220='http://www.nytimes.com/2012/08/11/us/if-the-sikh-temple-had-been-a-muslim-mosque-on-religion.html'
url221='https://thelede.blogs.nytimes.com/2012/08/10/after-attacks-and-threats-tennessee-mosque-opens/'
url222='http://www.nytimes.com/2012/08/11/us/in-wisconsin-service-held-for-6-killed-at-sikh-temple.html'
url223='http://www.nytimes.com/2012/08/11/us/islamic-center-of-murfreesboro-opens-in-tennessee.html'

# %%
#Sikh Temple
urls=[url191,url192,url193,url194,url195,url196,url197,url198,url199,url200,url201,url202,url203,url204,url205,url206,
     url207,url208,url209,url210,url211,url212,url213,url214,url215,url216,url217,url218,url219,url220,url221,
     url222,url223]
Nyt_Sikh =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Sikh= Nyt_Sikh.append([[a.title, a.text]], ignore_index=True)
Nyt_Sikh.columns=['Title','Article']
Nyt_Sikh['Incident Name'] = 'Sikh Temple in Wisconsin'
Nyt_Sikh
# Out:
#                                                 Title  \
# 0          Gunman Kills 6 at Sikh Temple in Wisconsin
# 1         Candidates React to Shooting at Sikh Temple
# 2             Alabama: Suspect In Killings Surrenders
# 3    Scenes From Shooting at Sikh Temple in Wisconsin
# 4                Gunman Kills 6 in Wisconsin Gurdwara
# 5   For Many Sikhs, Wisconsin Attack Has Troubling...
# 6           Wade Page Is Suspected Sikh Temple Killer
# 7   After Shooting, Searching for Clues in the Mus...
# 8           Wade Page Is Suspected Sikh Temple Killer
# 9                     The Shooting at the Sikh Temple
# 10  Sikhs Mourn Victims and Lament Post-9/11 Targe...
# 11   Wisconsin Killer Was Fueled by Hate-Driven Music
# 12                              Being Sikh in America
# 13  NRA Letter Warns of Gun Confiscation; Obama Ur...
# 14                            A Sikh Temple’s Century
# 15  Hatecore Music Is Called White Supremacist Rec...
# ...

# %%
#Accent Signage Systems in Minneapolis
url224='http://www.nytimes.com/2012/09/29/us/minnesota-shooting-toll-rises-to-six.html'
url225='http://www.nytimes.com/2012/09/28/us/several-killed-in-shooting-at-accent-signage-systems-in-minneapolis.html'
urls=[url224,url225]
Nyt_Accent =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Accent= Nyt_Accent.append([[a.title, a.text]], ignore_index=True)
Nyt_Accent.columns=['Title','Article']
Nyt_Accent['Incident Name'] = 'Accent Signage Systems in Minneapolis'
Nyt_Accent
# Out:
#                                                Title  \
# 0              Minnesota: Shooting Toll Rises to Six
# 1  Several Killed in Workplace Shooting in Minnea...
#
#                                              Article  \
# 0  The death toll from an attack at a sign compan...
# 1  MINNEAPOLIS (AP) — A workplace shooting result...
#
#                            Incident Name
# 0  Accent Signage Systems in Minneapolis
# 1  Accent Signage Systems in Minneapolis

# %%
#Spot NightClub
url=['No Articles'] # Appalachian School oF Law
Nyt_Spot =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Spot= Nyt_Spot.append([[a.title, a.text]], ignore_index=True)
Nyt_Spot.columns=['Title','Article']
Nyt_Spot['title'] = 'NaN'
Nyt_Spot['article'] = 'NaN'
Nyt_Spot['Incident Name'] = 'The Spot Nightclub'
Nyt_Spot.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Spot.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Spot
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Azana Spa in Brookfield
url226='http://www.nytimes.com/2012/10/22/us/three-killed-in-shooting-at-spa-in-brookfield-wis.html'
Nyt_ASB =pd.DataFrame() 
a=Article(url99, language='en')
a.download()
a.parse()
Nyt_ASB= Nyt_ASB.append([[a.title, a.text]], ignore_index=True)
Nyt_ASB.columns=['Title','Article']
Nyt_ASB['Incident Name'] = 'Azana Spa in Brookfield'
Nyt_ASB
# Out:
#                                    Title  \
# 0  Georgia: Five Dead in Shooting at Spa
#
#                                              Article            Incident Name
# 0  The police are investigating a shooting at a K...  Azana Spa in Brookfield

# %%
#Clackamas Town Center
url227='https://thelede.blogs.nytimes.com/2012/12/12/video-and-tweets-from-inside-oregon-shopping-mall/'
url228='http://www.nytimes.com/2012/12/12/us/fatal-mall-shooting-in-portland.html'
url229='http://www.nytimes.com/2012/12/12/us/fatal-shooting-in-oregon-shopping-mall.html'
url230='http://www.nytimes.com/2012/12/13/us/oregon-mall-closed-after-deadly-shooting.html'
urls=[url227,url228,url229,url230]
Nyt_Cla =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Cla= Nyt_Cla.append([[a.title, a.text]], ignore_index=True)
Nyt_Cla.columns=['Title','Article']
Nyt_Cla['Incident Name'] = 'Clackamas Town Center'
Nyt_Cla
# Out:
#                                                Title  \
# 0  Facebook Profile of Gunman in Oregon Shopping ...
# 1                    Fatal Mall Shooting in Portland
# 2  3 Dead, Including Gunman, in Shooting at Orego...
# 3  In Oregon Mall Shooting, a Lower Toll, Includi...
#
#                                              Article          Incident Name
# 0  Photo\n\nAbout 10,000 people were inside the C...  Clackamas Town Center
# 1  The police said at least one person had been k...  Clackamas Town Center
# 2  A gunman opened fire in a shopping mall in sub...  Clackamas Town Center
# 3  Some of the details that emerged on Wednesday ...  Clackamas Town Center

# %%
#Sandyhook
url231='http://www.nytimes.com/2012/12/15/nyregion/shooting-reported-at-connecticut-elementary-school.html'
url232='https://thelede.blogs.nytimes.com/2012/12/14/shooting-reported-at-connecticut-elementary-school/'
url233='https://parenting.blogs.nytimes.com/2012/12/14/should-students-be-trained-for-school-shootings/'
url234='https://learning.blogs.nytimes.com/2012/12/14/resources-talking-and-teaching-about-the-shooting-in-newtown-connecticut/'
url235='http://www.nytimes.com/2012/12/15/nyregion/sandy-hook-shooting-forces-re-examination-of-tough-questions.html'
url236='http://www.nytimes.com/2012/12/15/nyregion/sandy-hook-principal-and-school-psychologist-went-the-extra-mile.html'
url237='http://www.nytimes.com/2012/12/15/nyregion/adam-lanza-an-enigma-who-is-now-identified-as-a-mass-killer.html'
url238='http://www.nytimes.com/2012/12/15/opinion/collins-looking-for-america.html'
url239='http://www.nytimes.com/2012/12/15/nyregion/witnesses-recall-deadly-shooting-sandy-hook-newtown-connecticut.html'
url240='http://www.nytimes.com/2012/12/15/nyregion/after-newtown-shooting-running-and-hoping-to-find-a-child-safe.html'
url241='https://thelede.blogs.nytimes.com/2012/12/15/live-updates-on-school-shooting/'
url242='http://www.nytimes.com/2012/12/16/nyregion/gunman-kills-20-children-at-school-in-connecticut-28-dead-in-all.html'
url243='http://www.nytimes.com/2012/12/16/nyregion/for-newtown-horror-halts-a-season-of-celebration.html'
url244='http://www.nytimes.com/2012/12/16/nyregion/friends-of-gunmans-mother-his-first-victim-recall-her-as-generous.html'
url245='http://www.nytimes.com/2012/12/17/nyregion/sandy-hook-school-shooting-in-newtown.html'
url246='https://thelede.blogs.nytimes.com/2012/12/16/sunday-coverage-of-newtown-school-shooting/'
url247='https://opinionator.blogs.nytimes.com/2012/12/16/the-freedom-of-an-armed-society/'
url248='http://www.nytimes.com/2012/12/17/us/politics/bloomberg-urges-obama-to-take-action-on-gun-control.html'
url249='https://learning.blogs.nytimes.com/2012/12/16/the-newtown-school-shootings-a-place-to-post-your-thoughts/'
url250='http://www.nytimes.com/2012/12/17/nyregion/in-newtown-conn-a-stiff-resistance-to-gun-restrictions.html'
url251='http://www.nytimes.com/2012/12/17/business/media/newtown-has-mixed-feelings-about-the-media-horde-in-its-midst.html'
url252='http://www.nytimes.com/2012/12/17/us/in-wake-of-newtown-shooting-grappling-with-what-to-tell-the-children.html'
url253='https://learning.blogs.nytimes.com/2012/12/17/finding-our-student-and-teacher-resources-on-the-newtown-conn-shootings/'
url254='https://mediadecoder.blogs.nytimes.com/2012/12/17/the-breakfast-meeting-reporting-from-newtown-and-a-puppet-provocateur/'
url255='https://thelede.blogs.nytimes.com/2012/12/17/dec-17-updates-on-connecticut-shooting-aftermath/'
url256='http://www.nytimes.com/2012/12/18/nyregion/security-increased-at-connecticut-schools-as-investigation-into-shooting-continues.html'
url257='https://opinionator.blogs.nytimes.com/2012/12/17/guns-and-the-decline-of-the-young-man/'
url258='https://atwar.blogs.nytimes.com/2012/12/17/veterans-feel-anxiety-and-relief-after-school-shooting/'
url259='https://www.nytimes.com/roomfordebate/2012/12/17/is-the-gun-lobby-invincible/'
url260='https://publiceditor.blogs.nytimes.com/2012/12/17/errors-in-newtown-shootings-coverage-reflect-growing-pressures/'
url261='http://www.nytimes.com/2012/12/18/health/for-young-survivors-odds-of-emotional-recovery-are-high.html'
url262='https://thecaucus.blogs.nytimes.com/2012/12/17/poll-conducted-after-shooting-shows-more-support-for-stricter-gun-laws/'
url263='http://www.nytimes.com/2012/12/18/opinion/a-national-commission.html'
url264='http://www.nytimes.com/2012/12/18/opinion/after-newtown-mourning-outrage-and-questions.html'
url265='http://www.nytimes.com/2012/12/18/opinion/nocera-lets-get-madd-about-guns.html'
url266='http://www.nytimes.com/2012/12/18/nyregion/amid-the-whiz-of-bullets-seeking-comfort-in-song.html'
url266='https://dealbook.nytimes.com/2012/12/17/wall-street-invested-in-firearms-is-unlikely-to-push-for-reform/'
url267='http://www.nytimes.com/2012/12/18/nyregion/two-funerals-for-two-6-year-old-boys-in-newtown.html'
url268='https://learning.blogs.nytimes.com/2012/12/18/how-should-we-prevent-future-mass-shootings/'
url269='https://dealbook.nytimes.com/2012/12/18/cerberus-to-sell-gunmaker-freedom-group/'
url270='https://thecaucus.blogs.nytimes.com/2012/12/18/a-rising-chorus-but-not-quite-consensus-on-guns/'
url271='https://cityroom.blogs.nytimes.com/2012/12/18/a-growing-list-of-gun-victims-and-the-mayors-demand-for-a-plan/'
url272='https://thelede.blogs.nytimes.com/2012/12/18/latest-updates-on-connecticut-shooting-aftermath/'
url273='https://publiceditor.blogs.nytimes.com/2012/12/18/adam-lanza-aspergers-and-a-misleading-connection-with-violence/'
url274='https://mediadecoder.blogs.nytimes.com/2012/12/18/gun-focused-reality-tv-shows-get-new-scrutiny-after-newtown-killings/'
url275='http://www.nytimes.com/2012/12/19/nyregion/lanzas-mother-shot-4-times-in-head-medical-examiner-says.html'
url276='http://www.nytimes.com/2012/12/19/opinion/taking-steps-to-avert-mass-shootings.html'
url277='http://www.nytimes.com/2012/12/19/us/states-leaders-proposing-steps-to-control-guns.html'
url278='http://www.nytimes.com/2012/12/19/nyregion/more-funerals-held-in-newtown-after-massacre.html'
url279='http://www.nytimes.com/2012/12/19/nyregion/for-malloy-connecticut-shootings-provided-heart-wrenching-test.html'
url280='http://www.nytimes.com/2012/12/19/education/after-newtown-shootings-schools-consider-armed-security-officers.html'
url281='https://thelede.blogs.nytimes.com/2012/12/19/updates-on-connecticut-shooting-aftermath/'
url282='https://mediadecoder.blogs.nytimes.com/2012/12/19/piers-morgan-shows-disgust-while-interviewing-gun-owners-advocate/'
url283='http://www.nytimes.com/2012/12/20/us/politics/obama-to-give-congress-plan-on-gun-control-within-weeks.html'
url284='https://dealbook.nytimes.com/2012/12/19/morgan-stanley-reaches-out-after-sandy-hook-massacre/'
url285='http://www.nytimes.com/2012/12/20/nyregion/remembering-the-passion-of-victoria-soto-a-sandy-hook-teacher.html'
url286='http://www.nytimes.com/2012/12/20/opinion/kristof-looking-for-lessons-in-newtown.html'
url287='https://thelede.blogs.nytimes.com/2012/12/19/president-cites-other-shootings-since-newtown/'
url288='https://thelede.blogs.nytimes.com/2012/12/20/updates-on-connecticut-shooting-aftermath-2/'
url289='https://takingnote.blogs.nytimes.com/2012/12/20/preposterous-explanations-for-newtown/'
url290='https://dotearth.blogs.nytimes.com/2012/12/20/empathy-as-a-path-to-climate-and-energy-progress/'
url291='http://www.nytimes.com/2012/12/21/nyregion/newtown-conn-school-aide-is-remembered-for-her-devotion.html'
url292='http://www.nytimes.com/2012/12/21/nyregion/police-dept-to-use-internet-to-try-to-stop-shootings.html'
url293='https://opinionator.blogs.nytimes.com/2012/12/20/preparing-students-for-a-newtown-like-disaster/'
url294='http://www.nytimes.com/2012/12/21/nyregion/memorial-held-for-nancy-lanza-mother-of-newtown-gunman.html'
url295='http://www.nytimes.com/2012/12/21/nyregion/cuomo-says-he-will-outline-gun-measures-next-month.html'

# %%
urls=[url231, url232,url233,url234,url235,url236,url237,url238,url239,url240,url241,url242,url243,url244,url245,url246,
     url247,url248,url249,url250,url251,url252,url253,url254,url255,url256,url257,url258,url259,url260,url261,url262,
     url263,url264,url265,url266,url267,url268,url269,url270,url271,url272,url273,url274,url275,url276,url277,url278,
     url279,url280,url281,url282,url283,url284,url285,url286,url287,url288,url289,url290,url291,url292,url293,url294,
     url295]
Nyt_Sandy =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Sandy= Nyt_Sandy.append([[a.title, a.text]], ignore_index=True)
Nyt_Sandy.columns=['Title','Article']
Nyt_Sandy['Incident Name'] = 'Sandy Hook Elementary School'
Nyt_Sandy
# Out:
#                                                 Title  \
# 0       Gunman Kills 20 Schoolchildren in Connecticut
# 1      Dec. 14 Updates on Connecticut School Shooting
# 2    Should Students Be Trained for School Shootings?
# 3   Resources: Talking and Teaching About the Shoo...
# 4   Sandy Hook Forces Re-examination of Tough Ques...
# 5   Two Newtown Educators Went the Extra Mile for ...
# 6   Adam Lanza, an Enigma Who Is Now Identified as...
# 7                                 Looking for America
# 8        Witnesses Recall a Nightmare That Took Shape
# 9   After Newtown Shooting, Running and Hoping to ...
# 10  Dec. 15 Updates on Connecticut Shooting Aftermath
# 11  Children in Connecticut School Were All Shot M...
# 12  For Close-Knit Town, Horror Halts a Season of ...
# 13  Adam Lanza’s Mother Was a Gun Enthusiast, Frie...
# 14  Gunman Took Big Supply of Ammunition to School...
# 15  Dec. 16 Updates on Connecticut Shooting Aftermath
# ...

# %%
#South Valley Residence
url296='http://www.nytimes.com/2013/01/22/us/new-mexico-teenager-is-charged-with-killing-his-family.html'
Nyt_SVR =pd.DataFrame() 
a=Article(url296, language='en')
a.download()
a.parse()
Nyt_SVR= Nyt_SVR.append([[a.title, a.text]], ignore_index=True)
Nyt_SVR.columns=['Title','Article']
Nyt_SVR['Incident Name'] = 'South Valley Residence'
Nyt_SVR
# Out:
#                                                Title  \
# 0  New Mexico Teenager Is Charged With Killing Hi...
#
#                                              Article           Incident Name
# 0  ALBUQUERQUE (AP) — A New Mexico teenager accus...  South Valley Residence

# %%
#Phoenix Law Firm
url297='http://www.nytimes.com/2013/01/31/us/gunman-opens-fire-at-phoenix-office-complex.html'
Nyt_PLF =pd.DataFrame() 
a=Article(url297, language='en')
a.download()
a.parse()
Nyt_PLF= Nyt_PLF.append([[a.title, a.text]], ignore_index=True)
Nyt_PLF.columns=['Title','Article']
Nyt_PLF['Incident Name'] = 'South Valley Residence'
Nyt_PLF
# Out:
#                                                Title  \
# 0  Gunman in Phoenix Kills One and Injures Two Ot...
#
#                                              Article           Incident Name
# 0  Photo\n\nPHOENIX — A gunman opened fire at an ...  South Valley Residence

# %%
#Los Angeles Police Department
url298='https://thelede.blogs.nytimes.com/2013/02/07/excerpts-from-online-manifesto-of-ex-police-officer-wanted-in-shootings/'
url299='http://www.nytimes.com/2013/02/09/us/for-some-suspects-charges-of-police-racism-resound.html'
urls=[url298,url299]
Nyt_LAPD =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LAPD= Nyt_LAPD.append([[a.title, a.text]], ignore_index=True)
Nyt_LAPD.columns=['Title','Article']
Nyt_LAPD['Incident Name'] = 'Los Angeles Police Department'
Nyt_LAPD
# Out:
#                                                Title  \
# 0  Excerpts From Manifesto Posted Online by Ex-Of...
# 1  For Some, Suspect’s Charges of Police Racism R...
#
#                                              Article  \
# 0  Last Updated, 7:30 p.m. With three people dead...
# 1  Indeed, in posts on Facebook and in interviews...
#
#                    Incident Name
# 0  Los Angeles Police Department
# 1  Los Angeles Police Department

# %%
#Ladera Ranch, Santa Ana, Tustin and Orange
url300='http://www.nytimes.com/2013/02/20/us/shooting-spree-in-california.html'
Nyt_LR =pd.DataFrame() 
a=Article(url300, language='en')
a.download()
a.parse()
Nyt_LR= Nyt_LR.append([[a.title, a.text]], ignore_index=True)
Nyt_LR.columns=['Title','Article']
Nyt_LR['Incident Name'] = 'Ladera Ranch, Santa Ana, Tustin and Orange'
Nyt_LR
# Out:
#                                      Title  \
# 0  At Least 4 Dead in California Shootings
#
#                                              Article  \
# 0  As the man drove through the parking lot to es...
#
#                                 Incident Name
# 0  Ladera Ranch, Santa Ana, Tustin and Orange

# %%
#Pinewood Village Apartments
url301='http://www.nytimes.com/2013/04/23/us/washington-5-dead-in-shooting-at-apartments.html'
Nyt_PVA =pd.DataFrame() 
a=Article(url301, language='en')
a.download()
a.parse()
Nyt_PVA= Nyt_PVA.append([[a.title, a.text]], ignore_index=True)
Nyt_PVA.columns=['Title','Article']
Nyt_PVA['Incident Name'] = 'Pinewood Village Apartments'
Nyt_PVA
# Out:
#                                           Title  \
# 0  Washington: 5 Dead in Shooting at Apartments
#
#                                              Article  \
# 0  A 28-year-old man shot and killed his girlfrie...
#
#                  Incident Name
# 0  Pinewood Village Apartments

# %%
#Village of Manchester in Illinois
url=['No Articles']
Nyt_VMIL =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_VMIL= Nyt_VMIL.append([[a.title, a.text]], ignore_index=True)
Nyt_VMIL.columns=['Title','Article']
Nyt_VMIL['title'] = 'NaN'
Nyt_VMIL['article'] = 'NaN'
Nyt_VMIL['Incident Name'] = 'Village of Manchester in Illinois'
Nyt_VMIL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_VMIL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_VMIL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Santa Monica College
url302='http://www.nytimes.com/2013/06/08/us/santa-monica-college-shooting.html'
url303='http://www.nytimes.com/2013/06/09/us/police-call-santa-monica-gunman-ready-for-battle.html'
url304='http://www.nytimes.com/2013/06/10/us/toll-in-santa-monica-shooting-rampage-rises-to-five.html'
urls=[url302,url303,url304]
Nyt_SMC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SMC= Nyt_SMC.append([[a.title, a.text]], ignore_index=True)
Nyt_SMC.columns=['Title','Article']
Nyt_SMC['Incident Name'] = 'Santa Monica College'
Nyt_SMC
# Out:
#                                                Title  \
# 0                 Four Dead in Santa Monica Shooting
# 1  Police Call Santa Monica Gunman ‘Ready for Bat...
# 2  Toll in Santa Monica Shooting Rampage Rises to...
#
#                                              Article         Incident Name
# 0  SANTA MONICA, Calif. — Four people were killed...  Santa Monica College
# 1  SANTA MONICA, Calif. — The gunman whose rampag...  Santa Monica College
# 2  SANTA MONICA, Calif. — A woman who was critica...  Santa Monica College

# %%
#Hialeah Apartments
url305='http://www.nytimes.com/2013/07/28/us/6-shot-dead-by-neighbor-at-building-near-miami.html'
Nyt_HA =pd.DataFrame() 
a=Article(url305, language='en')
a.download()
a.parse()
Nyt_HA= Nyt_HA.append([[a.title, a.text]], ignore_index=True)
Nyt_HA.columns=['Title','Article']
Nyt_HA['Incident Name'] = 'Hialeah Apartments'
Nyt_HA
# Out:
#                                             Title  \
# 0  6 Shot Dead by Neighbor at Building Near Miami
#
#                                              Article       Incident Name
# 0  “No one seems to know why he acted the way he ...  Hialeah Apartments

# %%
#Ross Township Supervisor Council Meeting
url306='http://www.nytimes.com/2013/08/06/us/3-are-killed-at-a-township-meeting.html'
url307='https://thelede.blogs.nytimes.com/2013/08/06/pennsylvania-gunman-feuded-with-officials-for-almost-two-decades-over-land/'
url308='http://www.nytimes.com/2013/08/07/us/shooting-suspect-had-long-dispute-with-township-officials.html'
urls=[url306,url307,url308]
Nyt_RTSCM =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RTSCM= Nyt_RTSCM.append([[a.title, a.text]], ignore_index=True)
Nyt_RTSCM.columns=['Title','Article']
Nyt_RTSCM['Incident Name'] = 'Ross Township Supervisor Council Meeting'
Nyt_RTSCM
# Out:
#                                                Title  \
# 0  3 Are Shot to Death at a Township Meeting in P...
# 1  Pennsylvania Gunman Feuded With Officials for ...
# 2  Gunfire at Board Meeting Traced to Eviction Di...
#
#                                              Article  \
# 0  SAYLORSBURG, Pa. — A shooting during a townshi...
# 1  Angry that town officials in northeastern Penn...
# 2  After he was arrested, Mr. Newell told officer...
#
#                               Incident Name
# 0  Ross Township Supervisor Council Meeting
# 1  Ross Township Supervisor Council Meeting
# 2  Ross Township Supervisor Council Meeting

# %%
#Oklahoma City Residence
url=['No Articles']
Nyt_VMIL =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_VMIL= Nyt_VMIL.append([[a.title, a.text]], ignore_index=True)
Nyt_VMIL.columns=['Title','Article']
Nyt_VMIL['title'] = 'NaN'
Nyt_VMIL['article'] = 'NaN'
Nyt_VMIL['Incident Name'] = 'Oklahoma City Residence'
Nyt_VMIL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_VMIL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_VMIL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Navy Yard URLS
url309='http://www.nytimes.com/2013/09/17/us/shooting-reported-at-washington-navy-yard.html'
url310='https://thelede.blogs.nytimes.com/2013/09/16/live-updates-from-washington-navy-yard-shootings/'
url311='http://www.nytimes.com/2013/09/17/us/suspect-in-shooting-had-interest-in-thai-culture-and-problems-with-the-law.html'
url312='https://learning.blogs.nytimes.com/2013/09/17/6-qs-about-the-news-shooting-at-d-c-navy-yard/'
url313='http://www.nytimes.com/2013/09/18/us/washington-navy-yard-shootings.html'
url314='https://takingnote.blogs.nytimes.com/2013/09/17/yet-more-gun-violence/'
url315='https://thelede.blogs.nytimes.com/2013/09/17/remembering-the-victims-of-the-washington-navy-yard/'
url316='https://thecaucus.blogs.nytimes.com/2013/09/17/after-navy-yard-shooting-a-new-look-at-gun-control/'
url317='http://www.nytimes.com/2013/09/18/us/state-law-stopped-gunman-from-buying-rifle-officials-say.html'
url318='http://www.nytimes.com/2013/09/18/us/victims-of-navy-yard-shooting-are-remembered-for-their-simple-pleasures.html'
url319='http://www.nytimes.com/2013/09/18/opinion/dowd-losing-the-room.html'
url320='http://www.nytimes.com/2013/09/19/us/hagel-orders-reviews-of-security-procedures-and-clearances.html'
url321='http://www.nytimes.com/2013/09/19/us/gunmans-family-left-shocked-saddened-mystified.html'
url322='https://parenting.blogs.nytimes.com/2013/09/18/calming-a-childs-fears-after-another-mass-shooting/'
url323='http://www.nytimes.com/2013/09/19/opinion/blow-a-ghastly-ritual-repeats-itself.html'
url324='http://www.nytimes.com/2013/09/19/opinion/how-america-reacts-to-mass-shootings.html'
url325='http://www.nytimes.com/2013/09/19/us/signs-may-be-evident-in-hindsight-but-predicting-violent-behavior-is-tough.html'
url326='http://www.nytimes.com/2013/09/19/us/politics/mental-health-again-an-issue-in-gun-debate.html'
url327='http://www.nytimes.com/2013/09/20/us/gunman-was-wandering-halls-as-he-shot-fbi-chief-says.html'
url328='http://www.nytimes.com/2013/09/20/us/signs-of-trouble-on-navy-yard-gunmans-path-to-tragedy.html'
url329='http://www.nytimes.com/2013/09/20/opinion/luhrmann-the-violence-in-our-heads.html'
url330='http://www.nytimes.com/2013/09/21/us/navy-yard-gunman-shatters-a-texas-buddhist-groups-quiet.html'
url331='http://www.nytimes.com/2013/09/21/us/fbi-tries-to-find-motive-of-navy-yard-gunman.html'
url332='http://www.nytimes.com/2013/09/23/us/obama-to-attend-memorial-service-for-victims-of-navy-yard-shooting.html'

# %%
urls=[url309,url310,url311,url312,url313,url314,url315,url316,url317,url318,url319,url320,url321,url322,url323,
      url324,url325,url326,url327,url328,url329,url330,url331,url332]
Nyt_WNY =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WNY= Nyt_WNY.append([[a.title, a.text]], ignore_index=True)
Nyt_WNY.columns=['Title','Article']
Nyt_WNY['Incident Name'] = 'Washington Navy Yard'
Nyt_WNY
# Out:
#                                                 Title  \
# 0   Gunman and 12 Victims Killed in Shooting at D....
# 1         Updates From Washington Navy Yard Shootings
# 2       Suspect in Shooting Had Problems With the Law
# 3     Shooting at D.C. Navy Yard - The New York Times
# 4     Suspect’s Past Fell Just Short of Raising Alarm
# 5                               Yet More Gun Violence
# 6   Remembering the Victims of the Washington Navy...
# 7   After Navy Yard Shooting, a New Look at Gun Co...
# 8   State Law Prevented Sale of Assault Rifle to S...
# 9   Fathers and Mothers, Nature Lovers and Sports ...
# 10                                 The New York Times
# 11  Officials Never Learned of Police Doubts on Gu...
# 12  Gunman’s Family Left Shocked, Saddened, Mystified
# 13  Calming a Child's Fears After Another Mass Sho...
# 14                    A Ghastly Ritual Repeats Itself
# 15               How America Reacts to Mass Shootings
# ...

# %%
#Sparks Middle School
url333='https://thelede.blogs.nytimes.com/2013/10/23/after-theres-a-kid-with-a-gun-came-teacher-down/'
url334='http://www.nytimes.com/2013/10/22/us/two-killed-in-shooting-at-a-nevada-middle-school.html'
urls=[url333,url334]
Nyt_SMS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SMS= Nyt_SMS.append([[a.title, a.text]], ignore_index=True)
Nyt_SMS.columns=['Title','Article']
Nyt_SMS['Incident Name'] = 'Sparks Middle School'
Nyt_SMS
# Out:
#                                                Title  \
# 0  After 'There's a Kid With a Gun' Came 'Teacher...
# 1  Student Kills Math Teacher, Then Himself, at a...
#
#                                              Article         Incident Name
# 0  In a trembling voice, the student called 911 t...  Sparks Middle School
# 1  Photo\n\nA Nevada middle school student shot a...  Sparks Middle School

# %%
#Mohawk and Herkimer Villages in New York
url335='http://www.nytimes.com/2013/03/15/nyregion/man-sought-in-upstate-new-york-shootings-is-killed.html'
url336='http://www.nytimes.com/2013/03/14/nyregion/four-killed-in-shootings-in-upstate-new-york.html'
urls=[url335,url336]
Nyt_MHV =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MHV= Nyt_MHV.append([[a.title, a.text]], ignore_index=True)
Nyt_MHV.columns=['Title','Article']
Nyt_MHV['Incident Name'] = 'Mohawk and Herkimer Villages in New York'
Nyt_MHV
# Out:
#                                                Title  \
# 0  Suspect in Upstate Shootings Is Killed, but Qu...
# 1  Man Who Fatally Shot 4 in Upstate New York Is ...
#
#                                              Article  \
# 0  “He was very quiet,” Ms. Tooke said. “And I kn...
# 1  The police discovered the suspect’s car near a...
#
#                               Incident Name
# 0  Mohawk and Herkimer Villages in New York
# 1  Mohawk and Herkimer Villages in New York

# %%
#Los Angeles International Airport (LAX)
url337='https://thelede.blogs.nytimes.com/2013/11/01/descriptions-of-chaos-and-fear-at-los-angeles-airport-shooting/?_r=0'
url338='http://www.nytimes.com/2013/11/02/us/shots-fired-at-airport-in-los-angeles.html'
urls=[url337,url338]
Nyt_LAX =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LAX= Nyt_LAX.append([[a.title, a.text]], ignore_index=True)
Nyt_LAX.columns=['Title','Article']
Nyt_LAX['Incident Name'] = 'Los Angeles International Airport (LAX)'
Nyt_LAX
# Out:
#                                                Title  \
# 0  Descriptions of Chaos and Fear at Los Angeles ...
# 1    Security Agent Is Killed at Los Angeles Airport
#
#                                              Article  \
# 0  As my colleagues Jennifer Medina and Timothy W...
# 1  Federal officials identified the gunman as Pau...
#
#                              Incident Name
# 0  Los Angeles International Airport (LAX)
# 1  Los Angeles International Airport (LAX)

# %%
#Homes in Desoto and Dallas
url339='http://www.nytimes.com/2013/08/09/us/texas-man-held-in-four-killings.html'
Nyt_HDD =pd.DataFrame() 
a=Article(url339, language='en')
a.download()
a.parse()
Nyt_HDD= Nyt_HDD.append([[a.title, a.text]], ignore_index=True)
Nyt_HDD.columns=['Title','Article']
Nyt_HDD['Incident Name'] = 'Homes in Desoto and Dallas'
Nyt_HDD
# Out:
#                               Title  \
# 0  Texas: Man Held in Four Killings
#
#                                              Article  \
# 0  A former teacher and dancer for the Dallas Mav...
#
#                 Incident Name
# 0  Homes in Desoto and Dallas

# %%
#Centennial Hill Bar & Grill
url=['No Articles']
Nyt_CHB =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CHB= Nyt_CHB.append([[a.title, a.text]], ignore_index=True)
Nyt_CHB.columns=['Title','Article']
Nyt_CHB['title'] = 'NaN'
Nyt_CHB['article'] = 'NaN'
Nyt_CHB['Incident Name'] = 'Centennial Hill Bar & Grill'
Nyt_CHB.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CHB.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CHB
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#San Francisco Tenderloin
url=['No Articles']
Nyt_SFT =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SFT= Nyt_SFT.append([[a.title, a.text]], ignore_index=True)
Nyt_SFT.columns=['Title','Article']
Nyt_SFT['title'] = 'NaN'
Nyt_SFT['article'] = 'NaN'
Nyt_SFT['Incident Name'] = 'San Francisco Tenderloin'
Nyt_SFT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_SFT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_SFT
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Fort Hood
url340='https://www.nytimes.com/2014/04/03/us/gunshots-reported-at-fort-hood.html'
url341='https://thelede.blogs.nytimes.com/2014/04/02/live-updates-on-shooting-at-fort-hood-in-texas/'
url342='https://www.nytimes.com/2014/04/04/us/fort-hood-shooting.html'
url343='https://www.nytimes.com/2014/04/04/us/fort-hood-security-problems.html'
url344='https://www.nytimes.com/2014/04/04/us/gunman-had-clean-record-with-no-violent-sign-officials-say.html'
url345='https://www.nytimes.com/2014/04/04/us/among-fort-hood-victims-a-sergeant-is-killed-and-a-major-is-wounded.html'
url346='https://www.nytimes.com/2014/04/05/us/soldier-in-fort-hood-attack-was-in-dispute-over-leave.html'
urls=[url340,url341,url342,url343,url344,url345,url346]
Nyt_FtH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FtH= Nyt_FtH.append([[a.title, a.text]], ignore_index=True)
Nyt_FtH.columns=['Title','Article']
Nyt_FtH['Incident Name'] = 'Fort Hood'
Nyt_FtH
# Out:
#                                                Title  \
# 0  Iraq Veteran at Fort Hood Kills 3 and Himself ...
# 1                  Updates on the Fort Hood Shooting
# 2  Fort Hood Gunman Was Being Treated for Depression
# 3         Fort Hood Does Little to Keep Out Firearms
# 4  Gunman Had ‘Clean Record,’ With No Violent Sig...
# 5  Among Fort Hood Victims, a Sergeant Is Killed,...
# 6  Dispute Over Leave Agitated Ft. Hood Soldier B...
#
#                                              Article Incident Name
# 0  The chairman of the Joint Chiefs of Staff, Gen...     Fort Hood
# 1  The Lede is a blog that remixes national and i...     Fort Hood
# 2  “It’s not clear how common that is or whether ...     Fort Hood
# 3  At Fort Hood, which sprawls for 340 square mil...     Fort Hood
# 4  Photo\n\nSpecialist Ivan Antonio Lopez had see...     Fort Hood
# 5  Sergeant Owens dropped out of high school in 1...     Fort Hood
# 6  “The first guy he shot right in front of my so...     Fort Hood

# %%
#Kennesaw FedEx	
url347='https://www.nytimes.com/2014/04/30/us/fedex-shooting-atlanta.html'
Nyt_KF =pd.DataFrame() 
a=Article(url347, language='en')
a.download()
a.parse()
Nyt_KF= Nyt_KF.append([[a.title, a.text]], ignore_index=True)
Nyt_KF.columns=['Title','Article']
Nyt_KF['Incident Name'] = 'Kennesaw FedEx'
Nyt_KF
# Out:
#                                                Title  \
# 0  6 Wounded in Shooting at FedEx Warehouse in Ge...
#
#                                              Article   Incident Name
# 0  Photo\n\nA 19-year-old package handler at a Fe...  Kennesaw FedEx

# %%
#Isla Vista
url348='https://www.nytimes.com/2014/05/25/us/california-drive-by-shooting.html'
url349='https://www.nytimes.com/2014/05/25/business/youtube-removes-video-posted-by-shooting-suspect.html'
url350='https://news.blogs.nytimes.com/2014/05/24/gunman-made-threats-in-141-page-manifesto-and-youtube-videos/'
url351='https://www.nytimes.com/2014/05/26/us/gunman-was-able-to-fly-under-the-radar-says-santa-barbara-sheriff.html'
url352='https://www.nytimes.com/2014/05/26/us/even-in-a-state-with-restrictive-laws-gunman-amassed-weapons-and-ammunition.html'
url353='https://www.nytimes.com/2014/05/26/us/parents-nightmare-failed-race-to-stop-killings.html'
url354='https://www.nytimes.com/2014/05/26/us/shooting-victims-drawn-to-california-campus-from-near-and-from-far.html'
url355='https://www.nytimes.com/2014/05/27/us/limits-to-law-and-information-sharing-despite-gunmans-danger-signs.html'
url356='https://www.nytimes.com/2014/05/28/opinion/as-congress-sleeps-more-people-die.html'
url357='https://www.nytimes.com/2014/05/28/us/after-california-attack-students-pause-and-seek-closure.html'
ulr358='https://www.nytimes.com/2014/05/29/us/in-wake-of-mass-shooting-a-gun-bill-is-pushed-in-california.html'
urls=[url348,url349,url350,url351,url352,url353,url354]
Nyt_IV =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_IV= Nyt_IV.append([[a.title, a.text]], ignore_index=True)
Nyt_IV.columns=['Title','Article']
Nyt_IV['Incident Name'] = 'Isla Vista'
Nyt_IV
# Out:
#                                                Title  \
# 0  Video Rant, Then Deadly Rampage in California ...
# 1   YouTube Removes Video Posted by Shooting Suspect
# 2  Gunman Made Threats in 141-Page Manifesto and ...
# 3     Gunman Covered Up Risks He Posed, Sheriff Says
# 4  Even in a State With Restrictive Laws, Gunman ...
# 5   Parents’ Nightmare: Futile Race to Stop Killings
# 6  Rampage Victims Drawn to California Campus Fro...
#
#                                              Article Incident Name
# 0  “I do not know why you girls aren’t attracted ...    Isla Vista
# 1  As news spread of a shooting in California tha...    Isla Vista
# 2  Gunman Made Threats in 141-Page Manifesto and ...    Isla Vista
# 3  The police said that Mr. Rodger, a college stu...    Isla Vista
# 4  The Santa Barbara County sheriff, Bill Brown, ...    Isla Vista
# 5  Only weeks earlier, in late April, deputies fr...    Isla Vista
# 6  The three victims killed during the rampage th...    Isla Vista

# %%
#Seattle Pacific University
url354='https://www.nytimes.com/2014/06/06/us/shooting-leaves-one-dead-at-seattle-pacific-university.html'
url355='https://www.nytimes.com/2014/06/07/us/seattle-pacific-university-gunman-shoots-four.html'
url356='https://op-talk.blogs.nytimes.com/2014/06/06/a-good-man-with-pepper-spray/'
url357='https://www.nytimes.com/2014/06/07/opinion/hard-lessons-from-belmont.html'
url358='https://www.nytimes.com/2014/06/11/us/troutdale-oregon-reynolds-high-school-shooting.html'
urls=[url354,url355,url356,url357,url358]
Nyt_SPU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SPU= Nyt_SPU.append([[a.title, a.text]], ignore_index=True)
Nyt_SPU.columns=['Title','Article']
Nyt_SPU['Incident Name'] = 'Seattle Pacific University'
Nyt_SPU
# Out:
#                                                Title  \
# 0  Shooting Leaves One Dead at Seattle Pacific Un...
# 1  Seattle Pacific University Students Stopped Gu...
# 2                       A Good Man With Pepper Spray
# 3                          Hard Lessons From Belmont
# 4  Oregon Shooting Draws Obama’s Outrage on Gun Laws
#
#                                              Article  \
# 0  Photo\n\nSEATTLE — A man armed with a shotgun ...
# 1  Aaron R. Ybarra, 26, who is not a student at t...
# 2  And the only thing that can stop a bad man wit...
# 3  I’VE been fooled by the Belmont Stakes before....
# 4  The president’s emotional remarks later in Was...
#
#                 Incident Name
# 0  Seattle Pacific University
# 1  Seattle Pacific University
# 2  Seattle Pacific University
# 3  Seattle Pacific University
# 4  Seattle Pacific University

# %%
#Nellis Plaza
url359='https://www.nytimes.com/2014/06/09/us/five-dead-in-shooting-rampage-in-las-vegas.html'
Nyt_NP =pd.DataFrame() 
a=Article(url359, language='en')
a.download()
a.parse()
Nyt_NP= Nyt_NP.append([[a.title, a.text]], ignore_index=True)
Nyt_NP.columns=['Title','Article']
Nyt_NP['Incident Name'] = 'Nellis Plaza'
Nyt_NP
# Out:
#                                         Title  \
# 0  Five Dead in Shooting Rampage in Las Vegas
#
#                                              Article Incident Name
# 0  Some witnesses reported that the couple had sh...  Nellis Plaza

# %%
#Bourbon Street New Orleans
url360='https://www.nytimes.com/2014/06/30/us/crossfire-hits-9-on-a-street-that-defines-new-orleans.html'
Nyt_BSNOLA =pd.DataFrame() 
a=Article(url360, language='en')
a.download()
a.parse()
Nyt_BSNOLA= Nyt_BSNOLA.append([[a.title, a.text]], ignore_index=True)
Nyt_BSNOLA.columns=['Title','Article']
Nyt_BSNOLA['Incident Name'] = 'Bourbon Street New Orleans'
Nyt_BSNOLA
# Out:
#                                                Title  \
# 0  Crossfire Hits 9 on a Street That Defines New ...
#
#                                              Article  \
# 0  NEW ORLEANS — Nine people were wounded by cros...
#
#                 Incident Name
# 0  Bourbon Street New Orleans

# %%
#Albuquerque Auto Shop
url=['No Articles']
Nyt_AAS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AAS= Nyt_AAS.append([[a.title, a.text]], ignore_index=True)
Nyt_AAS.columns=['Title','Article']
Nyt_AAS['title'] = 'NaN'
Nyt_AAS['article'] = 'NaN'
Nyt_AAS['Incident Name'] = 'Albuquerque Auto Shop'
Nyt_AAS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_AAS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_AAS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Marysville-Pilchuck High School
url361='https://www.nytimes.com/2014/10/25/us/shooting-reported-at-high-school-north-of-seattle.html'
url362='https://www.nytimes.com/2014/10/26/us/contrasting-portraits-emerge-of-jaylen-ray-fryberg-shooter-at-washington-school.html'
url363='https://www.nytimes.com/2014/10/27/us/teacher-is-praised-for-her-intervention-in-washington-school-shooting.html'
url364='https://www.nytimes.com/2014/10/28/us/washington-school-shooting-claims-another-victim-gia-soriano.html'
url365='https://www.nytimes.com/2014/10/30/sports/seahawks-host-seattle-high-school-football-team-less-than-a-week-after-shooting.html'
urls=[url361,url362,url363,url364,url365]
Nyt_MPHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MPHS= Nyt_MPHS.append([[a.title, a.text]], ignore_index=True)
Nyt_MPHS.columns=['Title','Article']
Nyt_MPHS['Incident Name'] = 'Marysville-Pilchuck High School'
Nyt_MPHS
# Out:
#                                                Title  \
# 0  2 Die, Including Gunman, in Shooting at Washin...
# 1  Tangled Portrait of a Student Emerges in Washi...
# 2  Teacher Is Praised for Her Intervention in Was...
# 3  Washington School Gunman Used Texts to Gather ...
# 4  Seahawks Host Seattle High School Football Tea...
#
#                                              Article  \
# 0  Rick Iverson, a former Marysville-Pilchuck Eng...
# 1  “This wasn’t the typical trench coat, introver...
# 2  Photo\n\nMARYSVILLE, Wash. — As this community...
# 3  Zoe’s death was mourned at Marysville-Pilchuck...
# 4  Coach Pete Carroll said it was an “amazing exp...
#
#                      Incident Name
# 0  Marysville-Pilchuck High School
# 1  Marysville-Pilchuck High School
# 2  Marysville-Pilchuck High School
# 3  Marysville-Pilchuck High School
# 4  Marysville-Pilchuck High School

# %%
#Florida State University
url366='https://www.nytimes.com/2014/11/21/us/florida-state-university-shooting.html'
urls=[url366]
Nyt_FSU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FSU= Nyt_FSU.append([[a.title, a.text]], ignore_index=True)
Nyt_FSU.columns=['Title','Article']
Nyt_FSU['Incident Name'] = 'Florida State University'
Nyt_FSU
# Out:
#                                             Title  \
# 0  Gunman at Florida State Spoke of Being Watched
#
#                                              Article             Incident Name
# 0  Mr. May graduated from Florida State in 2005 a...  Florida State University

# %%
#Cedarville Rancheria Tribe
url=['No Articles']
Nyt_CRT =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CRT= Nyt_CRT.append([[a.title, a.text]], ignore_index=True)
Nyt_CRT.columns=['Title','Article']
Nyt_CRT['title'] = 'NaN'
Nyt_CRT['article'] = 'NaN'
Nyt_CRT['Incident Name'] = 'Cedarville Rancheria Tribe'
Nyt_CRT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CRT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CRT
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Ensley Birmingham
url=['No Articles']
Nyt_EBAL =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_EBAL= Nyt_EBAL.append([[a.title, a.text]], ignore_index=True)
Nyt_EBAL.columns=['Title','Article']
Nyt_EBAL['title'] = 'NaN'
Nyt_EBAL['article'] = 'NaN'
Nyt_EBAL['Incident Name'] = 'Ensley Birmingham'
Nyt_EBAL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_EBAL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_EBAL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Pennsburg PA
url367='https://www.nytimes.com/2014/12/17/us/shooting-pennsylvania-bradley-stone.html'
url368='https://www.nytimes.com/2014/12/16/us/police-outside-philadelphia-search-for-gunman-after-reports-of-multiple-shootings.html'
urls=[url367,url368]
Nyt_PPA =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PPA= Nyt_PPA.append([[a.title, a.text]], ignore_index=True)
Nyt_PPA.columns=['Title','Article']
Nyt_PPA['Incident Name'] = 'Pennsburg PA'
Nyt_PPA
# Out:
#                                                Title  \
# 0  Pennsylvania Man Sought in Slaying of Family I...
# 1  Suspect in 6 Killings Is at Large Near Philade...
#
#                                              Article Incident Name
# 0  Two of the victims died from gunshot wounds wh...  Pennsburg PA
# 1  Around the same time as the news conference, a...  Pennsburg PA

# %%
#Memphis
url=['No Articles']
Nyt_MEM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MEM= Nyt_MEM.append([[a.title, a.text]], ignore_index=True)
Nyt_MEM.columns=['Title','Article']
Nyt_MEM['title'] = 'NaN'
Nyt_MEM['article'] = 'NaN'
Nyt_MEM['Incident Name'] = 'Memphis'
Nyt_MEM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MEM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MEM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Moscow
url=['No Articles']
Nyt_MID =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MID= Nyt_MID.append([[a.title, a.text]], ignore_index=True)
Nyt_MID.columns=['Title','Article']
Nyt_MID['title'] = 'NaN'
Nyt_MID['article'] = 'NaN'
Nyt_MID['Incident Name'] = 'Moscow'
Nyt_MID.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MID.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MID
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Queens
url369='https://www.nytimes.com/2015/01/25/nyregion/3-are-killed-including-7-year-old-girl-in-queens-home.html'
urls=[url369]
Nyt_QNY =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_QNY= Nyt_QNY.append([[a.title, a.text]], ignore_index=True)
Nyt_QNY.columns=['Title','Article']
Nyt_QNY['Incident Name'] = 'Queens'
Nyt_QNY
# Out:
#                                             Title  \
# 0  Queens Father Killed 3 and Himself, Police Say
#
#                                              Article Incident Name
# 0  Photo\n\nIn the predawn darkness, Christina Wa...        Queens

# %%
#LaGrange
url=['No Articles']
Nyt_LaG =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LaG= Nyt_LaG.append([[a.title, a.text]], ignore_index=True)
Nyt_LaG.columns=['Title','Article']
Nyt_LaG['title'] = 'NaN'
Nyt_LaG['article'] = 'NaN'
Nyt_LaG['Incident Name'] = 'LaGrange'
Nyt_LaG.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LaG.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LaG
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Omaha
url=['No Articles']
Nyt_Omaha =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Omaha= Nyt_Omaha.append([[a.title, a.text]], ignore_index=True)
Nyt_Omaha.columns=['Title','Article']
Nyt_Omaha['title'] = 'NaN'
Nyt_Omaha['article'] = 'NaN'
Nyt_Omaha['Incident Name'] = 'Omaha'
Nyt_Omaha.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Omaha.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Omaha
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chapel Hill
url370='https://www.nytimes.com/2015/02/12/us/muslim-student-shootings-north-carolina.html'
url371='https://www.nytimes.com/2015/02/17/us/north-carolina-jury-brings-three-murder-counts.html'
url372='https://www.nytimes.com/2015/02/13/us/chapel-hill-neighbors-say-they-felt-threatened-by-man-held-in-killings.html'
url373='https://www.nytimes.com/2015/02/14/us/fbi-inquiry-muslim-student-killings-chapel-hill-north-carolina.html'
url374='https://www.nytimes.com/2015/02/13/us/chapel-hill-north-carolina-mourns-death-of-three-muslim-students.html'
url375='https://www.nytimes.com/2015/02/14/world/middleeast/online-commenters-see-reporting-bias-in-killing-of-3-muslims.html'
url376='https://learning.blogs.nytimes.com/2015/02/13/6-qs-about-the-news-in-chapel-hill-shooting-of-3-muslims-a-question-of-motive/'
url377='https://www.nytimes.com/2015/02/12/us/north-carolina-shooting-spurs-muslimlivesmatter.html'
urls=[url370,url371,url372,url373,url374,url375,url376,url377]
Nyt_UNCCH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_UNCCH= Nyt_UNCCH.append([[a.title, a.text]], ignore_index=True)
Nyt_UNCCH.columns=['Title','Article']
Nyt_UNCCH['Incident Name'] = 'Chapel Hill'
Nyt_UNCCH
# Out:
#                                                Title  \
# 0  In Chapel Hill Shooting of 3 Muslims, a Questi...
# 1    North Carolina: Jury Brings Three Murder Counts
# 2  Neighbors Say Suspect in Chapel Hill Shootings...
# 3  Federal Inquiry Begins Into Muslim Students’ K...
# 4  Funeral for Muslims Killed in Chapel Hill Draw...
# 5  Jordanians See U.S. Reporting Bias in Coverage...
# 6  In Chapel Hill Shooting of 3 Muslims, a Questi...
# 7  Outrage Over North Carolina Shootings Spurs #M...
#
#                                              Article Incident Name
# 0  Even as Chapel Hill awoke on Wednesday, frustr...   Chapel Hill
# 1  A grand jury has indicted Craig Hicks, 46, of ...   Chapel Hill
# 2  “He was definitely aggressive, and he spoke ha...   Chapel Hill
# 3  Mr. Hicks had a long record of heated confront...   Chapel Hill
# 4  Many of those attending said they felt a deep ...   Chapel Hill
# 5  The front page Friday of Al Ghad, an independe...   Chapel Hill
# ...

# %%
#Monroeville Macys
url=['No Articles']
Nyt_MM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MM= Nyt_MM.append([[a.title, a.text]], ignore_index=True)
Nyt_MM.columns=['Title','Article']
Nyt_MM['title'] = 'NaN'
Nyt_MM['article'] = 'NaN'
Nyt_MM['Incident Name'] = 'Monroeville Macys'
Nyt_MM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Moon Lake
url=['No Articles']
Nyt_ML =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ML= Nyt_ML.append([[a.title, a.text]], ignore_index=True)
Nyt_ML.columns=['Title','Article']
Nyt_ML['title'] = 'NaN'
Nyt_ML['article'] = 'NaN'
Nyt_ML['Incident Name'] = 'Moon Lake'
Nyt_ML.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ML.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ML
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tyrone
url378='https://www.nytimes.com/2015/02/28/us/gunman-kills-7-people-in-tyrone-missouri.html'
urls=[url378]
Nyt_Ty =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Ty= Nyt_Ty.append([[a.title, a.text]], ignore_index=True)
Nyt_Ty.columns=['Title','Article']
Nyt_Ty['Incident Name'] = 'Tyrone'
Nyt_Ty
# Out:
#                                                Title  \
# 0  Tiny Missouri Town Is Reeling After Gunman Kil...
#
#                                              Article Incident Name
# 0  “Not sure what precipitated this,” the county ...        Tyrone

# %%
#Morgantown
url=['No Articles']
Nyt_WV =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WV= Nyt_WV.append([[a.title, a.text]], ignore_index=True)
Nyt_WV.columns=['Title','Article']
Nyt_WV['title'] = 'NaN'
Nyt_WV['article'] = 'NaN'
Nyt_WV['Incident Name'] = 'Morgantown'
Nyt_WV.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WV.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WV
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Douglasville
url=['No Articles']
Nyt_DGA =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DGA= Nyt_DGA.append([[a.title, a.text]], ignore_index=True)
Nyt_DGA.columns=['Title','Article']
Nyt_DGA['title'] = 'NaN'
Nyt_DGA['article'] = 'NaN'
Nyt_DGA['Incident Name'] = 'Douglasville'
Nyt_DGA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DGA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DGA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#McAvan's Pub
url=['No Articles']
Nyt_Mpub =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Mpub= Nyt_Mpub.append([[a.title, a.text]], ignore_index=True)
Nyt_Mpub.columns=['Title','Article']
Nyt_Mpub['title'] = 'NaN'
Nyt_Mpub['article'] = 'NaN'
Nyt_Mpub['Incident Name'] = 'McAvans Pub'
Nyt_Mpub.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Mpub.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Mpub
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Clarkesville
url=['No Articles']
Nyt_CGA =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CGA= Nyt_CGA.append([[a.title, a.text]], ignore_index=True)
Nyt_CGA.columns=['Title','Article']
Nyt_CGA['title'] = 'NaN'
Nyt_CGA['article'] = 'NaN'
Nyt_CGA['Incident Name'] = 'Clarkesville'
Nyt_CGA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CGA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CGA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Killeen, TX
url=['No Articles']
Nyt_KTX =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_KTX= Nyt_KTX.append([[a.title, a.text]], ignore_index=True)
Nyt_KTX.columns=['Title','Article']
Nyt_KTX['title'] = 'NaN'
Nyt_KTX['article'] = 'NaN'
Nyt_KTX['Incident Name'] = 'Killeen'
Nyt_KTX.drop(['Title','Article'], axis=1, inplace=True)
Nyt_KTX.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_KTX
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Charlotte, TX
url=['No Articles']
Nyt_CH =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CH= Nyt_CH.append([[a.title, a.text]], ignore_index=True)
Nyt_CH.columns=['Title','Article']
Nyt_CH['title'] = 'NaN'
Nyt_CH['article'] = 'NaN'
Nyt_CH['Incident Name'] = 'Charlotte'
Nyt_CH.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CH.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CH
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Birmingham's Washington Park
url=['No Articles']
Nyt_BWP =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BWP= Nyt_BWP.append([[a.title, a.text]], ignore_index=True)
Nyt_BWP.columns=['Title','Article']
Nyt_BWP['title'] = 'NaN'
Nyt_BWP['article'] = 'NaN'
Nyt_BWP['Incident Name'] = 'Birminghams Washington Park'
Nyt_BWP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_BWP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_BWP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tarboro
url=['No Articles']
Nyt_Tar =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Tar= Nyt_Tar.append([[a.title, a.text]], ignore_index=True)
Nyt_Tar.columns=['Title','Article']
Nyt_Tar['title'] = 'NaN'
Nyt_Tar['article'] = 'NaN'
Nyt_Tar['Incident Name'] = 'Tarboro'
Nyt_Tar.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Tar.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Tar
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Brookhaven
url=['No Articles']
Nyt_Brook =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Brook= Nyt_Brook.append([[a.title, a.text]], ignore_index=True)
Nyt_Brook.columns=['Title','Article']
Nyt_Brook['title'] = 'NaN'
Nyt_Brook['article'] = 'NaN'
Nyt_Brook['Incident Name'] = 'Brookhaven'
Nyt_Brook.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Brook.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Brook
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#CottonWood
url=['No Articles']
Nyt_Cot =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Cot= Nyt_Cot.append([[a.title, a.text]], ignore_index=True)
Nyt_Cot.columns=['Title','Article']
Nyt_Cot['title'] = 'NaN'
Nyt_Cot['article'] = 'NaN'
Nyt_Cot['Incident Name'] = 'Cottonwood'
Nyt_Cot.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Cot.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Cot
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Mesa
url379='https://www.nytimes.com/2015/03/19/us/gunman-mesa-arizona.html'
urls=[url379]
Nyt_Mesa =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Mesa= Nyt_Mesa.append([[a.title, a.text]], ignore_index=True)
Nyt_Mesa.columns=['Title','Article']
Nyt_Mesa['Incident Name'] = 'Mesa'
Nyt_Mesa
# Out:
#                                                Title  \
# 0  Suspect Is Captured After Rampage in Mesa, Ari...
#
#                                              Article Incident Name
# 0  He was a difficult inmate who was punished 11 ...          Mesa

# %%
#Little Water
url=['No Articles']
Nyt_LW =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LW= Nyt_LW.append([[a.title, a.text]], ignore_index=True)
Nyt_LW.columns=['Title','Article']
Nyt_LW['title'] = 'NaN'
Nyt_LW['article'] = 'NaN'
Nyt_LW['Incident Name'] = 'Little Water'
Nyt_LW.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LW.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LW
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Panama City Beach
url380='https://www.nytimes.com/2015/03/30/us/panama-city-beach-increases-spring-break-patrols.html'
url381='https://www.nytimes.com/2015/03/29/us/7-wounded-in-spring-break-shooting-in-florida.html'
urls=[url380,url381]
Nyt_PCB =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PCB= Nyt_PCB.append([[a.title, a.text]], ignore_index=True)
Nyt_PCB.columns=['Title','Article']
Nyt_PCB['Incident Name'] = 'Panama City Beach'
Nyt_PCB
# Out:
#                                               Title  \
# 0  Panama City Beach Increases Spring Break Patrols
# 1     7 Wounded in Spring Break Shooting in Florida
#
#                                              Article      Incident Name
# 0  PANAMA CITY BEACH, Fla. — A weekend house part...  Panama City Beach
# 1  Spring break turned bloody when seven people i...  Panama City Beach

# %%
#Tulsa
url=['No Articles']
Nyt_Tulsa =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Tulsa= Nyt_Tulsa.append([[a.title, a.text]], ignore_index=True)
Nyt_Tulsa.columns=['Title','Article']
Nyt_Tulsa['title'] = 'NaN'
Nyt_Tulsa['article'] = 'NaN'
Nyt_Tulsa['Incident Name'] = 'Tulsa'
Nyt_Tulsa.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Tulsa.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Tulsa
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Daytona Beach
url=['No Articles']
Nyt_DB =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DB= Nyt_DB.append([[a.title, a.text]], ignore_index=True)
Nyt_DB.columns=['Title','Article']
Nyt_DB['title'] = 'NaN'
Nyt_DB['article'] = 'NaN'
Nyt_DB['Incident Name'] = 'Daytona Beach'
Nyt_DB.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DB.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DB
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Indianapolis
url=['No Articles']
Nyt_IND =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_IND= Nyt_IND.append([[a.title, a.text]], ignore_index=True)
Nyt_IND.columns=['Title','Article']
Nyt_IND['title'] = 'NaN'
Nyt_IND['article'] = 'NaN'
Nyt_IND['Incident Name'] = 'Indianapolis'
Nyt_IND.drop(['Title','Article'], axis=1, inplace=True)
Nyt_IND.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_IND
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Rome
url=['No Articles']
Nyt_RO =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RO= Nyt_RO.append([[a.title, a.text]], ignore_index=True)
Nyt_RO.columns=['Title','Article']
Nyt_RO['title'] = 'NaN'
Nyt_RO['article'] = 'NaN'
Nyt_RO['Incident Name'] = 'Rome'
Nyt_RO.drop(['Title','Article'], axis=1, inplace=True)
Nyt_RO.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_RO
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Phoenix
url=['No Articles']
Nyt_PHO =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PHO= Nyt_PHO.append([[a.title, a.text]], ignore_index=True)
Nyt_PHO.columns=['Title','Article']
Nyt_PHO['title'] = 'NaN'
Nyt_PHO['article'] = 'NaN'
Nyt_PHO['Incident Name'] = 'Phoenix'
Nyt_PHO.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PHO.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PHO
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Killeen
url=['No Articles']
Nyt_Kil =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Kil= Nyt_Kil.append([[a.title, a.text]], ignore_index=True)
Nyt_Kil.columns=['Title','Article']
Nyt_Kil['title'] = 'NaN'
Nyt_Kil['article'] = 'NaN'
Nyt_Kil['Incident Name'] = 'Killeen'
Nyt_Kil.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Kil.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Kil
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Gates Pub
url=['No Articles']
Nyt_GP =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GP= Nyt_GP.append([[a.title, a.text]], ignore_index=True)
Nyt_GP.columns=['Title','Article']
Nyt_GP['title'] = 'NaN'
Nyt_GP['article'] = 'NaN'
Nyt_GP['Incident Name'] = 'Gates Pub'
Nyt_GP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_GP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_GP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Milwaukee
url=['No Articles']
Nyt_Mil =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Mil= Nyt_Mil.append([[a.title, a.text]], ignore_index=True)
Nyt_Mil.columns=['Title','Article']
Nyt_Mil['title'] = 'NaN'
Nyt_Mil['article'] = 'NaN'
Nyt_Mil['Incident Name'] = 'Milwaukee'
Nyt_Mil.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Mil.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Mil
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Fox Cities Trestle Trail bridge over Little Lake Butte des Morts
url=['No Articles']
Nyt_FCTT =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FCTT= Nyt_FCTT.append([[a.title, a.text]], ignore_index=True)
Nyt_FCTT.columns=['Title','Article']
Nyt_FCTT['title'] = 'NaN'
Nyt_FCTT['article'] = 'NaN'
Nyt_FCTT['Incident Name'] = 'Fox Cities Trestle Trail bridge over Little Lake Butte des Morts'
Nyt_FCTT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FCTT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FCTT
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tucson
url=['No Articles']
Nyt_Tuc =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Tuc= Nyt_Tuc.append([[a.title, a.text]], ignore_index=True)
Nyt_Tuc.columns=['Title','Article']
Nyt_Tuc['title'] = 'NaN'
Nyt_Tuc['article'] = 'NaN'
Nyt_Tuc['Incident Name'] = 'Tucson'
Nyt_Tuc.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Tuc.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Tuc
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Club Maxey's
url=['No Articles']
Nyt_CM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CM= Nyt_CM.append([[a.title, a.text]], ignore_index=True)
Nyt_CM.columns=['Title','Article']
Nyt_CM['title'] = 'NaN'
Nyt_CM['article'] = 'NaN'
Nyt_CM['Incident Name'] = 'Club Maxeys'
Nyt_CM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Cleveland
url=['No Articles']
Nyt_Cle =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Cle= Nyt_Cle.append([[a.title, a.text]], ignore_index=True)
Nyt_Cle.columns=['Title','Article']
Nyt_Cle['title'] = 'NaN'
Nyt_Cle['article'] = 'NaN'
Nyt_Cle['Incident Name'] = 'Cleveland'
Nyt_Cle.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Cle.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Cle
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Conyers
url=['No Articles']
Nyt_Con =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Con= Nyt_Con.append([[a.title, a.text]], ignore_index=True)
Nyt_Con.columns=['Title','Article']
Nyt_Con['title'] = 'NaN'
Nyt_Con['article'] = 'NaN'
Nyt_Con['Incident Name'] = 'Conyers'
Nyt_Con.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Con.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Con
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Deer Lodge
url=['No Articles']
Nyt_DL =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DL= Nyt_DL.append([[a.title, a.text]], ignore_index=True)
Nyt_DL.columns=['Title','Article']
Nyt_DL['title'] = 'NaN'
Nyt_DL['article'] = 'NaN'
Nyt_DL['Incident Name'] = 'Deer Lodge'
Nyt_DL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Mother Emanuel AME Church
url382='https://www.nytimes.com/2015/06/18/us/church-attacked-in-charleston-south-carolina.html'
url383='https://www.nytimes.com/2015/06/18/magazine/before-charlestons-church-shooting-a-long-history-of-attacks.html'
url384='https://www.nytimes.com/2015/06/18/us/the-charleston-shooting-what-happened.html'
url385='https://www.nytimes.com/2015/06/19/us/charleston-church-shooting.html'
url386='https://parenting.blogs.nytimes.com/2015/06/18/with-charleston-shooting-a-time-to-stop-teaching-children-about-the-history-of-racial-violence/'
url387='https://www.nytimes.com/2015/06/19/us/on-facebook-dylann-roof-charleston-suspect-wears-symbols-of-white-supremacy.html'
url388='https://www.nytimes.com/2015/06/19/us/politics/obama-charleston-shooting.html'
url389='https://takingnote.blogs.nytimes.com/2015/06/18/the-murders-at-mother-emanuel-church-in-charleston/'
url390='https://www.nytimes.com/2015/06/19/us/charleston-killings-evoke-history-of-violence-against-black-churches.html'
url391='https://www.nytimes.com/2015/06/19/opinion/killings-at-a-black-church-in-charleston.html'
url392='https://www.nytimes.com/2015/06/19/opinion/no-sanctuary-in-charleston.html'
url393='https://www.nytimes.com/2015/06/19/us/nine-victims-of-charleston-church-shooting-remembered.html'
url394='https://www.nytimes.com/2015/06/19/us/charleston-shooting-terrorism-or-hate-crime.html'
url395='https://www.nytimes.com/2015/06/19/opinion/henry-louis-gates-if-clementa-pinckney-had-lived.html'
url396='https://www.nytimes.com/2015/06/19/us/watch-victims-families-address-dylann-roof-charleston-shooting-suspect.html'
url397='https://www.nytimes.com/2015/06/19/magazine/white-terrorism-is-as-old-as-america.html'
url398='https://learning.blogs.nytimes.com/2015/06/19/6-qs-about-the-news-charleston-church-shooting-suspect-dylann-storm-roof-is-captured/'
url399='https://www.nytimes.com/2015/06/20/us/charleston-shooting-dylann-storm-roof.html'
url400='https://www.nytimes.com/2015/06/20/us/jon-stewart-addresses-charleston-shooting-in-his-daily-show-monologue.html'
url401='https://www.nytimes.com/2015/06/20/us/charleston-shooting-reignites-debate-about-confederate-flag.html'
url402='https://www.nytimes.com/politics/first-draft/2015/06/19/chris-christie-suggests-that-changing-gun-laws-wont-stop-violence/'
url403='https://www.nytimes.com/times-insider/2015/06/19/breaking-news-the-rush-to-cover-a-shooting-in-charleston/'
url404='https://www.nytimes.com/2015/06/20/us/gun-control-voices-in-congress-all-but-silent-after-charleston-shooting.html'
url405='https://www.nytimes.com/politics/first-draft/2015/06/19/bloombergs-gun-control-group-starts-news-site-after-shooting/'
url406='https://www.nytimes.com/2015/06/20/opinion/the-nation-needs-more-than-mourning-after-charleston.html'
url407='https://www.nytimes.com/2015/06/20/us/steeped-in-racial-history-charleston-reflects-on-its-relationship-with-blacks.html'
url408='https://www.nytimes.com/politics/first-draft/2015/06/19/n-r-a-board-member-deletes-criticism-of-victim-in-church-massacre/'
url409='https://www.nytimes.com/2015/06/20/us/politics/returning-home-to-console-lindsey-graham-joins-the-mourning.html'
url410='https://www.nytimes.com/2015/06/20/us/outrage-vs-tradition-wrapped-in-a-confederate-flag.html'
url411='https://www.nytimes.com/2015/06/20/us/in-charleston-black-church-is-target-again-for-deadly-strike-at-the-heart.html'
url412='https://www.nytimes.com/2015/06/21/arts/radio-djs-offer-comfort-and-community-after-charleston-church-killings.html'
url413='https://www.nytimes.com/2015/06/20/opinion/shock-grief-and-questions-after-killings-in-charleston-church.html'
url414='https://www.nytimes.com/2015/06/21/us/dylann-storm-roof-photos-website-charleston-church-shooting.html'
url415='https://www.nytimes.com/2015/06/21/us/a-day-at-the-statehouse-and-a-night-of-slaughter.html'
url416='https://www.nytimes.com/2015/06/21/opinion/michael-eric-dyson-love-and-terror-in-the-black-church.html'
url417='https://www.nytimes.com/2015/06/21/opinion/sunday/what-is-whiteness.html'
url418='https://www.nytimes.com/2015/06/21/us/politics/hillary-clinton-calls-americas-struggle-with-racism-far-from-over.html'
url419='https://www.nytimes.com/2015/06/21/us/from-ferguson-to-charleston-and-beyond-anguish-about-race-keeps-building.html'
url420='https://www.nytimes.com/2015/06/21/us/after-killings-a-southern-tourist-destination-charleston-remains-calm-and-open.html'
url421='https://www.nytimes.com/2015/06/22/us/ame-church-in-charleston-reopens-as-congregation-mourns-shooting-victims.html'
url422='https://www.nytimes.com/2015/06/22/us/politics/republicans-tread-carefully-in-criticism-of-confederate-flag.html'
url423='https://www.nytimes.com/2015/06/22/nyregion/a-show-of-solidarity-in-harlem-churches-after-charleston-killings.html'
url424='https://www.nytimes.com/2015/06/22/opinion/charles-blow-in-charleston-a-millennial-race-terrorist.html'
url425='https://www.nytimes.com/2015/06/22/magazine/the-condition-of-black-life-is-one-of-mourning.html'
url426='https://www.nytimes.com/2015/06/22/opinion/white-supremacists-without-borders.html'
url427='https://www.nytimes.com/2015/06/22/us/campaign-donations-linked-to-white-supremacist.html'
url428='https://www.nytimes.com/2015/06/23/us/politics/obama-lowers-his-guard-in-unusual-displays-of-emotion.html'
url429='https://www.nytimes.com/politics/first-draft/2015/06/22/today-in-politics-republicans-face-unsteady-path-after-charleston-shooting/'
url430='https://www.nytimes.com/2015/06/23/us/obama-racism-marc-maron-podcast.html'
url431='https://www.nytimes.com/2015/06/23/us/south-carolina-confederate-flag-dylann-roof.html'
url432='https://www.nytimes.com/2015/06/23/us/obama-and-biden-to-attend-funeral-for-clementa-pinckney.html'
url433='https://www.nytimes.com/2015/06/23/opinion/take-down-the-confederate-battle-flag-symbol-of-hatred.html'
url434='https://www.nytimes.com/2015/06/23/us/politics/views-on-race-and-gop-ties-define-group-council-of-conservative-citizens.html'
url435='https://www.nytimes.com/2015/06/23/us/southern-newspaper-front-pages-reflect-shifting-politics-around-a-confederate-flag.html'
url436='https://www.nytimes.com/2015/06/23/opinion/race-guns-a-flag-and-charleston.html'
url437='https://www.nytimes.com/2015/06/24/us/south-carolina-nikki-haley-confederate-flag.html'
url438='https://learning.blogs.nytimes.com/2015/06/23/charlestonsyllabus-a-reading-list-to-contextualize-the-massacre/'
url439='https://www.nytimes.com/2015/06/24/business/amazon-big-retailers-remove-confederate-flag-merchandise.html'
url440='https://www.nytimes.com/2015/06/24/us/charleston-residents-seek-lasting-change-from-moment-of-unity.html'
url441='https://www.nytimes.com/2015/06/24/opinion/why-i-cant-forgive-dylann-roof.html'
url442='https://www.nytimes.com/politics/first-draft/2015/06/23/ben-carson-assails-foes-for-playing-down-race-in-charleston-shooting/'
url443='https://www.nytimes.com/2015/06/24/us/politics/hillary-clinton-says-confederate-flag-shouldnt-fly-anywhere.html'
url444='https://www.nytimes.com/2015/06/24/us/politics/south-carolina-governor-nikki-r-haley-points-to-personal-reasons-not-politics-for-shift-on-confederate-flag.html'
url445='https://www.nytimes.com/2015/06/24/opinion/beyond-the-flag-calling-for-governor-haley-to-do-more.html'
url446='https://www.nytimes.com/2015/06/24/us/politics/supporters-of-confederate-battle-flag-watch-as-symbol-is-stripped-from-public-eye.html'
url447='https://www.nytimes.com/2015/06/24/magazine/racisms-psychological-toll.html'

# %%
#Mother Emanuel AME Church
urls=[url382,url383,url384,url385,url386,url387,url388,url389,url390,url391,url392,url393,url394,url395,url396,url397,
     url398,url399,url400,url401,url402,url403,url404,url405,url406,url407,url408,url409,url410,url411,url412,url413,
     url414,url415,url416,url417,url418,url419,url420,url421,url422,url423,url424,url425,url426,url427,url428,url429,
     url430,url431,url432,url433,url434,url435,url436,url436,url437,url438,url439,url440,url441,url442,url443,url444,
     url445,url446,url447]
Nyt_MEAMEC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MEAMEC= Nyt_MEAMEC.append([[a.title, a.text]], ignore_index=True)
Nyt_MEAMEC.columns=['Title','Article']
Nyt_MEAMEC['Incident Name'] = 'Mother Emanuel AME Church'
Nyt_MEAMEC
# Out:
#                                                 Title  \
# 0   Nine Killed in Shooting at Black Church in Cha...
# 1   Before Charleston’s Church Shooting, a Long Hi...
# 2              The Charleston Shooting: What Happened
# 3   Church Massacre Suspect Held as Charleston Gri...
# 4   With Charleston Shooting, a Time to Stop Teach...
# 5   Dylann Roof, Suspect in Charleston Shooting, F...
# 6   After Charleston Shooting, a Sense at the Whit...
# 7   The Murders at Mother Emanuel Church in Charle...
# 8   Killings Add Painful Page to Storied History o...
# 9            Killings at a Black Church in Charleston
# 10                         No Sanctuary in Charleston
# 11  Recalling Nine Spiritual Mentors, Gunned Down ...
# 12  Many Ask, Why Not Call Church Shooting Terrorism?
# 13  Henry Louis Gates: If Clementa Pinckney Had Lived
# 14  Watch: Victims’ Families Address Dylann Roof, ...
# 15               White Terrorism Is as Old as America
# ...

# %%
#Boom Boom Room
url=['No Articles']
Nyt_BBM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BBM= Nyt_BBM.append([[a.title, a.text]], ignore_index=True)
Nyt_BBM.columns=['Title','Article']
Nyt_BBM['title'] = 'NaN'
Nyt_BBM['article'] = 'NaN'
Nyt_BBM['Incident Name'] = 'Boom Boom Room'
Nyt_BBM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_BBM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_BBM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Annual motorcycle event in Newark
url=['No Articles']
Nyt_AMNJ =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AMNJ= Nyt_AMNJ.append([[a.title, a.text]], ignore_index=True)
Nyt_AMNJ.columns=['Title','Article']
Nyt_AMNJ['title'] = 'NaN'
Nyt_AMNJ['article'] = 'NaN'
Nyt_AMNJ['Incident Name'] = 'Annual motorcycle event in Newark'
Nyt_AMNJ.drop(['Title','Article'], axis=1, inplace=True)
Nyt_AMNJ.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_AMNJ
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Miami Gardens
url=['No Articles']
Nyt_MG =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MG= Nyt_MG.append([[a.title, a.text]], ignore_index=True)
Nyt_MG.columns=['Title','Article']
Nyt_MG['title'] = 'NaN'
Nyt_MG['article'] = 'NaN'
Nyt_MG['Incident Name'] = 'Miami Gardens'
Nyt_MG.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MG.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MG
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#River Forest
url=['No Articles']
Nyt_RF =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RF= Nyt_RF.append([[a.title, a.text]], ignore_index=True)
Nyt_RF.columns=['Title','Article']
Nyt_RF['title'] = 'NaN'
Nyt_RF['article'] = 'NaN'
Nyt_RF['Incident Name'] = 'River Forest'
Nyt_RF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_RF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_RF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
url448='https://www.nytimes.com/2015/07/17/us/chattanooga-tennessee-shooting.html'
url449='https://www.nytimes.com/2015/07/17/us/chattanooga-shooting-suspect-was-ordinary-boy-neighbors-recall.html'
url450='https://www.nytimes.com/2015/07/17/us/chattanooga-mosque-where-gunman-worshiped-mourns-marines.html'
url451='https://www.nytimes.com/2015/07/18/us/chattanooga-gunmans-past-scoured-for-extremist-ties.html'
url452='https://takingnote.blogs.nytimes.com/2015/07/17/republican-doublethink-on-mass-shootings-scott-walker-edition/'
url453='https://www.nytimes.com/2015/07/18/us/marines-killed-in-chattanooga-are-mourned-by-friends.html'
url454='https://www.nytimes.com/2015/07/18/us/what-is-known-about-the-chattanooga-gunman.html'
url455='https://www.nytimes.com/2015/07/18/us/after-chattanooga-killings-military-recruiters-carry-on.html'
url456='https://www.nytimes.com/2015/07/18/us/at-chattanooga-mosque-grief-mixes-with-fear-of-revenge.html'
url457='https://www.nytimes.com/times-insider/2015/07/18/after-chattanooga-shooting-readers-debate-where-to-place-blame/'
url458='https://www.nytimes.com/2015/07/19/us/family-troubles-before-killings-in-chattanooga.html'
url459='https://www.nytimes.com/2015/07/19/us/chattanooga-attacks-claim-a-5th-military-service-members-life.html'
url460='https://www.nytimes.com/2015/07/20/us/chattanooga-wears-pride-beside-its-pain-after-killings.html'
url461='https://www.nytimes.com/2015/07/21/us/chattanooga-gunman-wrote-of-suicide-and-martyrdom-official-says.html'
url462='https://www.nytimes.com/2015/07/21/us/military-orders-recruiting-centers-to-increase-security.html'
url463='https://www.nytimes.com/2015/07/22/us/chattanooga-gunman-mohammod-abdulazeez.html'
url464='https://www.nytimes.com/2015/07/22/us/obama-orders-flags-lowered-for-chattanooga-victims.html'
url465='https://www.nytimes.com/2015/07/23/us/chattanooga-tennessee-shooting-investigation-mohammod-abdulazeez.html'
url466='https://www.nytimes.com/2015/07/23/us/armed-and-determined-civilians-look-to-prevent-another-chattanooga.html'
url467='https://www.nytimes.com/2015/07/23/opinion/can-mass-shootings-be-predicted.html'

# %%
#Amnicola Training Center, Chattanooga
urls=[url448,url449,url450,url451,url452,url453,url454,url455,url456,url457,url458,url459,url460,url461,url462,
     url463,url464,url465,url466,url467]
Nyt_CATC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CATC= Nyt_CATC.append([[a.title, a.text]], ignore_index=True)
Nyt_CATC.columns=['Title','Article']
Nyt_CATC['Incident Name'] = 'Amnicola Training Center, Chattanooga'
Nyt_CATC
# Out:
#                                                 Title  \
# 0   Gunman Kills 4 Marines at Military Site in Cha...
# 1   Chattanooga Gunman Mohammod Youssuf Abdulazeez...
# 2   Chattanooga Mosque Where Gunman Worshiped Mour...
# 3   Inquiry Focusing on Chattanooga Gunman’s Trip ...
# 4   Republican Doublethink on Mass Shootings: Scot...
# 5   As Chattanooga Death Toll Rises, Mourning Deat...
# 6          What Is Known About the Chattanooga Gunman
# 7   Military Recruiting Centers Keep Their Doors O...
# 8       At a Mosque, Grief Mixes With Fear of Revenge
# 9   After Chattanooga Shooting, Readers Debate Whe...
# 10     Family Troubles Before Killings in Chattanooga
# 11  Federal Inquiry Scrutinizes Chattanooga Gunman...
# 12  Chattanooga Wears Pride Beside Its Pain After ...
# 13   In Chattanooga, a Young Man in a Downward Spiral
# 14  Military Has Security Tightened for Recruiters...
# 15  Chattanooga Gunman Researched Islamic Martyrdo...
# ...

# %%
#Suwanee
url=['No Articles']
Nyt_Suw =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Suw= Nyt_Suw.append([[a.title, a.text]], ignore_index=True)
Nyt_Suw.columns=['Title','Article']
Nyt_Suw['title'] = 'NaN'
Nyt_Suw['article'] = 'NaN'
Nyt_Suw['Incident Name'] = 'Suwanee'
Nyt_Suw.drop(['Title','Article'], axis=1, inplace=True)
Nyt_Suw.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_Suw
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Grand 16 Theatre, Louisiana
url468='https://www.nytimes.com/2015/07/24/us/shooting-at-lafayette-la-movie-theater.html'
url469='https://www.nytimes.com/2015/07/25/us/lafayette-theater-shooting-john-houser.html'
url470='https://www.nytimes.com/2015/07/25/us/witnesses-describe-chaos-as-lafayette-la-shooting-unfolded.html'
url471='https://www.nytimes.com/2015/07/25/us/politics/presidential-candidates-denounce-violence-but-avoid-talk-of-policy.html'
url472='https://www.nytimes.com/2015/07/25/us/lost-in-lafayette-gunfire-two-with-bright-futures.html'
url473='https://www.nytimes.com/2015/07/27/us/politics/bobby-jindal-calls-for-states-to-follow-louisianas-example-in-toughening-gun-laws.html'
url474='https://www.nytimes.com/2015/07/28/us/an-outpouring-of-support-as-two-towns-mourn-lafayette-shooting-victims.html'
urls=[url468,url469,url470,url471,url472,url473,url474]
Nyt_16LA =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_16LA= Nyt_16LA.append([[a.title, a.text]], ignore_index=True)
Nyt_16LA.columns=['Title','Article']
Nyt_16LA['Incident Name'] = 'Grand 16 Theatre, Louisiana'
Nyt_16LA
# Out:
#                                                Title  \
# 0  Gunman Kills 2 and Himself at Movie Theater in...
# 1  Lafayette Shooting Adds Another Angry Face in ...
# 2  Witnesses Describe Chaos as Lafayette, La., Sh...
# 3  Presidential Candidates Denounce Violence, but...
# 4  Lost in Lafayette Gunfire, Two With Bright Fut...
# 5  Bobby Jindal Calls for States to Follow Louisi...
# 6  An Outpouring of Support as Two Towns Mourn La...
#
#                                              Article  \
# 0  Not sure that he is from Louisiana, Chief Craf...
# 1  Given his history, he should not have been all...
# 2  Photo\n\nOn Thursday, a gunman opened fire in ...
# 3  The leading Republican presidential candidates...
# 4  LAFAYETTE, La. — It seems that everybody in La...
# 5  “I think every state should strengthen their l...
# 6  “This whole town is mourning. It’s unbelievabl...
#
#                  Incident Name
# 0  Grand 16 Theatre, Louisiana
# 1  Grand 16 Theatre, Louisiana
# ...

# %%
#Houston, Texas
url475='https://www.nytimes.com/2015/08/10/us/8-people-found-dead-inside-texas-home-after-arrest.html'
urls=[url475]
Nyt_HOTX =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HOTX= Nyt_HOTX.append([[a.title, a.text]], ignore_index=True)
Nyt_HOTX.columns=['Title','Article']
Nyt_HOTX['Incident Name'] = 'Houston, Texas'
Nyt_HOTX
# Out:
#                                                Title  \
# 0  Man Charged After 8 Members of Texas Family Ar...
#
#                                              Article   Incident Name
# 0  It was unclear how the deputies knew Mr. Conle...  Houston, Texas

# %%
#Parking lot near Boys and Girls Club
url476='https://www.nytimes.com/2015/08/21/nyregion/three-fatally-shot-in-drive-by-shooting-in-rochester.html'
urls=[url476]
Nyt_BGC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BGC= Nyt_BGC.append([[a.title, a.text]], ignore_index=True)
Nyt_BGC.columns=['Title','Article']
Nyt_BGC['Incident Name'] = 'Parking lot near Boys and Girls Club'
Nyt_BGC
# Out:
#                                         Title  \
# 0  3 Killed in Drive-By Shooting in Rochester
#
#                                              Article  \
# 0  Three people were shot and killed after a bask...
#
#                           Incident Name
# 0  Parking lot near Boys and Girls Club

# %%
#Virginia WDBJ live TV interview shooting
url477='https://www.nytimes.com/2015/08/27/us/wdbj7-virginia-journalists-shot-during-live-broadcast.html'
url478='https://www.nytimes.com/2015/08/27/technology/personaltech/violence-gone-viral-in-a-well-planned-rollout-on-social-media.html'
url479='https://www.nytimes.com/2015/08/27/us/documents-show-virginia-shooting-suspects-turbulent-tenure-at-tv-station.html'
url480='https://www.nytimes.com/2015/08/27/opinion/killings-of-journalists-brings-gun-violence-to-dark-new-level.html'
url481='https://www.nytimes.com/2015/08/27/us/viewers-of-virginia-tv-station-wake-up-to-watch-a-nightmare.html'
url482='https://www.nytimes.com/2015/08/28/us/virginia-tv-shooting-bryce-williams.html'
url483='https://www.nytimes.com/2015/08/27/opinion/when-the-tragedy-youre-covering-is-your-own.html'
url484='https://www.nytimes.com/2015/08/28/business/media/outrage-over-images-of-tv-shooting-on-newspaper-front-pages.html'
url485='https://www.nytimes.com/2015/08/28/us/virginia-shooting-spotlights-riddle-of-workplace-safety.html'
url486='https://www.nytimes.com/2015/08/28/us/virginia-killings-andy-parker-father-flash-point-politicians.html'
url487='https://www.nytimes.com/2015/08/28/us/vester-lee-flanagan-grievances-homicidal-explosion.html'
url488='https://www.nytimes.com/2015/08/29/us/wdbj-virginia-shooting-bryce-williams-victim-vicki-gardner.html'
urls=[url477,url478,url479,url480,url481,url482,url483,url484,url485,url486,url487,url488]
Nyt_WDBJ =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WDBJ= Nyt_WDBJ.append([[a.title, a.text]], ignore_index=True)
Nyt_WDBJ.columns=['Title','Article']
Nyt_WDBJ['Incident Name'] = 'Virginia WDBJ live TV interview shooting'
Nyt_WDBJ
# Out:
#                                                 Title  \
# 0   Ex-Broadcaster Kills 2 on Air in Virginia Shoo...
# 1   Virginia Shooting Gone Viral, in a Well-Planne...
# 2   Documents Show Vester Lee Flanagan’s Turbulent...
# 3   Killings of Journalists Bring Gun Violence to ...
# 4   Viewers of Virginia TV Station Wake Up to Watc...
# 5   After Virginia TV Shooting, Grief and Calls fo...
# 6        When the Tragedy You’re Covering Is Your Own
# 7   Outrage Over Images of TV Shooting on Newspape...
# 8   Virginia Shooting Spotlights Riddle of Workpla...
# 9   Virginia Killings Produce Vow From Alison Park...
# 10  A Life of Listing Grievances, and Then Virgini...
# 11  Virginia Shooting Victims Were Hit in Head, Au...
#
#                                               Article  \
# 0   Around 6:45 a.m., the shooting began.\n\nThe s...
# 1   Twitter and Facebook moved quickly to suspend ...
# 2   Photo\n\nIn March 2012, Vester Lee Flanagan II...
# ...

# %%
#Bristol, Tennessee
url=['No Articles']
Nyt_BTN =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BTN= Nyt_BTN.append([[a.title, a.text]], ignore_index=True)
Nyt_BTN.columns=['Title','Article']
Nyt_BTN['title'] = 'NaN'
Nyt_BTN['article'] = 'NaN'
Nyt_BTN['Incident Name'] = 'Bristol, Tennessee'
Nyt_BTN.drop(['Title','Article'], axis=1, inplace=True)
Nyt_BTN.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_BTN
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Clearbrook (Greenwood), Minnesota
url489='https://www.nytimes.com/2015/09/12/us/minnesota-murder-suicide-was-result-of-shootings.html'
url490='https://www.nytimes.com/2015/09/11/us/minnesota-five-in-family-found-dead-in-home.html'
url491='https://www.nytimes.com/2015/09/12/us/after-death-of-family-of-five-in-minnesota-a-search-for-answers.html'
urls=[url489,url490,url491]
Nyt_CMN =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CMN= Nyt_CMN.append([[a.title, a.text]], ignore_index=True)
Nyt_CMN.columns=['Title','Article']
Nyt_CMN
# Out:
#                                                Title  \
# 0  Minnesota: Murder-Suicide Was Result of Shootings
# 1       Minnesota: Five in Family Found Dead in Home
# 2  After Death of Family of Five in Minnesota, a ...
#
#                                              Article
# 0  Five family members who were killed in what th...
# 1  Five family members, including three children,...
# 2  Photo\n\nFive members of a family who were fou...

# %%
#Platte, South Dakota
url=['No Articles']
Nyt_PSD =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PSD= Nyt_PSD.append([[a.title, a.text]], ignore_index=True)
Nyt_PSD.columns=['Title','Article']
Nyt_PSD['title'] = 'NaN'
Nyt_PSD['article'] = 'NaN'
Nyt_PSD['Incident Name'] = 'Bristol, Tennessee'
Nyt_PSD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PSD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PSD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Umpqua CC Urls
url492='https://www.nytimes.com/2015/10/02/us/oregon-shooting-umpqua-community-college.html'
url493='https://www.nytimes.com/2015/10/02/us/obama-oregon-shooting-umpqua-community-college-gun-control.html'
url494='https://www.nytimes.com/2015/10/03/us/chris-harper-mercer-umpqua-community-college-shooting.html'
url495='https://www.nytimes.com/2015/10/03/us/oregon-shooting-umpqua-chris-harper-mercer.html'
url496='https://www.nytimes.com/2015/10/03/opinion/calls-for-gun-control-after-oregon-college-shooting.html'
url497='https://www.nytimes.com/2015/10/03/opinion/the-political-ritual-after-mass-shootings.html'
url498='https://www.nytimes.com/politics/first-draft/2015/10/02/nancy-pelosi-calls-for-a-new-house-committee-to-address-gun-violence/'
url499='https://www.nytimes.com/2015/10/03/us/oregon-sheriff-shared-sandy-hook-conspiracy-theory-on-facebook.html'
url500='https://www.nytimes.com/2015/10/03/us/oregon-shooting-victims-umpqua-community-college-students.html'
url501='https://www.nytimes.com/2015/10/03/nyregion/cuomo-criticizes-political-response-to-mass-shootings-renews-call-for-tougher-gun-laws.html'
url502='https://www.nytimes.com/2015/10/04/us/confusion-horror-and-heroism-in-oregon-shooting.html'
url503='https://www.nytimes.com/2015/10/04/us/mass-murderers-fit-profile-as-do-many-others-who-dont-kill.html'
url504='https://www.nytimes.com/2015/10/04/us/death-of-gunman-in-oregon-college-shootings-is-ruled-suicide.html'
url505='https://www.nytimes.com/politics/first-draft/2015/10/04/donald-trump-says-shootings-will-happen-no-matter-what/'
url506='https://www.nytimes.com/2015/10/05/us/in-close-knit-oregon-community-few-are-untouched-by-college-killings.html'
url507='https://www.nytimes.com/2015/10/06/us/politics/bernie-sanders-hillary-clinton-gun-control.html'
url508='https://www.nytimes.com/2015/10/06/us/mother-of-oregon-gunman-wrote-of-keeping-firearms.html'
url509='https://www.nytimes.com/2015/10/06/us/mother-of-oregon-gunman-wrote-of-keeping-firearms.html'
url510='https://www.nytimes.com/2015/10/06/us/obama-to-meet-families-of-oregon-shooting-victims.html'
url511='https://www.nytimes.com/2015/10/07/us/campus-security-teams-try-to-learn-from-each-new-attack.html'
url512='https://www.nytimes.com/2015/10/08/us/oregon-roseburg-shooting-umpqua-community-college.html'
url513='https://takingnote.blogs.nytimes.com/2015/10/07/the-wrong-way-to-talk-about-guns/'

# %%
#Umpqua Community College
urls=[url492,url493,url494,url495,url496,url497,url498,url499,url500,url501,url502,url503,url504,url505,url506,
     url507,url508,url509,url510,url511,url512,url513]
Nyt_UCC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_UCC= Nyt_UCC.append([[a.title, a.text]], ignore_index=True)
Nyt_UCC.columns=['Title','Article']
Nyt_UCC['Incident Name'] = 'Umpqua Community College'
Nyt_UCC
# Out:
#                                                 Title  \
# 0   Oregon Shooting at Umpqua College Kills 10, Sh...
# 1   Obama Condemns ‘Routine’ of Mass Shootings, Sa...
# 2   Oregon Killer Described as Man of Few Words, E...
# 3   In Note Left Behind, Gunman ‘Did Not Like His ...
# 4   Calls for Gun Control After Oregon College Sho...
# 5           The Political Ritual After Mass Shootings
# 6   Nancy Pelosi Calls for a New House Committee t...
# 7   Oregon Sheriff Shared Sandy Hook Conspiracy Th...
# 8   A Snapshot of Students Lost: Young and Old, bu...
# 9   Cuomo, Citing Oregon Shooting, Criticizes Fail...
# 10   Confusion, Horror and Heroism in Oregon Shooting
# 11  Mass Murderers Fit Profile, as Do Many Others ...
# 12  Oregon Gunman’s Father Dismayed by Lack of Gun...
# 13  Donald Trump Says Shootings Will Happen 'No Ma...
# 14  In Close-Knit Oregon Community, Few Are Untouc...
# 15  Bernie Sanders, a Hunting-State Senator, Tread...
# ...

# %%
#Northern Arizona University at Flagstaff Campus
url514='https://www.nytimes.com/2015/10/10/us/northern-arizona-university-flagstaff-shooting.html'
url515='https://www.nytimes.com/2015/10/10/us/campus-shootings-texas-arizona.html'
urls=[url514,url515]
Nyt_NAU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NAU= Nyt_NAU.append([[a.title, a.text]], ignore_index=True)
Nyt_NAU.columns=['Title','Article']
Nyt_NAU['Incident Name'] = 'Northern Arizona University at Flagstaff Campus'
Nyt_NAU
# Out:
#                                                Title  \
# 0  Student Is Killed in Shooting at Northern Ariz...
# 1  Campus Shootings in Texas and Arizona Kill 2 S...
#
#                                              Article  \
# 0  Photo\n\nOne student was killed and three were...
# 1  A student, Colin Brough, was killed, and the t...
#
#                                      Incident Name
# 0  Northern Arizona University at Flagstaff Campus
# 1  Northern Arizona University at Flagstaff Campus

# %%
#King, North Carolina
url=['No Articles']
Nyt_KNC =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_KNC= Nyt_KNC.append([[a.title, a.text]], ignore_index=True)
Nyt_KNC.columns=['Title','Article']
Nyt_KNC['title'] = 'NaN'
Nyt_KNC['article'] = 'NaN'
Nyt_KNC['Incident Name'] = 'King, North Carolina'
Nyt_KNC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_KNC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_KNC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Hill Haven Event Center (Formerly Club CJ's)
url=['No Articles']
Nyt_HHEC =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HHEC= Nyt_HHEC.append([[a.title, a.text]], ignore_index=True)
Nyt_HHEC.columns=['Title','Article']
Nyt_HHEC['title'] = 'NaN'
Nyt_HHEC['article'] = 'NaN'
Nyt_HHEC['Incident Name'] = 'Hill Haven Event Center (Formerly Club CJs)'
Nyt_HHEC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_HHEC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_HHEC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Colerain Township, Ohio
url=['No Articles']
Nyt_CTO =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CTO= Nyt_CTO.append([[a.title, a.text]], ignore_index=True)
Nyt_CTO.columns=['Title','Article']
Nyt_CTO['title'] = 'NaN'
Nyt_CTO['article'] = 'NaN'
Nyt_CTO['Incident Name'] = 'Colerain Township, Ohio'
Nyt_CTO.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CTO.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CTO
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Colorado Springs
url516='https://www.nytimes.com/2015/11/01/us/four-dead-in-shootings-in-colorado-springs.html'
url517='https://www.nytimes.com/2015/11/02/us/police-investigating-colorado-springs-shooting-that-left-4-dead.html'
url518='https://www.nytimes.com/2015/11/03/us/colorado-suspect-killed-in-rampage-is-identified.html'
urls=[url516,url517,url518]
Nyt_CS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CS= Nyt_CS.append([[a.title, a.text]], ignore_index=True)
Nyt_CS.columns=['Title','Article']
Nyt_CS['Incident Name'] = 'Colorado Springs'
Nyt_CS
# Out:
#                                                Title  \
# 0         Four Dead in Shootings in Colorado Springs
# 1  Police Investigating Colorado Springs Shooting...
# 2  Colorado: Suspect Killed in Rampage Is Identified
#
#                                              Article     Incident Name
# 0  Photo\n\nA shooting rampage in Colorado Spring...  Colorado Springs
# 1  Photo\n\nLaw enforcement authorities in Colora...  Colorado Springs
# 2  Photo\n\nThe authorities in Colorado Springs h...  Colorado Springs

# %%
#Oakland, Maine
url=['No Articles']
Nyt_OM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_OM= Nyt_OM.append([[a.title, a.text]], ignore_index=True)
Nyt_OM.columns=['Title','Article']
Nyt_OM['title'] = 'NaN'
Nyt_OM['article'] = 'NaN'
Nyt_OM['Incident Name'] = 'Oakland, Maine'
Nyt_OM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_OM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_OM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Inglis, Florida
url=['No Articles']
Nyt_IF =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_IF= Nyt_IF.append([[a.title, a.text]], ignore_index=True)
Nyt_IF.columns=['Title','Article']
Nyt_IF['title'] = 'NaN'
Nyt_IF['article'] = 'NaN'
Nyt_IF['Incident Name'] = 'Inglis, Florida'
Nyt_IF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_IF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_IF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Waycross, GA
url=['No Articles']
Nyt_WG =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WG= Nyt_WG.append([[a.title, a.text]], ignore_index=True)
Nyt_WG.columns=['Title','Article']
Nyt_WG['title'] = 'NaN'
Nyt_WG['article'] = 'NaN'
Nyt_WG['Incident Name'] = 'Waycross, GA'
Nyt_WG.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WG.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WG
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Jacksonville, Florida
url=['No Articles']
Nyt_JF =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_JF= Nyt_JF.append([[a.title, a.text]], ignore_index=True)
Nyt_JF.columns=['Title','Article']
Nyt_JF['title'] = 'NaN'
Nyt_JF['article'] = 'NaN'
Nyt_JF['Incident Name'] = 'Jacksonville, Florida'
Nyt_JF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_JF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_JF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tennessee Colony, Texas
url519='https://www.nytimes.com/2015/11/17/us/texas-suspect-held-after-6-campers-are-found-dead.html'
urls=[url519]
Nyt_TCT =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TCT= Nyt_TCT.append([[a.title, a.text]], ignore_index=True)
Nyt_TCT.columns=['Title','Article']
Nyt_TCT['Incident Name'] = 'Tennessee Colony, Texas'
Nyt_TCT
# Out:
#                                                Title  \
# 0  Texas: Suspect Held After 6 Campers Are Found ...
#
#                                              Article            Incident Name
# 0  Six people were killed at a campsite and a sus...  Tennessee Colony, Texas

# %%
#Columbus, Ohio
url=['No Articles']
Nyt_CO =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CO= Nyt_CO.append([[a.title, a.text]], ignore_index=True)
Nyt_CO.columns=['Title','Article']
Nyt_CO['title'] = 'NaN'
Nyt_CO['article'] = 'NaN'
Nyt_CO['Incident Name'] = 'Columbus, Ohio'
Nyt_CO.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CO.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CO
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Minneapolis, Minnesota
url520='https://www.nytimes.com/2015/11/26/us/4-arrested-in-shooting-at-black-lives-matter-protest-are-identified.html'
urls=[url520]
Nyt_MMN =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MMN= Nyt_MMN.append([[a.title, a.text]], ignore_index=True)
Nyt_MMN.columns=['Title','Article']
Nyt_MMN['Incident Name'] = 'Minneapolis, Minnesota'
Nyt_MMN
# Out:
#                                                Title  \
# 0  4 Arrested in Shooting at Black Lives Matter P...
#
#                                              Article           Incident Name
# 0  The racial tension at the protests began to gr...  Minneapolis, Minnesota

# %%
#Colorado Springs, Colorado URLS
url521='https://www.nytimes.com/2015/11/28/us/garrett-swasey-officer-killed-in-colorado-is-recalled-for-courage-and-faith.html'
url522='https://www.nytimes.com/2015/11/29/us/colorado-springs-planned-parenthood-shooting.html'
url523='https://www.nytimes.com/2015/11/29/us/colorado-springs-planned-parenthood-obama-responds-to-gun-violence.html'
url524='https://www.nytimes.com/2015/11/29/us/siege-highlights-security-used-in-abortion-clinics.html'
url525='https://www.nytimes.com/2015/11/29/us/ex-wife-recalls-colorado-gunman-as-imperfect-but-a-good-man.html'
url526='https://www.nytimes.com/2015/11/29/us/robert-dear-suspect-in-colorado-killings-preferred-to-be-left-alone.html'
url527='https://www.nytimes.com/2015/11/30/us/colorado-shooting-planned-parenthood.html'
url528='https://www.nytimes.com/2015/11/30/us/victims-in-colorado-clinic-shooting-include-iraq-war-veteran.html'
url529='https://www.nytimes.com/2015/11/30/us/politics/shooting-at-planned-parenthood-adds-to-challenges-for-congress.html'
url530='https://www.nytimes.com/2015/11/30/magazine/planned-parenthood-and-the-tinderbox-of-abortion-rhetoric.html'
url531='https://www.nytimes.com/2015/12/01/us/politics/congress-budget-deadline-planned-parenthood.html'
url532='https://takingnote.blogs.nytimes.com/2015/11/30/after-attack-republicans-keep-hammering-planned-parenthood/'
url533='https://www.nytimes.com/2015/12/01/us/robert-dear-suspect-in-colorado-attack-appears-in-court.html'
url534='https://www.nytimes.com/2015/12/01/opinion/the-killings-at-a-planned-parenthood-clinic-in-colorado.html'
url535='https://www.nytimes.com/2015/12/02/nyregion/new-yorks-tactical-shift-on-terror-attacks-dont-wait-for-backup.html'
url536='https://www.nytimes.com/2015/12/02/us/robert-dear-planned-parenthood-shooting.html'
url537='https://www.nytimes.com/2015/12/02/us/obama-repeats-call-for-stricter-gun-laws-after-colorado-shooting.html'

# %%
#Colorado Springs, Colorado
urls=[url521,url522,url523,url524,url525,url526,url527,url528,url529,url530,url531,url532,url533,url534,url535,
     url536,url537]
Nyt_CSC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CSC= Nyt_CSC.append([[a.title, a.text]], ignore_index=True)
Nyt_CSC.columns=['Title','Article']
Nyt_CSC['Incident Name'] = 'Colorado Springs, Colorado'
Nyt_CSC
# Out:
#                                                 Title  \
# 0   Garrett Swasey, Officer Killed in Colorado, Is...
# 1   In Colorado, Bustling With Shoppers, Then Grip...
# 2   Obama Says ‘Enough Is Enough’ After Colorado S...
# 3   Siege Highlights Security Used in Abortion Cli...
# 4   Ex-Wife Says Robert Dear, Suspect in Colorado ...
# 5   Robert Dear, Suspect in Colorado Killings, ‘Pr...
# 6   Searching for Answers and Comfort After Killin...
# 7   Colorado Victims Identified as Iraq Veteran an...
# 8   Shooting at Planned Parenthood Adds to Challen...
# 9   Planned Parenthood and the Tinderbox of Aborti...
# 10         No Shutdown Expected on Planned Parenthood
# 11  After Attack, Republicans Keep Hammering Plann...
# 12  Suspect in Planned Parenthood Attack Hears Mur...
# 13  The Killings at a Planned Parenthood Clinic in...
# 14  Rushing to End Mass Shootings, Police Face Gre...
# 15  For Robert Dear, Religion and Rage Before Plan...
# ...

# %%
#San Bernadinho URLS
url538='https://www.nytimes.com/2015/12/03/us/san-bernardino-shooting.html'
url539='https://www.nytimes.com/politics/first-draft/2015/12/02/presidential-candidates-react-to-san-bernardino-shooting/'
url540='https://www.nytimes.com/2015/12/03/opinion/the-horror-in-san-bernardino.html'
url541='https://www.nytimes.com/2015/12/03/opinion/on-guns-were-not-even-trying.html'
url542='https://www.nytimes.com/2015/12/03/us/san-bernardino-is-traumatized-by-a-siege-and-a-loud-and-bloody-shooting.html'
url543='https://www.nytimes.com/2015/12/04/us/san-bernardino-shooting-syed-rizwan-farook.html'
url544='https://www.nytimes.com/2015/12/04/us/police-redlands-townhouse-san-bernardino-shooting.html'
url545='https://www.nytimes.com/2015/12/04/us/san-bernardino-shooting.html'
url546='https://www.nytimes.com/2015/12/04/us/politics/congress-shifts-attention-to-americas-role-in-the-world.html'
url547='https://www.nytimes.com/2015/12/04/us/terrorism-debate-san-bernardino-shooting.html'
url548='https://www.nytimes.com/2015/12/04/opinion/dont-make-san-bernardino-a-victory-for-isis.html'
url549='https://www.nytimes.com/politics/first-draft/2015/12/03/hillary-clinton-renews-call-for-tough-gun-measures-after-california-shooting/'
url550='https://parenting.blogs.nytimes.com/2015/12/03/raising-cynics-or-raising-hope-talking-with-older-children-about-mass-shootings/'
url551='https://www.nytimes.com/2015/12/04/us/weapons-in-san-bernardino-shootings-were-legally-obtained.html'
url552='https://www.nytimes.com/2015/12/04/opinion/how-many-mass-shootings-are-there-really.html'
url553='https://www.nytimes.com/2015/12/04/world/europe/us-media-mocked-abroad-for-reporting-false-name-of-california-shooting-suspect.html'
url554='https://www.nytimes.com/2015/12/04/nyregion/wanting-more-than-a-veto-and-a-prayer-after-mass-shootings.html'
url555='https://www.nytimes.com/2015/12/04/us/where-they-shared-their-working-hours-and-their-dying-moments.html'
url556='https://www.nytimes.com/roomfordebate/2015/12/03/does-motive-matter-in-mass-shootings-like-the-one-in-san-bernadino'
url557='https://www.nytimes.com/2015/12/04/us/fear-in-the-air-americans-look-over-their-shoulders.html'
url558='https://www.nytimes.com/2015/12/04/us/an-officer-who-trained-for-the-worst-and-faced-it-this-was-actually-happening.html'
url559='https://www.nytimes.com/2015/12/04/opinion/the-latest-site-of-carnage-san-bernardino.html'
url560='https://www.nytimes.com/2015/12/04/opinion/tough-talk-and-a-cowardly-vote-on-terrorism.html'
url561='https://www.nytimes.com/2015/12/04/opinion/a-battle-in-san-bernardino.html'
url562='https://www.nytimes.com/politics/first-draft/2015/12/04/a-few-house-democrats-to-attend-prayer-services-at-u-s-mosques/'
url563='https://www.nytimes.com/politics/first-draft/2015/12/04/san-bernardino-shooting-divides-party-narratives/'
url564='https://www.nytimes.com/2015/12/05/business/media/the-news-medias-grim-playbook-on-mass-shootings.html'
url565='https://www.nytimes.com/2015/12/05/us/tashfeen-malik-islamic-state.html'
url566='https://www.nytimes.com/2015/12/05/us/politics/white-house-seeks-path-to-executive-action-on-gun-sales.html'
url567='https://www.nytimes.com/2015/12/05/us/san-bernardino-shooting-the-investigation-so-far.html'
url568='https://www.nytimes.com/2015/12/05/us/landlord-lets-reporters-into-san-bernardino-suspects-apartment.html'
url569='https://www.nytimes.com/2015/12/05/opinion/fear-and-gun-violence-in-america.html'
url570='https://parenting.blogs.nytimes.com/2015/12/04/how-could-a-new-mother-shoot-other-parents/'
url571='https://www.nytimes.com/2015/12/05/opinion/no-more-thoughts-and-prayers.html'
url572='https://www.nytimes.com/2015/12/05/us/muslims-in-america-condemn-extremists-and-fear-anew-for-their-lives.html'
url573='https://www.nytimes.com/2015/12/05/us/gun-debate-yields-page-1-editorial.html'
url574='https://www.nytimes.com/2015/12/05/opinion/end-the-gun-epidemic-in-america.html'
url575='https://www.nytimes.com/2015/12/05/opinion/the-senate-goes-gaga-on-guns.html'
url576='https://www.nytimes.com/2015/12/05/us/politics/gop-candidates-seize-on-shootings-in-california-as-proof-of-terror-threat.html'
url577='https://www.nytimes.com/2015/12/05/opinion/fear-ignorance-not-muslims.html'
url578='https://www.nytimes.com/2015/12/06/us/politics/obama-calls-for-stronger-gun-laws-after-california-shooting.html'
url579='https://www.nytimes.com/2015/12/06/us/witnesses-recall-day-of-terror-in-San-Bernardino.html'
url580='https://www.nytimes.com/2015/12/06/opinion/sunday/hysteria-about-refugees-but-blindness-on-guns.html'
url581='https://www.nytimes.com/2015/12/06/us/in-wake-of-shootings-a-familiar-call-to-arms-drives-latest-jump-in-weapon-sales.html'
url582='https://www.nytimes.com/2015/12/06/world/middleeast/islamic-state-san-bernardino-massacre.html'
url583='https://www.nytimes.com/2015/12/06/us/politics/california-attack-has-us-rethinking-strategy-on-homegrown-terror.html'
url584='https://www.nytimes.com/2015/12/06/us/sisters-of-san-bernardino-shooting-suspect-say-they-saw-no-warning-signs.html'
url585='https://www.nytimes.com/2015/12/06/world/asia/tashfeen-malik-suspect-in-california-attack-remains-mystery-to-relatives.html'
url586='https://www.nytimes.com/2015/12/07/us/before-attack-san-bernardino-was-on-the-verge-of-a-turnaround.html'
url587='https://www.nytimes.com/2015/12/07/us/politics/president-obama-islamic-state-speech-oval-office.html'
url588='https://www.nytimes.com/2015/12/07/us/politics/president-obama-terrorism-threat-speech-oval-office.html'
url589='https://www.nytimes.com/2015/12/07/world/asia/in-conservative-pakistani-city-a-saudi-girl-who-stood-out.html'
url590='https://www.nytimes.com/politics/first-draft/2015/12/06/republicans-attack-obamas-address/'
url591='https://www.nytimes.com/2015/12/07/opinion/president-obamas-tough-calming-talk-on-terrorism.html'
url592='https://www.nytimes.com/2015/12/08/us/san-bernardino-shooting.html'
url593='https://www.nytimes.com/2015/12/08/opinion/president-obama-terrorism-and-guns.html'
url594='https://www.nytimes.com/2015/12/08/world/asia/tashfeen-malik-attended-conservative-religious-school-in-pakistan.html'
url595='https://www.nytimes.com/2015/12/08/us/fbi-says-san-bernardino-assailants-were-radicalized.html'
url596='https://www.nytimes.com/politics/first-draft/2015/12/07/donald-trump-calls-for-banning-muslims-from-entering-u-s/'
url597='https://www.nytimes.com/2015/12/08/world/middleeast/discrepancies-emerge-over-where-tashfeen-malik-grew-up.html'
url598='https://www.nytimes.com/2015/12/08/us/on-twitter-san-bernardino-shooting-divides-more-than-unites.html'
url599='https://www.nytimes.com/2015/12/09/us/enrique-marquez-buyer-of-guns-used-in-san-bernardino-attack-is-studied.html'

# %%
#San Bernadinho
urls=[url538,url539,url540,url541,url542,url543,url544,url545,url546,url547,url548,url549,url550,url551,url552,
     url553,url554,url555,url556,url557,url558,url559,url560,url561,url562,url563,url564,url565,url566,url567,
     url568,url569,url570,url571,url572,url573,url574,url575,url576,url577,url578,url579,url580,url581,url582,
     url583,url584,url585,url586,url587,url588,url589,url590,url591,url592,url593,url594,url595,url596,url597,
     url598,url599]
Nyt_SB =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SB= Nyt_SB.append([[a.title, a.text]], ignore_index=True)
Nyt_SB.columns=['Title','Article']
Nyt_SB['Incident Name'] = 'San Bernadinho'
Nyt_SB
# Out:
#                                                 Title  \
# 0   San Bernardino Shooting Kills at Least 14; Two...
# 1   Presidential Candidates React to San Bernardin...
# 2                        The Horror in San Bernardino
# 3                      On Guns, We’re Not Even Trying
# 4   Struggling City Is Traumatized by a Siege and ...
# 5   Couple Kept Tight Lid on Plans for San Bernard...
# 6   Police Raid Townhouse of Suspect in San Bernar...
# 7   San Bernardino Suspects Left Trail of Clues, b...
# 8   Mass Shootings Stoke Ideological Fighting in C...
# 9   A Nation Wonders When Bloodshed Becomes Terrorism
# 10       Don’t Make San Bernardino a Victory for ISIS
# 11  Hillary Clinton Renews Call for Tough Gun Meas...
# 12  Raising Cynics, or Raising Hope: Talking With ...
# 13  Weapons in San Bernardino Shootings Were Legal...
# 14         How Many Mass Shootings Are There, Really?
# 15  U.S. Media Mocked Abroad for Reporting False N...
# ...

# %%
#Omaha, Nebraska
url=['No Articles']
Nyt_ON =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ON= Nyt_ON.append([[a.title, a.text]], ignore_index=True)
Nyt_ON.columns=['Title','Article']
Nyt_ON['title'] = 'NaN'
Nyt_ON['article'] = 'NaN'
Nyt_ON['Incident Name'] = 'Omaha, Nebraska'
Nyt_ON.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ON.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ON
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chesapeake, Virginia
url=['No Articles']
Nyt_CV =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CV= Nyt_CV.append([[a.title, a.text]], ignore_index=True)
Nyt_CV.columns=['Title','Article']
Nyt_CV['title'] = 'NaN'
Nyt_CV['article'] = 'NaN'
Nyt_CV['Incident Name'] = 'Chesapeake, Virginia'
Nyt_CV.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CV.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CV
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Orlando, Florida
url=['No Articles']
Nyt_OF =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_OF= Nyt_OF.append([[a.title, a.text]], ignore_index=True)
Nyt_OF.columns=['Title','Article']
Nyt_OF['title'] = 'NaN'
Nyt_OF['article'] = 'NaN'
Nyt_OF['Incident Name'] = 'Orlando, Florida'
Nyt_OF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_OF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_OF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Luka, Mississippi
url=['No Articles']
Nyt_LM =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LM= Nyt_LM.append([[a.title, a.text]], ignore_index=True)
Nyt_LM.columns=['Title','Article']
Nyt_LM['title'] = 'NaN'
Nyt_LM['article'] = 'NaN'
Nyt_LM['Incident Name'] = 'Luka, Mississippi'
Nyt_LM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Kalamazoo, Michigan
url600='https://www.nytimes.com/2016/02/21/us/kalamazoo-michigan-shootings.html?_r=0'
url601='https://www.nytimes.com/2016/02/22/us/kalamazoo-michigan-random-shootings.html'
url602='https://www.nytimes.com/2016/02/23/us/kalamazoo-michigan-shooting.html'
urls=[url600,url601,url602]
Nyt_KM =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_KM= Nyt_KM.append([[a.title, a.text]], ignore_index=True)
Nyt_KM.columns=['Title','Article']
Nyt_KM['Incident Name'] = 'Kalamazoo, Michigan'
Nyt_KM
# Out:
#                                                Title  \
# 0  At Least 6 Are Killed in Random Shootings in K...
# 1  Kalamazoo Searches for Motive in Spree That Ki...
# 2  Kalamazoo Shooting Suspect Charged, but Motive...
#
#                                              Article        Incident Name
# 0  At least seven people in the Kalamazoo, Mich.,...  Kalamazoo, Michigan
# 1  In all, six people were killed and two injured...  Kalamazoo, Michigan
# 2  President Obama weighed in, as he has many tim...  Kalamazoo, Michigan

# %%
#Glendale, Arizona
url=['No Articles']
Nyt_GA =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GA= Nyt_GA.append([[a.title, a.text]], ignore_index=True)
Nyt_GA.columns=['Title','Article']
Nyt_GA['title'] = 'NaN'
Nyt_GA['article'] = 'NaN'
Nyt_GA['Incident Name'] = 'Glendale, Arizona'
Nyt_GA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_GA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_GA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Heeston, Kansas
url603='https://www.nytimes.com/2016/02/26/us/shooting-at-plant-hesston-kansas.html'
urls=[url603]
Nyt_HK =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HK= Nyt_HK.append([[a.title, a.text]], ignore_index=True)
Nyt_HK.columns=['Title','Article']
Nyt_HK['Incident Name'] = 'Heeston, Kansas'
Nyt_HK
# Out:
#                                                Title  \
# 0  Gunman Kills 3 at Kansas Factory Before Dying ...
#
#                                              Article    Incident Name
# 0  Paul Mullet, the chief executive of Excel Indu...  Heeston, Kansas

# %%
#Belfair, Washington
url604='https://www.nytimes.com/2016/02/27/us/washington-state-man-kills-his-family-and-then-himself.html'
urls=[url604]
Nyt_BW =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BW= Nyt_BW.append([[a.title, a.text]], ignore_index=True)
Nyt_BW.columns=['Title','Article']
Nyt_BW['Incident Name'] = 'Belfair, Washington'
Nyt_BW
# Out:
#                                                Title  \
# 0  Washington State Man Kills His Family and Then...
#
#                                              Article        Incident Name
# 0  Photo\n\nBELFAIR, Wash. — A gunman who killed ...  Belfair, Washington

# %%
#Woodbridge, Virginia
url605='https://www.nytimes.com/2016/02/29/us/new-virginia-officer-killed-on-domestic-violence-call.html'
url606='https://www.nytimes.com/2016/03/01/us/virginia-soldier-accused-of-killing-wife-and-officer.html'
url607='https://www.nytimes.com/2016/03/02/us/thousands-honor-virginia-officer-ashley-guindon-killed-on-her-first-day-on-the-job.html'
urls=[url605,url606,url607]
Nyt_Wood =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Wood= Nyt_Wood.append([[a.title, a.text]], ignore_index=True)
Nyt_Wood.columns=['Title','Article']
Nyt_Wood['Incident Name'] = 'WoodBridge, Virginia'
Nyt_Wood
# Out:
#                                                Title  \
# 0  New Virginia Officer Killed on Domestic Violen...
# 1  Virginia: Soldier Admitted Killings, Affidavit...
# 2  Thousands Honor Virginia Officer Killed on Her...
#
#                                              Article         Incident Name
# 0  Photo\n\nWOODBRIDGE, Va. — On her first day on...  WoodBridge, Virginia
# 1  An Army staff sergeant has admitted to shootin...  WoodBridge, Virginia
# 2  As the service ended, the officers — including...  WoodBridge, Virginia

# %%
#Chelsea, Massachusetts
url=['No Articles']
Nyt_CMa=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CMa= Nyt_CMa.append([[a.title, a.text]], ignore_index=True)
Nyt_CMa.columns=['Title','Article']
Nyt_CMa['title'] = 'NaN'
Nyt_CMa['article'] = 'NaN'
Nyt_CMa['Incident Name'] = 'Chelsea, Massachusetts'
Nyt_CMa.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CMa.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CMa
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Kansas City, Kansas
url608='https://www.nytimes.com/2016/03/10/us/errors-led-to-release-of-suspect-in-three-previous-crimes.html'
urls=[url608]
Nyt_KCK =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_KCK= Nyt_KCK.append([[a.title, a.text]], ignore_index=True)
Nyt_KCK.columns=['Title','Article']
Nyt_KCK['Incident Name'] = 'Kansas City, Kansas'
Nyt_KCK
# Out:
#                                                Title  \
# 0  Series of Errors Allowed Shooting Suspect, in ...
#
#                                              Article        Incident Name
# 0  And in September, the agency received more new...  Kansas City, Kansas

# %%
#Pittsburgh, Pennsylvania
url609='https://www.nytimes.com/2016/03/11/us/mass-shooting-wilkinsburg-pittsburgh.html'
urls=[url609]
Nyt_PP =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PP= Nyt_PP.append([[a.title, a.text]], ignore_index=True)
Nyt_PP.columns=['Title','Article']
Nyt_PP['Incident Name'] = 'Pittsburgh, Pennsylvania'
Nyt_PP
# Out:
#                                                Title  \
# 0  Shooting That Killed 5 at Party Near Pittsburg...
#
#                                              Article             Incident Name
# 0  Photo\n\nWILKINSBURG, Pa. — A shooting at a ba...  Pittsburgh, Pennsylvania

# %%
#Plantation, Florida
url=['No Articles']
Nyt_PF=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PF= Nyt_PF.append([[a.title, a.text]], ignore_index=True)
Nyt_PF.columns=['Title','Article']
Nyt_PF['title'] = 'NaN'
Nyt_PF['article'] = 'NaN'
Nyt_PF['Incident Name'] = 'Plantation, Florida'
Nyt_PF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Louisville, Kentucky
url=['No Articles']
Nyt_LK=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LK= Nyt_LK.append([[a.title, a.text]], ignore_index=True)
Nyt_LK.columns=['Title','Article']
Nyt_LK['title'] = 'NaN'
Nyt_LK['article'] = 'NaN'
Nyt_LK['Incident Name'] = 'Louisville, Kentucky'
Nyt_LK.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LK.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LK
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Sherman, Texas
url=['No Articles']
Nyt_ST=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ST= Nyt_ST.append([[a.title, a.text]], ignore_index=True)
Nyt_ST.columns=['Title','Article']
Nyt_ST['title'] = 'NaN'
Nyt_ST['article'] = 'NaN'
Nyt_ST['Incident Name'] = 'Sherman, Texas'
Nyt_ST.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ST.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ST
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Lawrenceburg, Tennessee
url=['No Articles']
Nyt_LT=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LT= Nyt_LT.append([[a.title, a.text]], ignore_index=True)
Nyt_LT.columns=['Title','Article']
Nyt_LT['title'] = 'NaN'
Nyt_LT['article'] = 'NaN'
Nyt_LT['Incident Name'] = 'Lawrenceburg, Tennessee'
Nyt_LT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LT
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Louisburg, North Carolina
url=['No Articles']
Nyt_LNC=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LNC= Nyt_LNC.append([[a.title, a.text]], ignore_index=True)
Nyt_LNC.columns=['Title','Article']
Nyt_LNC['title'] = 'NaN'
Nyt_LNC['article'] = 'NaN'
Nyt_LNC['Incident Name'] = 'Louisburg, North Carolina'
Nyt_LNC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LNC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LNC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Richmond, Virginia
url610='https://www.nytimes.com/2016/04/03/us/virginia-gunman-said-he-hated-police-ex-girlfriend-says.html'
url611='https://www.nytimes.com/2016/04/01/us/virginia-state-police-officer-is-killed-at-richmond-bus-station.html'
urls=[url610,url611]
Nyt_RV =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RV= Nyt_RV.append([[a.title, a.text]], ignore_index=True)
Nyt_RV.columns=['Title','Article']
Nyt_RV['Incident Name'] = 'Richmond, Virginia'
Nyt_RV
# Out:
#                                                Title  \
# 0  Virginia Gunman Said He Hated Police, Ex-Girlf...
# 1  Virginia State Trooper Killed in Bus Station S...
#
#                                              Article       Incident Name
# 0  The authorities said Friday that they are stil...  Richmond, Virginia
# 1  Photo\n\nA Virginia police trooper was killed ...  Richmond, Virginia

# %%
#Residence in Lakeland, Florida
url=['No Articles']
Nyt_LF=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LF= Nyt_LF.append([[a.title, a.text]], ignore_index=True)
Nyt_LF.columns=['Title','Article']
Nyt_LF['title'] = 'NaN'
Nyt_LF['article'] = 'NaN'
Nyt_LF['Incident Name'] = 'Residence in Lakeland, Florida'
Nyt_LF.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LF.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LF
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Roadside in Memphis, Tennessee
url=['No Articles']
Nyt_RMT=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RMT= Nyt_RMT.append([[a.title, a.text]], ignore_index=True)
Nyt_RMT.columns=['Title','Article']
Nyt_RMT['title'] = 'NaN'
Nyt_RMT['article'] = 'NaN'
Nyt_RMT['Incident Name'] = 'Roadside in Memphis, Tennessee'
Nyt_RMT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_RMT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_RMT
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Wilmington, DE robbery
url=['No Articles']
Nyt_WDE=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WDE= Nyt_WDE.append([[a.title, a.text]], ignore_index=True)
Nyt_WDE.columns=['Title','Article']
Nyt_WDE['title'] = 'NaN'
Nyt_WDE['article'] = 'NaN'
Nyt_WDE['Incident Name'] = 'Wilmington, DE robbery'
Nyt_WDE.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WDE.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WDE
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Gloucester County, VA, House Party
url=['No Articles']
Nyt_GCVA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GCVA= Nyt_GCVA.append([[a.title, a.text]], ignore_index=True)
Nyt_GCVA.columns=['Title','Article']
Nyt_GCVA['title'] = 'NaN'
Nyt_GCVA['article'] = 'NaN'
Nyt_GCVA['Incident Name'] = 'Gloucester County, VA, House Party'
Nyt_GCVA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_GCVA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_GCVA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Florida family murder
url=['No Articles']
Nyt_FFM=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FFM= Nyt_FFM.append([[a.title, a.text]], ignore_index=True)
Nyt_FFM.columns=['Title','Article']
Nyt_FFM['title'] = 'NaN'
Nyt_FFM['article'] = 'NaN'
Nyt_FFM['Incident Name'] = 'Florida family murder'
Nyt_FFM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FFM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FFM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Los Angeles Drive-by
url=['No Articles']
Nyt_LAD=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LAD= Nyt_LAD.append([[a.title, a.text]], ignore_index=True)
Nyt_LAD.columns=['Title','Article']
Nyt_LAD['title'] = 'NaN'
Nyt_LAD['article'] = 'NaN'
Nyt_LAD['Incident Name'] = 'Los Angeles Drive-by'
Nyt_LAD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LAD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LAD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Perris, CA Mexican restaurant shooting
url=['No Articles']
Nyt_PCA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PCA= Nyt_PCA.append([[a.title, a.text]], ignore_index=True)
Nyt_PCA.columns=['Title','Article']
Nyt_PCA['title'] = 'NaN'
Nyt_PCA['article'] = 'NaN'
Nyt_PCA['Incident Name'] = 'Perris, CA Mexican restaurant shooting'
Nyt_PCA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PCA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PCA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chesapeake, VA Family Murder Suicide
url=['No Articles']
Nyt_CAFMS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CAFMS= Nyt_CAFMS.append([[a.title, a.text]], ignore_index=True)
Nyt_CAFMS.columns=['Title','Article']
Nyt_CAFMS['title'] = 'NaN'
Nyt_CAFMS['article'] = 'NaN'
Nyt_CAFMS['Incident Name'] = 'Chesapeake, VA Family Murder Suicide'
Nyt_CAFMS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CAFMS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CAFMS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Caroline County, VA Family Murder Suicide
url=['No Articles']
Nyt_CCV=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CCV= Nyt_CCV.append([[a.title, a.text]], ignore_index=True)
Nyt_CCV.columns=['Title','Article']
Nyt_CCV['title'] = 'NaN'
Nyt_CCV['article'] = 'NaN'
Nyt_CCV['Incident Name'] = 'Caroline County, VA Family Murder Suicide'
Nyt_CCV.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CCV.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CCV
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Glendale, AZ House Party shooting
url=['No Articles']
Nyt_GAZ=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GAZ= Nyt_GAZ.append([[a.title, a.text]], ignore_index=True)
Nyt_GAZ.columns=['Title','Article']
Nyt_GAZ['title'] = 'NaN'
Nyt_GAZ['article'] = 'NaN'
Nyt_GAZ['Incident Name'] = 'Glendale, AZ House Party shooting'
Nyt_GAZ.drop(['Title','Article'], axis=1, inplace=True)
Nyt_GAZ.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_GAZ
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#New Orleans gas station shoot-out
url=['No Articles']
Nyt_NOGS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NOGS= Nyt_NOGS.append([[a.title, a.text]], ignore_index=True)
Nyt_NOGS.columns=['Title','Article']
Nyt_NOGS['title'] = 'NaN'
Nyt_NOGS['article'] = 'NaN'
Nyt_NOGS['Incident Name'] = 'New Orleans gas station shoot-out'
Nyt_NOGS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_NOGS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_NOGS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tampa, FL Strip club shooting
url=['No Articles']
Nyt_TFL=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TFL= Nyt_TFL.append([[a.title, a.text]], ignore_index=True)
Nyt_TFL.columns=['Title','Article']
Nyt_TFL['title'] = 'NaN'
Nyt_TFL['article'] = 'NaN'
Nyt_TFL['Incident Name'] = 'Tampa, FL Strip club shooting'
Nyt_TFL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_TFL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_TFL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Los Angeles, CA street shooting
url=['No Articles']
Nyt_LASS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LASS= Nyt_LASS.append([[a.title, a.text]], ignore_index=True)
Nyt_LASS.columns=['Title','Article']
Nyt_LASS['title'] = 'NaN'
Nyt_LASS['article'] = 'NaN'
Nyt_LASS['Incident Name'] = 'Los Angeles, CA street shooting'
Nyt_LASS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LASS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LASS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Texas teen commits family murder suicide
url=['No Articles']
Nyt_TXFMS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TXFMS= Nyt_TXFMS.append([[a.title, a.text]], ignore_index=True)
Nyt_TXFMS.columns=['Title','Article']
Nyt_TXFMS['title'] = 'NaN'
Nyt_TXFMS['article'] = 'NaN'
Nyt_TXFMS['Incident Name'] = 'Texas teen commits family murder suicide'
Nyt_TXFMS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_TXFMS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_TXFMS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Nightclub fight turns into shootout
url=['No Articles']
Nyt_NFS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NFS= Nyt_NFS.append([[a.title, a.text]], ignore_index=True)
Nyt_NFS.columns=['Title','Article']
Nyt_NFS['title'] = 'NaN'
Nyt_NFS['article'] = 'NaN'
Nyt_NFS['Incident Name'] = 'Nightclub fight turns into shootout'
Nyt_NFS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_NFS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_NFS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Michigan school shooting
url=['No Articles']
Nyt_MSS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MSS= Nyt_MSS.append([[a.title, a.text]], ignore_index=True)
Nyt_MSS.columns=['Title','Article']
Nyt_MSS['title'] = 'NaN'
Nyt_MSS['article'] = 'NaN'
Nyt_MSS['Incident Name'] = 'Michigan school shooting'
Nyt_MSS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MSS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MSS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Vallejo, CA car shooting
url=['No Articles']
Nyt_VCA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_VCA= Nyt_VCA.append([[a.title, a.text]], ignore_index=True)
Nyt_VCA.columns=['Title','Article']
Nyt_VCA['title'] = 'NaN'
Nyt_VCA['article'] = 'NaN'
Nyt_VCA['Incident Name'] = 'Vallejo, CA car shooting'
Nyt_VCA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_VCA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_VCA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Florida Hookah Bar Shooting
url=['No Articles']
Nyt_FHB=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FHB= Nyt_FHB.append([[a.title, a.text]], ignore_index=True)
Nyt_FHB.columns=['Title','Article']
Nyt_FHB['title'] = 'NaN'
Nyt_FHB['article'] = 'NaN'
Nyt_FHB['Incident Name'] = 'Florida Hookah Bar Shooting'
Nyt_FHB.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FHB.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FHB
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Kalamazoo Uber Driver Spree Killing
url612='https://www.nytimes.com/2016/02/22/us/kalamazoo-michigan-random-shootings.html'
url613='https://www.nytimes.com/2016/02/23/us/kalamazoo-michigan-shooting.html'
urls=[url612,url613]
Nyt_Uber =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Uber= Nyt_Uber.append([[a.title, a.text]], ignore_index=True)
Nyt_Uber.columns=['Title','Article']
Nyt_Uber['Incident Name'] = 'Kalamazoo Uber Driver Spree Killing'
Nyt_Uber
# Out:
#                                                Title  \
# 0  Kalamazoo Searches for Motive in Spree That Ki...
# 1  Kalamazoo Shooting Suspect Charged, but Motive...
#
#                                              Article  \
# 0  In all, six people were killed and two injured...
# 1  President Obama weighed in, as he has many tim...
#
#                          Incident Name
# 0  Kalamazoo Uber Driver Spree Killing
# 1  Kalamazoo Uber Driver Spree Killing

# %%
#Missouri Highway shooting
url=['No Articles']
Nyt_MH=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MH= Nyt_MH.append([[a.title, a.text]], ignore_index=True)
Nyt_MH.columns=['Title','Article']
Nyt_MH['title'] = 'NaN'
Nyt_MH['article'] = 'NaN'
Nyt_MH['Incident Name'] = 'Missouri Highway shooting'
Nyt_MH.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MH.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MH
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Houston Drive-by
url=['No Articles']
Nyt_HD=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HD= Nyt_HD.append([[a.title, a.text]], ignore_index=True)
Nyt_HD.columns=['Title','Article']
Nyt_HD['title'] = 'NaN'
Nyt_HD['article'] = 'NaN'
Nyt_HD['Incident Name'] = 'Houston Drive-by'
Nyt_HD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_HD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_HD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Arizona Family Murder
url=['No Articles']
Nyt_AZFM=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AZFM= Nyt_AZFM.append([[a.title, a.text]], ignore_index=True)
Nyt_AZFM.columns=['Title','Article']
Nyt_AZFM['title'] = 'NaN'
Nyt_AZFM['article'] = 'NaN'
Nyt_AZFM['Incident Name'] = 'Arizona Family Murder'
Nyt_AZFM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_AZFM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_AZFM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Detroit Strip Club Shootout
url=['No Articles']
Nyt_DSC=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DSC= Nyt_DSC.append([[a.title, a.text]], ignore_index=True)
Nyt_DSC.columns=['Title','Article']
Nyt_DSC['title'] = 'NaN'
Nyt_DSC['article'] = 'NaN'
Nyt_DSC['Incident Name'] = 'Detroit Strip Club Shootout'
Nyt_DSC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DSC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DSC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Riverside restaurant shooting
url=['No Articles']
Nyt_RRS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RRS= Nyt_RRS.append([[a.title, a.text]], ignore_index=True)
Nyt_RRS.columns=['Title','Article']
Nyt_RRS['title'] = 'NaN'
Nyt_RRS['article'] = 'NaN'
Nyt_RRS['Incident Name'] = 'Riverside restaurant shooting'
Nyt_RRS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_RRS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_RRS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Wichita Nightclub shooting
url=['No Articles']
Nyt_WN=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WN= Nyt_WN.append([[a.title, a.text]], ignore_index=True)
Nyt_WN.columns=['Title','Article']
Nyt_WN['title'] = 'NaN'
Nyt_WN['article'] = 'NaN'
Nyt_WN['Incident Name'] = 'Wichita Nightclub shooting'
Nyt_WN.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WN.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WN
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chelsea, MA empty apartment party shooting
url=['No Articles']
Nyt_CMAP=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CMAP= Nyt_CMAP.append([[a.title, a.text]], ignore_index=True)
Nyt_CMAP.columns=['Title','Article']
Nyt_CMAP['title'] = 'NaN'
Nyt_CMAP['article'] = 'NaN'
Nyt_CMAP['Incident Name'] = 'Chelsea, MA empty apartment party shooting'
Nyt_CMAP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CMAP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CMAP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Roswell, GA Hookah shootout
url=['No Articles']
Nyt_RGA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RGA= Nyt_RGA.append([[a.title, a.text]], ignore_index=True)
Nyt_RGA.columns=['Title','Article']
Nyt_RGA['title'] = 'NaN'
Nyt_RGA['article'] = 'NaN'
Nyt_RGA['Incident Name'] = 'Roswell, GA Hookah shootout'
Nyt_RGA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_RGA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_RGA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Lafayette, LA drive by
url=['No Articles']
Nyt_LLA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LLA= Nyt_LLA.append([[a.title, a.text]], ignore_index=True)
Nyt_LLA.columns=['Title','Article']
Nyt_LLA['title'] = 'NaN'
Nyt_LLA['article'] = 'NaN'
Nyt_LLA['Incident Name'] = 'Lafayette, LA drive by'
Nyt_LLA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LLA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LLA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Kansas City Home Invasion
url614='https://www.nytimes.com/2016/03/10/us/errors-led-to-release-of-suspect-in-three-previous-crimes.html'
urls=[url614]
Nyt_Uber =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Uber= Nyt_Uber.append([[a.title, a.text]], ignore_index=True)
Nyt_Uber.columns=['Title','Article']
Nyt_Uber['Incident Name'] = 'Kansas City Home Invasion'
Nyt_Uber
# Out:
#                                                Title  \
# 0  Series of Errors Allowed Shooting Suspect, in ...
#
#                                              Article  \
# 0  And in September, the agency received more new...
#
#                Incident Name
# 0  Kansas City Home Invasion

# %%
#Trenton, NJ sidewalk shooting
url=['No Articles']
Nyt_TNJ=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TNJ= Nyt_TNJ.append([[a.title, a.text]], ignore_index=True)
Nyt_TNJ.columns=['Title','Article']
Nyt_TNJ['title'] = 'NaN'
Nyt_TNJ['article'] = 'NaN'
Nyt_TNJ['Incident Name'] = 'Trenton, NJ sidewalk shooting'
Nyt_TNJ.drop(['Title','Article'], axis=1, inplace=True)
Nyt_TNJ.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_TNJ
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Detroit Drive-by
url=['No Articles']
Nyt_DD=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DD= Nyt_DD.append([[a.title, a.text]], ignore_index=True)
Nyt_DD.columns=['Title','Article']
Nyt_DD['title'] = 'NaN'
Nyt_DD['article'] = 'NaN'
Nyt_DD['Incident Name'] = 'Detroit Drive-by'
Nyt_DD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Elberton, Georgia murder-suicide
url=['No Articles']
Nyt_EGA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_EGA= Nyt_EGA.append([[a.title, a.text]], ignore_index=True)
Nyt_EGA.columns=['Title','Article']
Nyt_EGA['title'] = 'NaN'
Nyt_EGA['article'] = 'NaN'
Nyt_EGA['Incident Name'] = 'Elberton, Georgia murder-suicide'
Nyt_EGA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_EGA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_EGA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Florida Family celebration ends in shooting
url=['No Articles']
Nyt_FFC=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FFC= Nyt_FFC.append([[a.title, a.text]], ignore_index=True)
Nyt_FFC.columns=['Title','Article']
Nyt_FFC['title'] = 'NaN'
Nyt_FFC['article'] = 'NaN'
Nyt_FFC['Incident Name'] = 'Florida Family celebration ends in shooting'
Nyt_FFC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FFC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FFC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Atlanta Nightclub shooting
url=['No Articles']
Nyt_AN=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AN= Nyt_AN.append([[a.title, a.text]], ignore_index=True)
Nyt_AN.columns=['Title','Article']
Nyt_AN['title'] = 'NaN'
Nyt_AN['article'] = 'NaN'
Nyt_AN['Incident Name'] = 'Atlanta Nightclub shooting'
Nyt_AN.drop(['Title','Article'], axis=1, inplace=True)
Nyt_AN.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_AN
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Wetumpka Drive-by
url=['No Articles']
Nyt_WD=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WD= Nyt_WD.append([[a.title, a.text]], ignore_index=True)
Nyt_WD.columns=['Title','Article']
Nyt_WD['title'] = 'NaN'
Nyt_WD['article'] = 'NaN'
Nyt_WD['Incident Name'] = 'Wetumpka Drive-by'
Nyt_WD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Spring Break Party shooting
url=['No Articles']
Nyt_SBP=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SBP= Nyt_SBP.append([[a.title, a.text]], ignore_index=True)
Nyt_SBP.columns=['Title','Article']
Nyt_SBP['title'] = 'NaN'
Nyt_SBP['article'] = 'NaN'
Nyt_SBP['Incident Name'] = 'Spring Break Party shooting'
Nyt_SBP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_SBP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_SBP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Louisville, KY Family Murder-Suicide
url=['No Articles']
Nyt_LKY=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LKY= Nyt_LKY.append([[a.title, a.text]], ignore_index=True)
Nyt_LKY.columns=['Title','Article']
Nyt_LKY['title'] = 'NaN'
Nyt_LKY['article'] = 'NaN'
Nyt_LKY['Incident Name'] = 'Louisville, KY Family Murder-Suicide'
Nyt_LKY.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LKY.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LKY
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Greenhill, AL Family murder-suicide
url=['No Articles']
Nyt_GAL=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GAL= Nyt_GAL.append([[a.title, a.text]], ignore_index=True)
Nyt_GAL.columns=['Title','Article']
Nyt_GAL['title'] = 'NaN'
Nyt_GAL['article'] = 'NaN'
Nyt_GAL['Incident Name'] = 'Greenhill, AL Family murder-suicide'
Nyt_GAL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_GAL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_GAL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Albuquerque, NM Family restaurant shooting
url=['No Articles']
Nyt_ANM=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ANM= Nyt_ANM.append([[a.title, a.text]], ignore_index=True)
Nyt_ANM.columns=['Title','Article']
Nyt_ANM['title'] = 'NaN'
Nyt_ANM['article'] = 'NaN'
Nyt_ANM['Incident Name'] = 'Albuquerque, NM Family restaurant shooting'
Nyt_ANM.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ANM.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ANM
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chicago Birthday Party Bus Shooting
url=['No Articles']
Nyt_CBP=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CBP= Nyt_CBP.append([[a.title, a.text]], ignore_index=True)
Nyt_CBP.columns=['Title','Article']
Nyt_CBP['title'] = 'NaN'
Nyt_CBP['article'] = 'NaN'
Nyt_CBP['Incident Name'] = 'Chicago Birthday Party Bus Shooting'
Nyt_CBP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CBP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CBP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Albuquerque, NM House party shooting
url=['No Articles']
Nyt_ANMH=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ANMH= Nyt_ANMH.append([[a.title, a.text]], ignore_index=True)
Nyt_ANMH.columns=['Title','Article']
Nyt_ANMH['title'] = 'NaN'
Nyt_ANMH['article'] = 'NaN'
Nyt_ANMH['Incident Name'] = 'Albuquerque, NM House party shooting'
Nyt_ANMH.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ANMH.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ANMH
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Memphis, TN gas station shooting
url=['No Articles']
Nyt_MTNG=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MTNG= Nyt_MTNG.append([[a.title, a.text]], ignore_index=True)
Nyt_MTNG.columns=['Title','Article']
Nyt_MTNG['title'] = 'NaN'
Nyt_MTNG['article'] = 'NaN'
Nyt_MTNG['Incident Name'] = 'Memphis, TN gas station shooting'
Nyt_MTNG.drop(['Title','Article'], axis=1, inplace=True)
Nyt_MTNG.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_MTNG
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Long Beach Street murder
url=['No Articles']
Nyt_LBS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LBS= Nyt_LBS.append([[a.title, a.text]], ignore_index=True)
Nyt_LBS.columns=['Title','Article']
Nyt_LBS['title'] = 'NaN'
Nyt_LBS['article'] = 'NaN'
Nyt_LBS['Incident Name'] = 'Long Beach Street murder'
Nyt_LBS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LBS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LBS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Chicago Rap video Shootout
url=['No Articles']
Nyt_CR=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CR= Nyt_CR.append([[a.title, a.text]], ignore_index=True)
Nyt_CR.columns=['Title','Article']
Nyt_CR['title'] = 'NaN'
Nyt_CR['article'] = 'NaN'
Nyt_CR['Incident Name'] = 'Chicago Rap video Shootout'
Nyt_CR.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CR.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CR
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Texas family murder-suicide
url=['No Articles']
Nyt_TFMS=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TFMS= Nyt_TFMS.append([[a.title, a.text]], ignore_index=True)
Nyt_TFMS.columns=['Title','Article']
Nyt_TFMS['title'] = 'NaN'
Nyt_TFMS['article'] = 'NaN'
Nyt_TFMS['Incident Name'] = 'Texas family murder-suicide'
Nyt_TFMS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_TFMS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_TFMS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Alabama highway random shooting
url=['No Articles']
Nyt_AHR=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AHR= Nyt_AHR.append([[a.title, a.text]], ignore_index=True)
Nyt_AHR.columns=['Title','Article']
Nyt_AHR['title'] = 'NaN'
Nyt_AHR['article'] = 'NaN'
Nyt_AHR['Incident Name'] = 'Alabama highway random shooting'
Nyt_AHR.drop(['Title','Article'], axis=1, inplace=True)
Nyt_AHR.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_AHR
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Tire-Slashing revenge escalation
url=['No Articles']
Nyt_TSR=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TSR= Nyt_TSR.append([[a.title, a.text]], ignore_index=True)
Nyt_TSR.columns=['Title','Article']
Nyt_TSR['title'] = 'NaN'
Nyt_TSR['article'] = 'NaN'
Nyt_TSR['Incident Name'] = 'Tire-Slashing revenge escalation'
Nyt_TSR.drop(['Title','Article'], axis=1, inplace=True)
Nyt_TSR.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_TSR
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Halifax County, VA
url=['No Articles']
Nyt_HVA=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HVA= Nyt_HVA.append([[a.title, a.text]], ignore_index=True)
Nyt_HVA.columns=['Title','Article']
Nyt_HVA['title'] = 'NaN'
Nyt_HVA['article'] = 'NaN'
Nyt_HVA['Incident Name'] = 'Halifax County, VA'
Nyt_HVA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_HVA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_HVA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Forestville, Maryland Drive-by
url=['No Articles']
Nyt_FMD=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FMD= Nyt_FMD.append([[a.title, a.text]], ignore_index=True)
Nyt_FMD.columns=['Title','Article']
Nyt_FMD['title'] = 'NaN'
Nyt_FMD['article'] = 'NaN'
Nyt_FMD['Incident Name'] = 'Forestville, Maryland Drive-by'
Nyt_FMD.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FMD.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FMD
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Ferguson, MO Drive by
url=['No Articles']
Nyt_FMO=pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FMO= Nyt_FMO.append([[a.title, a.text]], ignore_index=True)
Nyt_FMO.columns=['Title','Article']
Nyt_FMO['title'] = 'NaN'
Nyt_FMO['article'] = 'NaN'
Nyt_FMO['Incident Name'] = 'Ferguson, MO Drive by'
Nyt_FMO.drop(['Title','Article'], axis=1, inplace=True)
Nyt_FMO.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_FMO
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
NYT_2010s=pd.concat([Nyt_LR, Nyt_UAH, Nyt_HBC, Nyt_AZGG, Nyt_YSU, Nyt_SUSCC, Nyt_NIHOP, Nyt_SS, Nyt_SJHS, Nyt_CHS,
                     Nyt_OU, Nyt_NT, Nyt_SC, Nyt_AU, Nyt_Aurora, Nyt_Sikh, Nyt_Accent, Nyt_Spot, Nyt_ASB, Nyt_Cla, 
                     Nyt_Sandy, Nyt_SVR, Nyt_PLF, Nyt_LAPD, Nyt_LR, Nyt_PVA, Nyt_VMIL, Nyt_SMC, Nyt_HA, Nyt_RTSCM, 
                     Nyt_WNY, Nyt_SMS, Nyt_MHV, Nyt_LAX, Nyt_HDD, Nyt_CHB, Nyt_SFT, Nyt_FtH, Nyt_KF, Nyt_IV, 
                     Nyt_SPU, Nyt_NP, Nyt_BSNOLA, Nyt_MPHS, Nyt_FSU, Nyt_CRT, Nyt_EBAL, Nyt_PPA, Nyt_MEM, Nyt_MID, 
                     Nyt_QNY, Nyt_LaG, Nyt_Omaha, Nyt_UNCCH, Nyt_MM, Nyt_Ty, Nyt_WV, Nyt_DGA, Nyt_Mpub, Nyt_CGA, 
                     Nyt_KTX, Nyt_CH, Nyt_BWP, Nyt_Tar, Nyt_Brook, Nyt_Cot, Nyt_Mesa, Nyt_LW, Nyt_PCB, Nyt_Tulsa, 
                     Nyt_DB, Nyt_IND, Nyt_RO, Nyt_PHO, Nyt_Kil, Nyt_GP, Nyt_Mil, Nyt_FCTT, Nyt_Tuc, Nyt_CM, Nyt_Cle,
                     Nyt_Con, Nyt_DL, Nyt_MEAMEC, Nyt_BBM, Nyt_AMNJ, Nyt_MG, Nyt_RF, Nyt_CATC, Nyt_Suw, Nyt_16LA, 
                     Nyt_HOTX, Nyt_WDBJ, Nyt_BTN, Nyt_CMN, Nyt_UCC, Nyt_NAU, Nyt_KNC, Nyt_HHEC, Nyt_CTO, Nyt_CS, 
                     Nyt_OM, Nyt_IF, Nyt_WG, Nyt_JF, Nyt_TCT, Nyt_CO, Nyt_MMN, Nyt_CSC, Nyt_SB, Nyt_ON, Nyt_CV, 
                     Nyt_OF, Nyt_LM,  Nyt_KM,  Nyt_GA, Nyt_HK, Nyt_BW, Nyt_Wood, Nyt_CMa, Nyt_KCK, Nyt_PP, Nyt_PF, 
                     Nyt_LK, Nyt_LT, Nyt_LNC, Nyt_RV, Nyt_LF, Nyt_RMT,Nyt_WDE, Nyt_GCVA, Nyt_FFM, Nyt_LAD,Nyt_PCA,
                     Nyt_CAFMS, Nyt_CCV, Nyt_GAZ, Nyt_NOGS,Nyt_TFL, Nyt_LASS, Nyt_TXFMS, Nyt_NFS, Nyt_MSS, Nyt_VCA, 
                     Nyt_FHB, Nyt_Uber, Nyt_MH, Nyt_HD,Nyt_AZFM, Nyt_DSC,Nyt_RRS, Nyt_WN, Nyt_CMAP, Nyt_RGA, Nyt_LLA, 
                     Nyt_TNJ, Nyt_DD, Nyt_EGA, Nyt_FFC, Nyt_FMO,Nyt_FMD, Nyt_HVA, Nyt_TSR, Nyt_AHR, Nyt_TFMS, Nyt_CR, 
                     Nyt_LBS, Nyt_AN,Nyt_WD, Nyt_SBP, Nyt_LKY, Nyt_GAL, Nyt_ANM, Nyt_CBP, Nyt_ANMH, Nyt_MTNG])

# %%
NYT_2010s.to_csv('NYT 2010s Shootings.csv',index=False, encoding='utf-8')
