# %%
import pandas as pd
import newspaper
from newspaper import Article

# %%
#GMAC Loan Office
url1='http://www.nytimes.com/1990/06/20/us/hazy-records-helped-florida-gunman-buy-arms.html'
url2='http://www.nytimes.com/1990/06/19/us/florida-gunman-kills-8-and-wounds-6-in-office.html'
url3='http://www.nytimes.com/1990/06/19/us/florida-gunman-kills-8-and-then-himself.html'
urls=[url1, url2,url3]
Nyt_GLO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GLO= Nyt_GLO.append([[a.title, a.text]], ignore_index=True)
Nyt_GLO.columns=['Title','Article']

# %%
Nyt_GLO['Incident Name'] = 'GMAC Loan Office'
Nyt_GLO['Shooter Race']='African American'
Nyt_GLO
# Out:
#                                            Title  \
# 0    Hazy Records Helped Florida Gunman Buy Arms
# 1  Florida Gunman Kills 8 And Wounds 6 in Office
# 2        Florida Gunman Kills 8 and Then Himself
#
#                                              Article     Incident Name  \
# 0  JACKSONVILLE, Fla., June 19— The police said t...  GMAC Loan Office
# 1  JACKSONVILLE, Fla., June 18— A man sprayed doz...  GMAC Loan Office
# 2  This item appeared in the paper as a stand alo...  GMAC Loan Office
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American

# %%
#Univeristy of Iowa
url161='http://www.nytimes.com/1991/11/02/us/student-opens-fire-at-u-of-iowa-killing-4-before-shooting-himself.html'
url162='http://www.nytimes.com/1991/11/03/us/gunman-in-iowa-wrote-of-plans-in-five-letters.html'
url163='http://www.nytimes.com/1991/11/04/us/portrait-of-gunman-s-victims.html'
urls=[url161, url162,url163]
Nyt_UofI =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_UofI= Nyt_UofI.append([[a.title, a.text]], ignore_index=True)
Nyt_UofI.columns=['Title','Article']
Nyt_UofI['Incident Name'] = 'Univeristy of Iowa'
Nyt_UofI['Shooter Race']='Asian'
Nyt_UofI
# Out:
#                                                Title  \
# 0  Student Opens Fire at U. of Iowa, Killing 4 Be...
# 1      Gunman in Iowa Wrote of Plans In Five Letters
# 2                       Portrait of Gunman's Victims
#
#                                              Article       Incident Name  \
# 0  A distraught graduate student went on a shooti...  Univeristy of Iowa
# 1  IOWA CITY, Iowa, Nov. 2— Late Friday afternoon...  Univeristy of Iowa
# 2  IOWA CITY, Iowa, Nov. 3— Following are biograp...  Univeristy of Iowa
#
#   Shooter Race
# 0        Asian
# 1        Asian
# 2        Asian

# %%
#Ridgewood Post Office
url4='http://www.nytimes.com/1991/10/14/nyregion/4-killed-and-2-are-wounded-in-queens-rampage.html'
url5='http://www.nytimes.com/1991/10/13/nyregion/death-invades-a-tranquil-village-and-ridgewood-deals-with-horror.html'
url6='http://www.nytimes.com/1991/10/12/nyregion/suspect-in-spree-refused-to-fight-loss-of-his-job.html'
url7='http://www.nytimes.com/1991/10/11/nyregion/4-slain-in-2-new-jersey-attacks-and-former-postal-clerk-is-held.html'
urls=[url4, url5,url6,url7]
Nyt_RPO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RPO= Nyt_RPO.append([[a.title, a.text]], ignore_index=True)
Nyt_RPO.columns=['Title','Article']

# %%
Nyt_RPO['Incident Name'] = 'Ridgewood Post Office'
Nyt_RPO['Shooter Race']='African American'
Nyt_RPO
# Out:
#                                                Title  \
# 0       4 Killed and 2 Are Wounded in Queens Rampage
# 1  Death Invades a Tranquil Village, And Ridgewoo...
# 2  Suspect in Spree Refused to Fight Loss of His Job
# 3  4 Slain in 2 New Jersey Attacks And Former Pos...
#
#                                              Article          Incident Name  \
# 0  A 47-year-old neighborhood eccentric went on a...  Ridgewood Post Office
# 1  RIDGEWOOD, N.J., Oct. 12 --\n\nThe people who ...  Ridgewood Post Office
# 2  RIDGEWOOD, N.J., Oct. 11— Months before conduc...  Ridgewood Post Office
# 3  RIDGEWOOD, N.J., Oct. 10— A former postal cler...  Ridgewood Post Office
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American
# 3  African American

# %%
#Luby's Cafeteria
url8='http://www.nytimes.com/1991/10/17/us/gunman-kills-22-and-himself-in-texas-cafeteria.html'
url9='http://www.nytimes.com/1991/10/18/business/company-news-luby-s-delay-on-earnings.html'
url10='http://www.nytimes.com/1991/10/18/us/portrait-of-texas-killer-impatient-and-troubled.html'
url11='http://www.nytimes.com/1991/10/18/us/some-victims-in-texas-a-colonel-an-ex-teacher-and-dr-g.html'
url12='http://www.nytimes.com/1991/10/19/us/town-in-texas-quietly-gathers-for-a-memorial.html'
url13='http://www.nytimes.com/1991/10/20/weekinreview/dead-23-texans-and-1-anti-gun-measure.html'
url14='http://www.nytimes.com/1991/10/20/us/deaths-at-home-rend-town-used-to-worst-of-war.html'
url15='http://www.nytimes.com/1991/10/22/us/autopsy-of-man-who-killed-23-in-texas-finds-no-drugs-or-tumor.html'
urls=[url8, url9,url10,url11,url12,url13,url14,url15]
Nyt_LC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LC= Nyt_LC.append([[a.title, a.text]], ignore_index=True)
Nyt_LC.columns=['Title','Article']
Nyt_LC['Incident Name'] = 'Lubys Cafeteria'
Nyt_LC['Shooter Race']='White'
Nyt_LC
# Out:
#                                                Title  \
# 0     Gunman Kills 22 and Himself in Texas Cafeteria
# 1                           Luby's Delay On Earnings
# 2                           Portrait of Texas Killer
# 3              A Colonel, an Ex-Teacher and 'Dr. G.'
# 4       Town in Texas Quietly Gathers For a Memorial
# 5                   23 Texans and 1 Anti-Gun Measure
# 6      Deaths at Home Rend Town Used to Worst of War
# 7  Autopsy of Man Who Killed 23 In Texas Finds No...
#
#                                              Article    Incident Name  \
# 0  KILLEEN, Tex., Oct. 16— A man smashed a pickup...  Lubys Cafeteria
# 1  KILLEEN, Tex., Oct. 17— The earnings report fo...  Lubys Cafeteria
# 2  BELTON, Tex., Oct. 17— At 5:30 Wednesday morni...  Lubys Cafeteria
# 3  KILLEEN, Tex., Oct., 17— Steven Charles Dody w...  Lubys Cafeteria
# 4  KILLEEN, Tex., Oct. 18— Two days after a gunma...  Lubys Cafeteria
# ...

# %%
#Royal Oak Post Office
url16='http://www.nytimes.com/1991/11/16/us/slayings-at-michigan-post-office-spur-a-review-of-all-employees.html'
url17='http://www.nytimes.com/1991/11/15/us/ex-postal-worker-kills-3-and-wounds-6-in-michigan.html'
url18='http://www.nytimes.com/1991/11/15/us/concerned-over-morale-post-office-asks-why.html'
urls=[url16,url17,url18]
Nyt_ROPO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ROPO= Nyt_ROPO.append([[a.title, a.text]], ignore_index=True)
Nyt_ROPO.columns=['Title','Article']
Nyt_ROPO['Incident Name'] = 'Royal Oak Post Office'
Nyt_ROPO['Shooter Race']='White'
Nyt_ROPO
# Out:
#                                                Title  \
# 0  Slayings at Michigan Post Office Spur a Review...
# 1  Ex-Postal Worker Kills 3 and Wounds 6 in Michigan
# 2        Concerned Over Morale, Post Office Asks Why
#
#                                              Article          Incident Name  \
# 0  BIRMINGHAM, Mich., Nov. 15— The nation's Postm...  Royal Oak Post Office
# 1  ROYAL OAK, Mich., Friday, Nov. 15— A former po...  Royal Oak Post Office
# 2  WASHINGTON, Nov. 14— Concerned with the morale...  Royal Oak Post Office
#
#   Shooter Race
# 0        White
# 1        White
# 2        White

# %%
url=['No Articles'] # Lindhurst High School
Nyt_LHS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LHS= Nyt_LHS.append([[a.title, a.text]], ignore_index=True)
Nyt_LHS.columns=['Title','Article']
Nyt_LHS['title'] = 'NaN'
Nyt_LHS['article'] = 'NaN'
Nyt_LHS['Incident Name'] = 'Lindhurst High School'
Nyt_LHS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LHS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LHS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
url=['No Articles'] # Palo Duro High School
Nyt_PDHS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PDHS= Nyt_PDHS.append([[a.title, a.text]], ignore_index=True)
Nyt_PDHS.columns=['Title','Article']
Nyt_PDHS['title'] = 'NaN'
Nyt_PDHS['article'] = 'NaN'
Nyt_PDHS['Incident Name'] = 'Palo Duro High School'
Nyt_PDHS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PDHS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PDHS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Schuyler Child Support
url19='http://www.nytimes.com/1992/10/18/nyregion/little-things-of-4-lost-lives-recalled.html'
url20='http://www.nytimes.com/1992/10/16/nyregion/gunman-kills-4-who-collected-child-payments.html'
url21='http://www.nytimes.com/1992/10/17/nyregion/shooting-followed-tougher-efforts-to-collect-child-support.html'
urls=[url19,url20,url21]
Nyt_SCS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SCS= Nyt_SCS.append([[a.title, a.text]], ignore_index=True)
Nyt_SCS.columns=['Title','Article']
Nyt_SCS['Incident Name'] = 'Schuyler County Office Building'
Nyt_SCS['Shooter Race']='White'
Nyt_SCS
# Out:
#                                                Title  \
# 0             Little Things of 4 Lost Lives Recalled
# 1        Gunman Kills 4 Who Collected Child Payments
# 2  Shooting Followed Tougher Efforts to Collect C...
#
#                                              Article  \
# 0  WATKINS GLEN, N.Y., Oct. 17— Carol Goodrich sa...
# 1  WATKINS GLEN, N.Y., Oct. 15— A truck driver wh...
# 2  WATKINS GLEN, N.Y., Oct. 16— John T. Miller nu...
#
#                      Incident Name Shooter Race
# 0  Schuyler County Office Building        White
# 1  Schuyler County Office Building        White
# 2  Schuyler County Office Building        White

# %%
#Simon Rock College of Bard
url22='http://www.nytimes.com/1992/12/16/us/college-student-sprays-campus-with-an-assault-rifle-killing-2.html'
url23='http://www.nytimes.com/1992/12/19/opinion/the-slain-principal-s-last-lesson.html'
urls=[url22,url23]
Nyt_SRCB =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SRCB= Nyt_SRCB.append([[a.title, a.text]], ignore_index=True)
Nyt_SRCB.columns=['Title','Article']
Nyt_SRCB['Incident Name'] = 'Simons Rock College of Bard'
Nyt_SRCB['Shooter Race']='Asian'
Nyt_SRCB
# Out:
#                                                Title  \
# 0  College Student Sprays Campus With an Assault ...
# 1                  The Slain Principal's Last Lesson
#
#                                              Article  \
# 0  GREAT BARRINGTON, Mass., Dec. 15— An honors st...
# 1  Patrick Daly was a peaceful man who dedicated ...
#
#                  Incident Name Shooter Race
# 0  Simons Rock College of Bard        Asian
# 1  Simons Rock College of Bard        Asian

# %%
#Pettit and Martin Law Firm
url24='http://www.nytimes.com/1993/07/02/us/gunman-raids-law-office-and-kills-8.html'
Nyt_PMLLP =pd.DataFrame()
a=Article(url17, language='en')
a.download()
a.parse()
Nyt_PMLLP= Nyt_PMLLP.append([[a.title, a.text]], ignore_index=True)
Nyt_PMLLP.columns=['Title','Article']
Nyt_PMLLP['Incident Name'] = 'SF Offices of Pettit & Martin'
Nyt_PMLLP['Shooter Race']='White'
Nyt_PMLLP
# Out:
#                                                Title  \
# 0  Ex-Postal Worker Kills 3 and Wounds 6 in Michigan
#
#                                              Article  \
# 0  ROYAL OAK, Mich., Friday, Nov. 15— A former po...
#
#                    Incident Name Shooter Race
# 0  SF Offices of Pettit & Martin        White

# %%
#Dearborn PO
url25='http://www.nytimes.com/1993/05/09/weekinreview/may-2-8-workers-kill-workers-yet-again-violence-in-the-post-office.html'
url26='http://www.nytimes.com/1993/05/07/us/2-are-killed-in-post-office-shootings-in-2-states.html'
url27='http://www.nytimes.com/1993/05/08/us/postal-officials-examine-system-after-2-killings.html'
urls=[url25,url26,url27]
Nyt_DPO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DPO= Nyt_DPO.append([[a.title, a.text]], ignore_index=True)
Nyt_DPO.columns=['Title','Article']
Nyt_DPO['Incident Name'] = 'Dearborn Post Office'
Nyt_DPO['Shooter Race']='White'
Nyt_DPO
# Out:
#                                                Title  \
# 0             Yet Again, Violence In the Post Office
# 1  2 Are Killed in Post Office Shootings in 2 States
# 2   Postal Officials Examine System After 2 Killings
#
#                                              Article         Incident Name  \
# 0  The coincidence was bizarre, but the events we...  Dearborn Post Office
# 1  LOS ANGELES, May 6— Two people were killed and...  Dearborn Post Office
# 2  WASHINGTON, May 7— As shaken Post Office offic...  Dearborn Post Office
#
#   Shooter Race
# 0        White
# 1        White
# 2        White

# %%
#Dana Point PO
url28='http://www.nytimes.com/1993/05/09/weekinreview/may-2-8-workers-kill-workers-yet-again-violence-in-the-post-office.html'
url29='http://www.nytimes.com/1993/05/07/us/2-are-killed-in-post-office-shootings-in-2-states.html'
url30='http://www.nytimes.com/1993/05/08/us/postal-officials-examine-system-after-2-killings.html'
urls=[url25,url26,url27]
Nyt_DPPO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DPPO= Nyt_DPPO.append([[a.title, a.text]], ignore_index=True)
Nyt_DPPO.columns=['Title','Article']
Nyt_DPPO['Incident Name'] = 'Dana Point Post Office'
Nyt_DPPO['Shooter Race']='White'
Nyt_DPPO
# Out:
#                                                Title  \
# 0             Yet Again, Violence In the Post Office
# 1  2 Are Killed in Post Office Shootings in 2 States
# 2   Postal Officials Examine System After 2 Killings
#
#                                              Article           Incident Name  \
# 0  The coincidence was bizarre, but the events we...  Dana Point Post Office
# 1  LOS ANGELES, May 6— Two people were killed and...  Dana Point Post Office
# 2  WASHINGTON, May 7— As shaken Post Office offic...  Dana Point Post Office
#
#   Shooter Race
# 0        White
# 1        White
# 2        White

# %%
#Weber State University
url31='http://www.nytimes.com/1993/07/09/us/student-shoots-3-at-hearing-in-utah-and-is-then-killed.html'
Nyt_WSU =pd.DataFrame()
a=Article(url31, language='en')
a.download()
a.parse()
Nyt_WSU= Nyt_WSU.append([[a.title, a.text]], ignore_index=True)
Nyt_WSU.columns=['Title','Article']
Nyt_WSU['Incident Name'] = 'Weber State University'
Nyt_WSU['Shooter Race']='Asian'
Nyt_WSU
# Out:
#                                                Title  \
# 0  Student Shoots 3 at Hearing In Utah, and Is Th...
#
#                                              Article           Incident Name  \
# 0  SALT LAKE CITY, July 8— A student grievance he...  Weber State University
#
#   Shooter Race
# 0        Asian

# %%
url=['No Articles'] # Luigi's Restaurant in Fayetteville,LA
Nyt_LFLA =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LFLA= Nyt_LFLA.append([[a.title, a.text]], ignore_index=True)
Nyt_LFLA.columns=['Title','Article']
Nyt_LFLA['title'] = 'NaN'
Nyt_LFLA['article'] = 'NaN'
Nyt_LFLA['Incident Name'] = 'Luigis Restaurant in Fayetteville,LA'
Nyt_LFLA.drop(['Title','Article'], axis=1, inplace=True)
Nyt_LFLA.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_LFLA
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Central Middle School, Wyoming
url32='http://www.nytimes.com/1993/09/18/us/gunman-wounds-4-at-wyoming-school.html'
Nyt_CMS =pd.DataFrame()
a=Article(url32, language='en')
a.download()
a.parse()
Nyt_CMS= Nyt_CMS.append([[a.title, a.text]], ignore_index=True)
Nyt_CMS.columns=['Title','Article']
Nyt_CMS['Incident Name'] = 'Central Middle School'
Nyt_CMS['Shooter Race']='White'
Nyt_CMS
# Out:
#                                Title  \
# 0  Gunman Wounds 4 at Wyoming School
#
#                                              Article          Incident Name  \
# 0  This item appeared in the paper as a stand alo...  Central Middle School
#
#   Shooter Race
# 0        White

# %%
#LIRR Shooting
url33='http://www.nytimes.com/1993/12/08/nyregion/metro-digest-441693.html'
url34='http://www.nytimes.com/1993/12/08/nyregion/gunman-kills-5-on-lirr-train-19-are-wounded.html'
url35='http://www.nytimes.com/1993/12/08/nyregion/riders-on-board-train-scramble-to-survive.html'
url36='http://www.nytimes.com/1993/12/09/nyregion/death-on-the-lirr-the-rampage-gunman-in-a-train-aisle-passes-out-death.html'
url37='http://www.nytimes.com/1993/12/09/nyregion/death-lirr-commuters-ride-day-later-5-33-will-never-seem-same-again.html'
url38='http://www.nytimes.com/1993/12/09/nyregion/news-summary-300893.html'
url39='http://www.nytimes.com/1993/12/09/nyregion/metro-digest-455193.html'
url40='http://www.nytimes.com/1993/12/09/nyregion/death-lirr-white-house-moved-killings-clinton-urges-action-gun-legislation.html'
rul41='http://www.nytimes.com/1993/12/09/nyregion/death-lirr-overview-portrait-suspect-emerges-shooting-li-train.html'
url41='http://www.nytimes.com/1993/12/09/nyregion/death-on-the-lirr-the-weapon-16-days-in-california-and-a-fateful-purchase.html'
url42='http://www.nytimes.com/1993/12/10/nyregion/death-lirr-adelphi-recalls-student-driven-rage-suspended-for-making-threats.html'
url43='http://www.nytimes.com/1993/12/10/opinion/mass-murder-on-the-5-33.html'
url44='http://www.nytimes.com/1993/12/10/nyregion/death-on-the-lirr-suspect-s-quiet-roots-in-jamaica-suburb.html'
url45='http://www.nytimes.com/1993/12/10/nyregion/death-on-the-lirr-police-look-for-the-spark-that-led-to-the-shootings.html'
url46='http://www.nytimes.com/1993/12/10/nyregion/death-on-the-lirr-suddenly-fearful-riders-mourn-loss-of-a-haven.html'
url47='http://www.nytimes.com/1993/12/10/us/administration-floats-proposal-for-licensing-all-gun-owners.html'
url48='http://www.nytimes.com/1993/12/11/nyregion/a-yonkers-neighborhood-reels-after-shootings.html'
url49='http://www.nytimes.com/1993/12/11/nyregion/death-on-the-lirr-lawyer-seeks-sanity-inquiry-in-li-killings.html'
url50='http://www.nytimes.com/1993/12/11/nyregion/death-on-lirr-a-rampage-shatters-semblance-of-safety.html'
url51='http://www.nytimes.com/1993/12/11/nyregion/death-on-lirr-gathering-to-mourn-lives-lost-on-train.html'
url52='http://www.nytimes.com/1993/12/12/nyregion/tormented-life-special-report-long-slide-privilege-ends-slaughter-train.html'
url53='http://www.nytimes.com/1993/12/12/nyregion/killings-leave-yonkers-now-talking-about-violence.html'
url54='http://www.nytimes.com/1993/12/12/weekinreview/the-nation-as-gunfire-gets-closer-fear-comes-home.html'
url55='http://www.nytimes.com/1993/12/12/opinion/in-america-a-sea-change-on-crime.html'
url56='http://www.nytimes.com/1993/12/13/nyregion/mineola-woman-is-6th-to-die-in-rail-shootings.html'
url57='http://www.nytimes.com/1993/12/13/nyregion/after-train-killings-worry-about-backlash.html'
url58='http://www.nytimes.com/1993/12/13/nyregion/woman-in-92-subway-dispute-with-lirr-suspect-says-all-the-signs-were-there.html'
url59='http://www.nytimes.com/1993/12/13/nyregion/giuliani-repeats-his-call-for-national-gun-licensing.html'
url60='http://www.nytimes.com/1993/12/13/us/rise-is-found-in-hate-crimes-committed-by-blacks.html'
url61='http://www.nytimes.com/1993/12/14/nyregion/sadness-and-hope-for-family-of-victims-of-train-shooting.html'

# %%
#LIRR Shooting
urls=[url33,url34,url35,url36,url37,url38,url39,url40,url41,url42,url43,url44,
      url45,url46,url47,url48,url49,url50,url51,url52,url53,url54,url55,url56,
     url57,url58,url59,url60,url61]
Nyt_LIRR =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LIRR= Nyt_LIRR.append([[a.title, a.text]], ignore_index=True)
Nyt_LIRR.columns=['Title','Article']
Nyt_LIRR['Incident Name'] = 'Long Island Rail Road(LIRR)'
Nyt_LIRR['Shooter Race']='African American'
Nyt_LIRR
# Out:
#                                                 Title  \
# 0                                        METRO DIGEST
# 1                    Gunman Kills 5 on L.I.R.R. Train
# 2           Riders on Board Train Scramble to Survive
# 3            Gunman in a Train Aisle Passes Out Death
# 4                   33 Will Never Seem the Same Again
# 5                                        NEWS SUMMARY
# 6                                        METRO DIGEST
# 7   Moved by Killings, Clinton Urges Action on Gun...
# 8        16 Days in California and a Fateful Purchase
# 9   Adelphi Recalls a Student Driven by Rage and S...
# 10                               Mass Murder on the 5
# 11            Suspect's Quiet Roots in Jamaica Suburb
# 12  Police Look for the Spark That Led to the Shoo...
# 13     Suddenly Fearful, Riders Mourn Loss of a Haven
# 14  Administration Floats Proposal For Licensing A...
# 15       A Yonkers Neighborhood Reels After Shootings
# ...

# %%
#Chuck E. Cheese
url62='http://www.nytimes.com/1993/12/19/us/funeral-for-victim-of-pizza-parlor-shooting-in-colorado.html'
Nyt_CEC =pd.DataFrame()
a=Article(url62, language='en')
a.download()
a.parse()
Nyt_CEC= Nyt_CEC.append([[a.title, a.text]], ignore_index=True)
Nyt_CEC.columns=['Title','Article']
Nyt_CEC['Incident Name'] = 'Chuck E. Cheese'
Nyt_CEC['Shooter Race']='African American'
Nyt_CEC
# Out:
#                                                Title  \
# 0  Funeral for Victim of Pizza Parlor Shooting in...
#
#                                              Article    Incident Name  \
# 0  This item appeared in the paper as a stand alo...  Chuck E. Cheese
#
#        Shooter Race
# 0  African American

# %%
#Chelsea, Michigan HS
url=['No Articles']
Nyt_CMHS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CMHS= Nyt_CMHS.append([[a.title, a.text]], ignore_index=True)
Nyt_CMHS.columns=['Title','Article']
Nyt_CMHS['title'] = 'NaN'
Nyt_CMHS['article'] = 'NaN'
Nyt_CMHS['Incident Name'] = 'Chelsea, Michigan High School'
Nyt_CMHS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CMHS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
Nyt_CMHS
# Out:
#   Title Article                  Incident Name
# 0   NaN     NaN  Chelsea, Michigan High School

# %%
#Union Residence, Kentucky
url=['No Articles']
Nyt_URKY =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_URKY= Nyt_URKY.append([[a.title, a.text]], ignore_index=True)
Nyt_URKY.columns=['Title','Article']
Nyt_URKY['title'] = 'NaN'
Nyt_URKY['article'] = 'NaN'
Nyt_URKY['Incident Name'] = 'Union Residence, Kentucky'
Nyt_URKY.drop(['Title','Article'], axis=1, inplace=True)
Nyt_URKY.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
Nyt_URKY
# Out:
#   Title Article              Incident Name
# 0   NaN     NaN  Union Residence, Kentucky

# %%
#Fairchild AFB
url63='http://www.nytimes.com/1994/06/22/us/an-airman-s-revenge-5-minutes-of-terror.html'
Nyt_FAFB =pd.DataFrame()
a=Article(url63, language='en')
a.download()
a.parse()
Nyt_FAFB= Nyt_FAFB.append([[a.title, a.text]], ignore_index=True)
Nyt_FAFB.columns=['Title','Article']
Nyt_FAFB['Incident Name'] = 'Fairchild AFB Hospital'
Nyt_FAFB['Shooter Race']='White'
Nyt_FAFB
# Out:
#                  Title                                            Article  \
# 0  An Airman's Revenge  SPOKANE, Wash., June 21— The gunman who killed...
#
#             Incident Name Shooter Race
# 0  Fairchild AFB Hospital        White

# %%
#Wickliffe MS
url=['No Articles']
Nyt_WMS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WMS= Nyt_WMS.append([[a.title, a.text]], ignore_index=True)
Nyt_WMS.columns=['Title','Article']
Nyt_WMS['title'] = 'NaN'
Nyt_WMS['article'] = 'NaN'
Nyt_WMS['Incident Name'] = 'Wickliffe Middle School'
Nyt_WMS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_WMS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_WMS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Downtown Chapel Hill - UNC
url=['No Articles']
Nyt_DCHUNC =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DCHUNC= Nyt_DCHUNC.append([[a.title, a.text]], ignore_index=True)
Nyt_DCHUNC.columns=['Title','Article']
Nyt_DCHUNC['title'] = 'NaN'
Nyt_DCHUNC['article'] = 'NaN'
Nyt_DCHUNC['Incident Name'] = 'Downtown Chapel Hill UNC'
Nyt_DCHUNC.drop(['Title','Article'], axis=1, inplace=True)
Nyt_DCHUNC.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_DCHUNC
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
url64='http://www.nytimes.com/1995/03/22/nyregion/death-post-office-4-shot-dead-new-jersey-post-office-wide-manhunt-but-motive-not.html'
url65='http://www.nytimes.com/1995/03/22/nyregion/death-post-office-victims-workers-tiny-post-office-were-well-known-community.html'
url66='http://www.nytimes.com/1995/03/22/nyregion/death-post-office-4-shot-dead-new-jersey-post-office-fear-walks-suburb-bolts.html'
url67='http://www.nytimes.com/1995/03/22/nyregion/metro-digest-490795.html'
url68='http://www.nytimes.com/1995/03/23/nyregion/metro-digest-657895.html'
url69='http://www.nytimes.com/1995/03/23/nyregion/death-post-office-overview-former-montclair-postal-worker-charged-with-killings.html'
url70='http://www.nytimes.com/1995/03/23/nyregion/death-post-office-victims-for-4-slain-postal-workers-customers-mourning-with.html'
url71='http://www.nytimes.com/1995/03/23/nyregion/new-jersey-daily-briefing-arrest-in-4-post-office-killings.html'
url72='http://www.nytimes.com/1995/03/23/nyregion/death-post-office-suspect-workers-are-stunned-no-it-couldn-t-be-true.html'
url73='http://www.nytimes.com/1995/03/24/nyregion/stunned-town-seeks-reason-for-slayings.html'
url74='http://www.nytimes.com/1995/03/25/nyregion/post-office-survivor-s-help-is-recounted-as-heroic-act.html'
url75='http://www.nytimes.com/1995/03/26/weekinreview/march-19-25-4-killed-in-montclair-mass-murder-in-suburbia-a-new-york-area-update.html'
url76='http://www.nytimes.com/1995/03/26/nyregion/victim-of-post-office-attack-is-mourned.html'
url77='http://www.nytimes.com/1995/03/27/nyregion/honoring-slain-men-montclair-also-mourns-for-itself.html'
url78='http://www.nytimes.com/1995/03/28/nyregion/new-jersey-daily-briefing-delay-in-postal-killings-case.html'

# %%
#Montclair PO
urls=[url64,url65,url66, url67,url68,url69,url70,url71,url72,url73,url74,url75,url76,url77,url78]
Nyt_MPO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MPO= Nyt_MPO.append([[a.title, a.text]], ignore_index=True)
Nyt_MPO.columns=['Title','Article']
Nyt_MPO['Incident Name'] = 'Montclair Post Office'
Nyt_MPO['Shooter Race']='White'
Nyt_MPO
# Out:
#                                                 Title  \
# 0               4 Shot Dead in New Jersey Post Office
# 1   Workers in Tiny Post Office Were Well Known to...
# 2             Fear Walks In, and a Suburb Bolts Doors
# 3                                        METRO DIGEST
# 4                                        METRO DIGEST
# 5   Former Montclair Postal Worker Charged With Ki...
# 6   For 4 Slain Postal Workers and Customers, Mour...
# 7                    Arrest in 4 Post Office Killings
# 8                           'No, It Couldn't Be True'
# 9              Stunned Town Seeks Reason For Slayings
# 10  Post Office Survivor's Help Is Recounted as He...
# 11                            Mass Murder in Suburbia
# 12            Victim of Post Office Attack Is Mourned
# 13  Honoring Slain Men, Montclair Also Mourns for ...
# 14                      Delay in Postal-Killings Case
#
#                                               Article          Incident Name  \
# ...

# %%
#Walter Rossier office, Corpus Christie
url83='http://www.nytimes.com/1995/04/04/us/6-die-in-texas-office-shooting.html?mcubz=0'
Nyt_WRCC =pd.DataFrame()
a=Article(url83, language='en')
a.download()
a.parse()
Nyt_WRCC= Nyt_WRCC.append([[a.title, a.text]], ignore_index=True)
Nyt_WRCC.columns=['Title','Article']
Nyt_WRCC['Incident Name'] = 'Walter Rossier Office, Corpus Christie'
Nyt_WRCC['Shooter Race']='White'
Nyt_WRCC
# Out:
#                             Title  \
# 0  6 Die in Texas Office Shooting
#
#                                              Article  \
# 0  CORPUS CHRISTI, Tex., April 3— A former employ...
#
#                             Incident Name Shooter Race
# 0  Walter Rossier Office, Corpus Christie        White

# %%
#Richland HS
url79='http://www.nytimes.com/1995/11/16/us/student-held-after-2-die-in-shooting-at-school.html'
Nyt_RHS =pd.DataFrame()
a=Article(url79, language='en')
a.download()
a.parse()
Nyt_RHS= Nyt_RHS.append([[a.title, a.text]], ignore_index=True)
Nyt_RHS.columns=['Title','Article']
Nyt_RHS['Incident Name'] = 'Richland High School'
Nyt_RHS['Shooter Race']='White'
Nyt_RHS
# Out:
#                                             Title  \
# 0  Student Held After 2 Die in Shooting at School
#
#                                              Article         Incident Name  \
# 0  LYNNVILLE, Tenn., Nov. 15— A teen-ager who was...  Richland High School
#
#   Shooter Race
# 0        White

# %%
#Frontier Junior High School
url80='http://www.nytimes.com/1996/02/04/us/boy-14-with-rifle-kills-3-in-school.html'
Nyt_FJHS =pd.DataFrame()
a=Article(url80, language='en')
a.download()
a.parse()
Nyt_FJHS= Nyt_FJHS.append([[a.title, a.text]], ignore_index=True)
Nyt_FJHS.columns=['Title','Article']
Nyt_FJHS['Incident Name'] = 'Frontier Junior High School'
Nyt_FJHS['Shooter Race']='White'
Nyt_FJHS
# Out:
#                                    Title  \
# 0  Boy, 14, With Rifle Kills 3 in School
#
#                                              Article  \
# 0  A 14-year-old boy with a high-powered rifle ki...
#
#                  Incident Name Shooter Race
# 0  Frontier Junior High School        White

# %%
url81='http://www.nytimes.com/1996/02/11/us/florida-killer-said-victims-were-racists-police-say.html'
url82='http://www.nytimes.com/1996/02/10/us/5-beach-workers-in-florida-are-slain-by-ex-colleague.html'
#Fort Lauderdale 
urls=[url81,url82]
Nyt_FtL =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FtL= Nyt_FtL.append([[a.title, a.text]], ignore_index=True)
Nyt_FtL.columns=['Title','Article']
Nyt_FtL['Incident Name'] = 'Fort Lauderdale City Parks Office'
Nyt_FtL['Shooter Race']='African American'
Nyt_FtL
# Out:
#                                                Title  \
# 0  Florida Killer Said Victims Were Racists, Poli...
# 1  5 Beach Workers in Florida Are Slain by Ex-Col...
#
#                                              Article  \
# 0  A man who killed five former co-workers left a...
# 1  When he was discharged, Mr. McCree threatened ...
#
#                        Incident Name      Shooter Race
# 0  Fort Lauderdale City Parks Office  African American
# 1  Fort Lauderdale City Parks Office  African American

# %%
#SDSU Shooting
url=['No Articles']
Nyt_SDSU =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SDSU= Nyt_SDSU.append([[a.title, a.text]], ignore_index=True)
Nyt_SDSU.columns=['Title','Article']
Nyt_SDSU['title'] = 'NaN'
Nyt_SDSU['article'] = 'NaN'
Nyt_SDSU['Incident Name'] = 'San Diego State University'
Nyt_SDSU.drop(['Title','Article'], axis=1, inplace=True)
Nyt_SDSU.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_SDSU
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Bethel Regional HSShooting
url=['No Articles']
Nyt_BRHS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BRHS= Nyt_BRHS.append([[a.title, a.text]], ignore_index=True)
Nyt_BRHS.columns=['Title','Article']
Nyt_BRHS['title'] = 'NaN'
Nyt_BRHS['article'] = 'NaN'
Nyt_BRHS['Incident Name'] = 'Bethel Regional High School'
Nyt_BRHS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_BRHS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_BRHS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#RE Phelon Shooting
url=['No Articles']
Nyt_REP =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_REP= Nyt_REP.append([[a.title, a.text]], ignore_index=True)
Nyt_REP.columns=['Title','Article']
Nyt_REP['title'] = 'NaN'
Nyt_REP['article'] = 'NaN'
Nyt_REP['Incident Name'] = 'R.E. Phelon Company'
Nyt_REP.drop(['Title','Article'], axis=1, inplace=True)
Nyt_REP.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_REP
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Pearl HS Shooting
url=['No Articles']
Nyt_PHS =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PHS= Nyt_PHS.append([[a.title, a.text]], ignore_index=True)
Nyt_PHS.columns=['Title','Article']
Nyt_PHS['title'] = 'NaN'
Nyt_PHS['article'] = 'NaN'
Nyt_PHS['Incident Name'] = 'Peal High School'
Nyt_PHS.drop(['Title','Article'], axis=1, inplace=True)
Nyt_PHS.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_PHS
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Heath HS
url83='http://www.nytimes.com/1997/12/04/us/theories-but-no-answer-in-school-shooting.html'
url84='http://www.nytimes.com/1997/12/03/us/forgiveness-after-3-die-in-shootings-in-kentucky.html'
url85='http://www.nytimes.com/1997/12/07/weekinreview/nov-30-dec-6-death-at-an-early-age.html'
urls=[url83,url84,url85]
Nyt_HHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HHS= Nyt_HHS.append([[a.title, a.text]], ignore_index=True)
Nyt_HHS.columns=['Title','Article']
Nyt_HHS['Incident Name'] = 'Heath High School'
Nyt_HHS['Shooter Race']='White'
Nyt_HHS
# Out:
#                                                Title  \
# 0          Theories but No Answer in School Shooting
# 1  Forgiveness, After 3 Die in Shootings in Kentucky
# 2              Nov. 30-Dec. 6; Death at an Early Age
#
#                                              Article      Incident Name  \
# 0  In front of some 40 students, Michael, who has...  Heath High School
# 1  But the police were no closer to discovering a...  Heath High School
# 2  Saying only that he acted ''like I was in a dr...  Heath High School
#
#   Shooter Race
# 0        White
# 1        White
# 2        White

# %%
#Milwaukee PO
url86='http://www.nytimes.com/1997/12/20/us/postal-worker-in-milwaukee-shoots-3-and-kills-himself.html'
Nyt_MilPO =pd.DataFrame()
a=Article(url86, language='en')
a.download()
a.parse()
Nyt_MilPO= Nyt_MilPO.append([[a.title, a.text]], ignore_index=True)
Nyt_MilPO.columns=['Title','Article']
Nyt_MilPO['Incident Name'] = 'Milwaukee Post Office'
Nyt_MilPO['Shooter Race']='African American'
Nyt_MilPO
# Out:
#                                                Title  \
# 0  Postal Worker in Milwaukee Shoots 3 and Kills ...
#
#                                              Article          Incident Name  \
# 0  Mr. Chaney said he had warned postal officials...  Milwaukee Post Office
#
#        Shooter Race
# 0  African American

# %%
#Orange CalTrans
url87='http://www.nytimes.com/1997/12/20/us/dismissed-worker-kills-4-and-then-is-slain.html'
Nyt_OCT =pd.DataFrame()
a=Article(url87, language='en')
a.download()
a.parse()
Nyt_OCT= Nyt_OCT.append([[a.title, a.text]], ignore_index=True)
Nyt_OCT.columns=['Title','Article']
Nyt_OCT['Incident Name'] = 'Caltrans Maintenance Yard '
Nyt_OCT['Shooter Race']='Latin American'
Nyt_OCT
# Out:
#                                         Title  \
# 0  Dismissed Worker Kills 4 and Then Is Slain
#
#                                              Article  \
# 0  A dismissed state highway employee armed with ...
#
#                 Incident Name    Shooter Race
# 0  Caltrans Maintenance Yard   Latin American

# %%
#Connecticut State Lottery
url87='http://www.nytimes.com/1998/03/11/nyregion/at-work-and-funeral-lottery-workers-struggle-with-their-grief.html'
url88='http://www.nytimes.com/1998/03/10/nyregion/city-stunned-to-lose-ex-mayor-in-lottery-attack.html'
url89='http://www.nytimes.com/1998/03/07/nyregion/rampage-connecticut-gunman-neighbors-who-recall-quiet-teen-ager-cannot-fathom.html'
url90='http://www.nytimes.com/1998/03/07/nyregion/rampage-connecticut-overview-connecticut-lottery-worker-kills-4-bosses-then.html'
urls=[url87,url88,url89,url90]
Nyt_CTSL =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CTSL= Nyt_CTSL.append([[a.title, a.text]], ignore_index=True)
Nyt_CTSL.columns=['Title','Article']
Nyt_CTSL['Incident Name'] = 'Connecticut State Lottery'
Nyt_CTSL['Shooter Race']='White'
Nyt_CTSL
# Out:
#                                                Title  \
# 0  At Work and Funeral, Lottery Workers Struggle ...
# 1    City Stunned to Lose Ex-Mayor in Lottery Attack
# 2  RAMPAGE IN CONNECTICUT: THE GUNMAN; Neighbors ...
# 3  RAMPAGE IN CONNECTICUT: THE OVERVIEW; Connecti...
#
#                                              Article  \
# 0  As he put flowers on the site outside the head...
# 1  ''She was always smiling, with a twinkle in he...
# 2  For many hours after the shooting, even Mr. Be...
# 3  During the last few months, there had been str...
#
#                Incident Name Shooter Race
# 0  Connecticut State Lottery        White
# 1  Connecticut State Lottery        White
# 2  Connecticut State Lottery        White
# 3  Connecticut State Lottery        White

# %%
#WestSide Middle School
url91='http://www.nytimes.com/1998/03/27/us/bloodshed-schoolyard-overview-arkansas-jail-one-boy-cries-other-studies-bible.html'
url92='http://www.nytimes.com/1998/03/26/opinion/death-in-a-middle-school.html'
url93='http://www.nytimes.com/1998/03/26/us/bloodshed-schoolyard-overview-arkansas-law-may-bar-stiff-prosecution-boys.html'
url94='http://www.nytimes.com/1998/03/26/us/bloodshed-schoolyard-suspects-grieving-shattered-town-asks-who-are-these-boys.html'
url95='http://www.nytimes.com/1998/03/25/us/5-are-killed-at-school-boys-11-and-13-are-held.html'
url96='http://www.nytimes.com/1998/03/28/us/arkansas-city-begins-burying-its-young-dead.html'
url97='http://www.nytimes.com/1998/03/29/us/funerals-end-for-jonesboro-but-not-questions.html'
url98='http://www.nytimes.com/1998/03/29/us/from-wild-talk-and-friendship-to-five-deaths-in-a-schoolyard.html'
url99='http://www.nytimes.com/1998/03/29/weekinreview/the-nation-spin-cycle-round-and-round-in-the-search-for-meaning.html'
urls=[url91,url92,url93,url94,url95,url96,url97,url98,url99]
Nyt_WestMS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WestMS= Nyt_WestMS.append([[a.title, a.text]], ignore_index=True)
Nyt_WestMS.columns=['Title','Article']
Nyt_WestMS['Incident Name'] = 'Westside Middle School'
Nyt_WestMS['Shooter Race']='White'
Nyt_WestMS
# Out:
#                                                Title  \
# 0  BLOODSHED IN A SCHOOLYARD: THE OVERVIEW; In Ar...
# 1                           Death in a Middle School
# 2  BLOODSHED IN A SCHOOLYARD: THE OVERVIEW; Arkan...
# 3  BLOODSHED IN A SCHOOLYARD: THE SUSPECTS; A Gri...
# 4  5 Are Killed at School; Boys, 11 and 13, Are Held
# 5        Arkansas City Begins Burying Its Young Dead
# 6      Funerals End for Jonesboro, but Not Questions
# 7  From Wild Talk and Friendship To Five Deaths i...
# 8  The Nation: Spin Cycle; Round and Round in the...
#
#                                              Article           Incident Name  \
# 0  And at the Westside Middle School, where the g...  Westside Middle School
# 1  The statistics about school violence offer no ...  Westside Middle School
# 2  The very thing that made the crime so shocking...  Westside Middle School
# 3  ''He said, 'Everyone that hates me, everyone t...  Westside Middle School
# ...

# %%
#Thurston High School
url164='http://www.nytimes.com/1998/05/22/us/shootings-in-a-school-the-tortured-path-of-a-troubled-youth.html'
url165='http://www.nytimes.com/1998/05/22/us/shootings-in-a-school-the-town-oasis-with-a-dark-side.html'
url166='http://www.nytimes.com/1998/05/22/us/shootings-school-suspect-15-year-old-seen-some-troubled-violent.html'
url167='http://www.nytimes.com/1998/05/22/us/shootings-school-overview-oregon-student-held-3-killings-one-dead-23-hurt-his.html'
url168='http://www.nytimes.com/1998/05/26/us/sorrowful-town-honors-teen-ager-killed-in-school-shooting.html'
url169='http://www.nytimes.com/1998/05/25/us/school-opens-doors-to-grief-on-holiday.html'
url170='http://www.nytimes.com/1998/05/24/us/shootings-schoolhouse-town-springfield-struggles-heal-itself-wake-shootings.html'
url171='http://www.nytimes.com/1998/05/23/us/shootings-in-a-schoolhouse-the-hero-wounded-teen-ager-is-called-a-hero.html'
url172='http://www.nytimes.com/1998/05/24/us/shootings-schoolhouse-suspect-lethal-fantasies-15-year-old-became-reality.html'
url173='http://www.nytimes.com/1998/05/23/us/shootings-schoolhouse-overview-oregon-freshman-goes-court-number-deaths-rises-4.html'
urls=[url164,url165,url166,url167,url168,url169,url170,url171,url172,url173]
Nyt_THS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_THS= Nyt_THS.append([[a.title, a.text]], ignore_index=True)
Nyt_THS.columns=['Title','Article']
Nyt_THS['Incident Name'] = 'Thurston High School'
Nyt_THS['Shooter Race']='White'
Nyt_THS
# Out:
#                                                Title  \
# 0  SHOOTINGS IN A SCHOOL; The Tortured Path Of a ...
# 1  SHOOTINGS IN A SCHOOL: THE TOWN; Oasis With a ...
# 2  SHOOTINGS IN A SCHOOL: THE SUSPECT; 15-Year-Ol...
# 3  SHOOTINGS IN A SCHOOL: THE OVERVIEW; Oregon St...
# 4  Sorrowful Town Honors Teen-Ager Killed in Scho...
# 5             School Opens Doors To Grief on Holiday
# 6  SHOOTINGS IN A SCHOOLHOUSE: THE TOWN; Springfi...
# 7  SHOOTINGS IN A SCHOOLHOUSE: THE HERO; Wounded ...
# 8  SHOOTINGS IN A SCHOOLHOUSE: THE SUSPECT; Letha...
# 9  SHOOTINGS IN A SCHOOLHOUSE: THE OVERVIEW; Oreg...
#
#                                              Article         Incident Name  \
# 0  The Kinkel family lived in a wooded neighborho...  Thurston High School
# 1  There is no more idyllic spot in May than Spri...  Thurston High School
# 2  Friends said Kip had been angry at his father ...  Thurston High School
# 3  The state superintendent of schools, Norma Pau...  Thurston High School
# ...

# %%
#MA Abortion Clinic Shooting
url102='http://www.nytimes.com/1994/12/31/us/anti-abortion-killings-victims-desk-jobs-end-violent-death-for-2-clinics.html'
url103='http://www.nytimes.com/1994/12/31/nyregion/no-headline-257524.html'
url104='http://www.nytimes.com/1994/12/31/us/anti-abortion-killings-overview-gunman-kills-2-abortion-clinics-boston-suburb.html'
url105='http://www.nytimes.com/1995/01/01/us/anti-abortion-killings-fire-investigator-is-praised-in-apprehension-of-suspect.html'
url106='http://www.nytimes.com/1995/01/01/us/anti-abortion-killings-arrest-suspect-clinic-killings-eludes-hunt-but-caught-3d.html'
url107='http://www.nytimes.com/1995/01/01/us/anti-abortion-killings-the-movement-anti-abortion-groups-continue-radical-talk.html'
url108='http://www.nytimes.com/1995/01/02/us/authorities-seeking-motive-for-attacks-at-abortion-clinics.html'
url109='http://www.nytimes.com/1995/01/02/us/though-hunt-for-suspect-was-vast-chance-proved-crucial-for-capture.html'
url110='http://www.nytimes.com/1995/01/03/us/brookline-shows-fervor-in-keeping-clinics-open.html'
url111='http://www.nytimes.com/1995/01/04/us/suspect-in-3-clinic-assaults-is-arraigned-in-virginia.html'
url112='http://www.nytimes.com/1995/01/03/us/talks-held-on-prosecuting-suspect-in-clinic-shootings.html'
url113='http://www.nytimes.com/1995/01/04/us/mourning-the-victims-of-two-clinic-shootings.html'
url114='http://www.nytimes.com/1995/01/04/opinion/curbing-violence-at-abortion-clinics.html'
url115='http://www.nytimes.com/1995/01/04/nyregion/o-connor-takes-his-message-to-cyberspace.html'
url116='http://www.nytimes.com/1995/01/05/us/suspect-in-3-abortion-attacks-is-indicted.html'
urls=[url102,url103,url104,url105,url106,url107,url108,url109,url110,url111,url112,url113,url114,url115,url116]
Nyt_MAAC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MAAC= Nyt_MAAC.append([[a.title, a.text]], ignore_index=True)
Nyt_MAAC.columns=['Title','Article']
Nyt_MAAC['Incident Name'] = 'Massachusetts Abortion Clinic'
Nyt_MAAC['Shooter Race']='White'
Nyt_MAAC
# Out:
#                                                 Title  \
# 0     Desk Jobs End in Violent Death for 2 at Clinics
# 1                                         No Headline
# 2   Gunman Kills 2 at Abortion Clinics in Boston S...
# 3   Fire Investigator Is Praised In Apprehension o...
# 4   Suspect in Clinic Killings Eludes Hunt But Is ...
# 5          Anti-Abortion Groups Continue Radical Talk
# 6   Authorities Seeking Motive For Attacks At Abor...
# 7   Though Hunt for Suspect Was Vast, Chance Prove...
# 8      Brookline Shows Fervor In Keeping Clinics Open
# 9   Suspect in 3 Clinic Assaults Is Arraigned in V...
# 10  Talks Held on Prosecuting Suspect in Clinic Sh...
# 11       Mourning the Victims of Two Clinic Shootings
# 12               Curbing Violence at Abortion Clinics
# 13           O'Connor Takes His Message to Cyberspace
# 14          Suspect in 3 Abortion Attacks Is Indicted
#
#                                               Article  \
# ...

# %%
#Wat Promkunaram Buddhist Temple
url100='http://www.nytimes.com/1991/08/13/us/phoenix-asking-if-bias-played-role-in-9-killings.html'
url101='http://www.nytimes.com/1991/08/12/us/under-desert-sun-mourners-pray-for-9-killed-at-temple.html'
urls=[url100,url101]
Nyt_WestProm =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WestProm= Nyt_WestProm.append([[a.title, a.text]], ignore_index=True)
Nyt_WestProm.columns=['Title','Article']
Nyt_WestProm['Incident Name'] = 'Wat Promkunaram Buddhist Temple'
Nyt_WestProm['Shooter Race']='Asian'
Nyt_WestProm
# Out:
#                                                Title  \
# 0   Phoenix Asking if Bias Played Role in 9 Killings
# 1  Under Desert Sun, Mourners Pray for 9 Killed a...
#
#                                              Article  \
# 0  PHOENIX, Aug. 12— Without a clear motive in th...
# 1  PHOENIX, Aug. 11— As police investigators were...
#
#                      Incident Name Shooter Race
# 0  Wat Promkunaram Buddhist Temple        Asian
# 1  Wat Promkunaram Buddhist Temple        Asian

# %%
#Radisson Bay Hotel
url117='http://www.nytimes.com/1999/12/31/us/gunman-kills-5-in-rampage-starting-at-a-florida-hotel.html'
Nyt_RBH =pd.DataFrame()
a=Article(url117, language='en')
a.download()
a.parse()
Nyt_RBH= Nyt_RBH.append([[a.title, a.text]], ignore_index=True)
Nyt_RBH.columns=['Title','Article']
Nyt_RBH['Incident Name'] = 'Radisson Bay Hotel'
Nyt_RBH['Shooter Race']='Latin American'
Nyt_RBH
# Out:
#                                                Title  \
# 0  Gunman Kills 5 in Rampage Starting at a Florid...
#
#                                              Article       Incident Name  \
# 0  After the shooting, the chief said, Mr. Leyva ...  Radisson Bay Hotel
#
#      Shooter Race
# 0  Latin American

# %%
#Xerox HI
url118='http://www.nytimes.com/1999/11/04/us/few-clues-to-gunman-s-rage-in-hawaii-killings.html'
url119='http://www.nytimes.com/1999/11/03/us/seven-people-killed-in-a-honolulu-office.html'
urls=[url118,url119]
Nyt_XHI =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_XHI= Nyt_XHI.append([[a.title, a.text]], ignore_index=True)
Nyt_XHI.columns=['Title','Article']
Nyt_XHI['Incident Name'] = 'Xerox Hawaii'
Nyt_XHI['Shooter Race']='Asian'
Nyt_XHI
# Out:
#                                            Title  \
# 0  Few Clues to Gunman's Rage in Hawaii Killings
# 1       Seven People Killed In a Honolulu Office
#
#                                              Article Incident Name  \
# 0  But on Tuesday, as police officers surrounded ...  Xerox Hawaii
# 1  A Xerox employee killed seven co-workers yeste...  Xerox Hawaii
#
#   Shooter Race
# 0        Asian
# 1        Asian

# %%
#Offices of All-Tech
url120='http://www.nytimes.com/1999/07/30/us/shootings-atlanta-scene-office-building-scenes-chaos-blood-death.html'
Nyt_OAT =pd.DataFrame()
a=Article(url120, language='en')
a.download()
a.parse()
Nyt_OAT= Nyt_OAT.append([[a.title, a.text]], ignore_index=True)
Nyt_OAT.columns=['Title','Article']
Nyt_OAT['Incident Name'] = 'Offices of All-Tech'
Nyt_OAT['Shooter Race']='White'
Nyt_OAT
# Out:
#                                                Title  \
# 0  SHOOTINGS IN ATLANTA: THE SCENE; In an Office ...
#
#                                              Article        Incident Name  \
# 0  Now people were rushing into the room. But the...  Offices of All-Tech
#
#   Shooter Race
# 0        White

# %%
#Riverside City Hall
url120='http://www.nytimes.com/1998/10/07/us/6-at-city-hall-are-shot-ex-worker-is-accused.html'
Nyt_RCH =pd.DataFrame()
a=Article(url120, language='en')
a.download()
a.parse()
Nyt_RCH= Nyt_RCH.append([[a.title, a.text]], ignore_index=True)
Nyt_RCH.columns=['Title','Article']
Nyt_RCH['Incident Name'] = 'Riverside City Hall'
Nyt_RCH['Shooter Race']='African American'
Nyt_RCH
# Out:
#                                            Title  \
# 0  6 at City Hall Are Shot; Ex-Worker Is Accused
#
#                                              Article        Incident Name  \
# 0  Sergeant Rice was hospitalized in fair conditi...  Riverside City Hall
#
#        Shooter Race
# 0  African American

# %%
#Heritage HS
url121='http://www.nytimes.com/1999/05/21/us/guns-and-schools-an-affinity-for-weapons-but-no-signs-of-anger.html'
url122='https://learning.blogs.nytimes.com/1999/05/21/school-violence-is-it-in-your-backyard/?_r=0'
url123='http://www.nytimes.com/1999/05/21/us/guns-and-schools-the-overview-youth-with-2-guns-shoots-6-at-georgia-school.html'
url124='http://www.nytimes.com/1999/05/22/us/boy-took-parent-s-guns-for-attack-sheriff-says.html'
url125='http://www.nytimes.com/1999/05/23/opinion/l-another-shooting-another-search-for-lessons-829552.html'
url126='http://www.nytimes.com/1999/05/24/us/schools-look-hard-at-lockers-shirts-bags-and-manners.html'
urls=[url121,url122,url123,url124,url125,url126]
Nyt_HerHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_HerHS= Nyt_HerHS.append([[a.title, a.text]], ignore_index=True)
Nyt_HerHS.columns=['Title','Article']
Nyt_HerHS['Incident Name'] = 'Heritage High School'
Nyt_HerHS['Shooter Race']='White'
Nyt_HerHS
# Out:
#                                                Title  \
# 0  GUNS AND SCHOOLS; An Affinity for Weapons, But...
# 1           School Violence: Is It in Your Backyard?
# 2  GUNS AND SCHOOLS: THE OVERVIEW; Youth With 2 G...
# 3    Boy Took Parent's Guns For Attack, Sheriff Says
# 4       Another Shooting, Another Search for Lessons
# 5  Schools Look Hard At Lockers, Shirts, Bags and...
#
#                                              Article         Incident Name  \
# 0  Larry Cohran, who played baseball with Thomas ...  Heritage High School
# 1  Note: This lesson was originally published on ...  Heritage High School
# 2  Officials did not identify the boy in custody ...  Heritage High School
# 3  ''This is where people move for the peace and ...  Heritage High School
# 4  To the Editor:\n\nThe Senate has finally decid...  Heritage High School
# 5  Mr. Sumner's attitude is far from unique. Sinc...  Heritage High School
#
#   Shooter Race
# 0        White
# 1        White
# ...

# %%
#Columbine URLs
url160='http://www.nytimes.com/1999/04/21/us/terror-littleton-trench-coat-mafia-students-fringe-found-way-stand.html'
url127='http://www.nytimes.com/1999/04/21/opinion/gun-spree-at-columbine-high.html'
url128='http://www.nytimes.com/1999/04/21/us/terror-in-littleton-the-scene-in-a-violent-instant-routine-gives-way-to-panic.html'
url129='http://www.nytimes.com/1999/04/21/us/terror-littleton-television-critic-s-notebook-with-abundance-confusion-few-facts.html'
url130='https://learning.blogs.nytimes.com/1999/04/21/taking-aim-at-violence-in-schools/?_r=0'
url131='http://www.nytimes.com/1999/04/21/us/terror-littleton-overview-2-students-colorado-school-said-gun-down-many-23-kill.html'
url132='http://www.nytimes.com/1999/04/22/us/terror-in-littleton-the-dead-father-of-victim-says-son-had-dispute-with-suspect.html'
url133='http://www.nytimes.com/1999/04/22/us/terror-in-littleton-the-suspects-portrait-of-outcasts-seeking-to-stand-out.html'
url134='http://www.nytimes.com/1999/04/22/us/terror-in-littleton-the-reasons-violence-by-youths-looking-for-answers.html'
url135='http://www.nytimes.com/1999/04/22/us/terror-in-littleton-the-school-good-grades-good-teams-and-some-bad-feelings.html'
url136='http://www.nytimes.com/1999/04/22/us/terror-in-littleton-the-overview-15-bodies-are-removed-from-school-in-colorado.html'
url137='http://www.nytimes.com/1999/04/23/opinion/l-what-was-behind-colorado-shooting-361518.html'
url138='http://www.nytimes.com/1999/04/23/nyregion/news-summary-360880.html'
url139='http://www.nytimes.com/1999/04/23/us/terror-littleton-students-fears-though-far-colorado-one-high-school-feeling.html'
url140='http://www.nytimes.com/1999/04/23/us/terror-littleton-gun-debate-shootings-firm-up-gun-control-cause-least-for.html'
url141='http://www.nytimes.com/1999/04/23/opinion/l-what-was-behind-colorado-shooting-361470.html'
url142='http://www.nytimes.com/1999/04/23/us/terror-in-littleton-the-suspects-sketch-of-killers-contradictions-and-confusion.html'
url143='http://www.nytimes.com/1999/04/23/opinion/l-what-was-behind-colorado-shooting-361437.html'
url144='http://www.nytimes.com/1999/04/23/opinion/l-what-was-behind-colorado-shooting-361429.html'
url145='http://www.nytimes.com/1999/04/24/us/terror-in-littleton-excerpts-from-tape-of-2-emergency-calls-at-columbine-high.html'
url146='http://www.nytimes.com/1999/04/24/us/terror-in-littleton-the-overview-sounds-from-a-massacre-oh-god-kids-stay-down.html'
url147='http://www.nytimes.com/1999/04/24/us/terror-in-littleton-the-seniors-in-horrific-circumstance-sense-of-lost-pomp.html'
url148='http://www.nytimes.com/1999/04/24/us/religion-journal-to-the-clerics-of-littleton-words-of-experience.html'
url149='http://www.nytimes.com/1999/04/25/weekinreview/the-nation-after-the-madness-violence-even-before-the-internet.html'
url150='http://www.nytimes.com/1999/04/25/opinion/the-scourge-of-school-violence.html'
url151='http://www.nytimes.com/1999/04/25/opinion/l-access-to-guns-sets-us-apart-we-re-paying-attention-395234.html'
url152='http://www.nytimes.com/1999/04/25/us/terror-in-littleton-the-details-attack-at-school-planned-a-year-authorities-say.html'
url153='http://www.nytimes.com/1999/04/25/weekinreview/the-nation-the-trouble-with-looking-for-signs-of-trouble.html'
url154='http://www.nytimes.com/1999/04/25/us/terror-in-littleton-the-group-society-of-outcasts-began-with-a-99-black-coat.html'
url155='http://www.nytimes.com/1999/04/26/us/terror-littleton-gun-debate-renewed-battle-over-weapons-control-both-sides-use.html'
url156='http://www.nytimes.com/1999/04/26/us/terror-in-littleton-the-principal-sharing-anguish-guilt-and-hope.html'
url157='http://www.nytimes.com/1999/04/26/us/terror-in-littleton-the-gunmen-a-portrait-of-two-killers-at-war-with-themselves.html'
url158='http://www.nytimes.com/1999/04/26/us/terror-in-littleton-the-gunmen-a-portrait-of-two-killers-at-war-with-themselves.html'
url159='http://www.nytimes.com/1999/04/26/us/terror-in-littleton-the-service-70000-mourn-in-quiet-tears-song-and-rain.html'

# %%
urls=[url127,url128,url129,url130,url131,url132,url133,url134,url135,url136,url137,url138,url139,url140,
     url141,url142,url143,url144,url145,url146,url147,url148,url149,url150,url151,url152,url153,url154,url155,url156,
     url157,url158,url159,url160]
Nyt_Columbine =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Columbine= Nyt_Columbine.append([[a.title, a.text]], ignore_index=True)
Nyt_Columbine.columns=['Title','Article']
Nyt_Columbine['Incident Name'] = 'Columbine High School'
Nyt_Columbine['Shooter Race']='White'
Nyt_Columbine
# Out:
#                                                 Title  \
# 0                         Gun Spree at Columbine High
# 1   TERROR IN LITTLETON: THE SCENE; In a Violent I...
# 2   TERROR IN LITTLETON: TELEVISION -- CRITIC'S NO...
# 3                   Taking Aim at Violence in Schools
# 4   TERROR IN LITTLETON: THE OVERVIEW; 2 STUDENTS ...
# 5   TERROR IN LITTLETON: THE DEAD; Father of Victi...
# 6   TERROR IN LITTLETON: THE SUSPECTS; Portrait of...
# 7   TERROR IN LITTLETON: THE REASONS; Violence by ...
# 8   TERROR IN LITTLETON: THE SCHOOL; Good Grades, ...
# 9   TERROR IN LITTLETON: THE OVERVIEW; 15 Bodies A...
# 10                 What Was Behind Colorado Shooting?
# 11                                 The New York Times
# 12  TERROR IN LITTLETON: STUDENTS' FEARS; Though F...
# 13  TERROR IN LITTLETON: THE GUN DEBATE; Shootings...
# 14                 What Was Behind Colorado Shooting?
# 15  TERROR IN LITTLETON: THE SUSPECTS; Sketch of K...
# ...

# %%
#Wedgwood Baptist Church
url174='http://www.nytimes.com/1999/09/18/us/death-in-a-church-the-killer-a-troubled-man-went-free-as-long-as-none-were-hurt.html'
url175='http://www.nytimes.com/1999/09/17/us/deaths-church-governor-bush-blames-wave-evil-for-shootings-across-nation.html'
url176='http://www.nytimes.com/1999/09/18/us/death-in-a-church-the-faith-after-7-are-killed-texans-look-for-meaning.html'
url177='http://www.nytimes.com/1999/09/18/us/death-church-politics-gore-assails-bush-texas-law-that-permits-guns-churches.html'
url178='http://www.nytimes.com/1999/09/17/us/deaths-in-a-church-the-victims-back-to-the-flagpole-this-time-to-mourn.html'
url179='http://www.nytimes.com/1999/09/18/us/death-in-a-church-the-overview-with-question-of-why-unanswered-fort-worth-mourns.html'
url180='http://www.nytimes.com/1999/09/22/us/bush-announces-initiative-on-gun-crime.html'
url181='http://www.nytimes.com/1999/09/16/us/gunman-kills-7-and-himself-at-baptist-church-in-fort-worth.html'
url182='http://www.nytimes.com/1999/09/17/us/deaths-in-a-church-the-overview-an-angry-mystery-man-who-brought-death.html'
url183='http://www.nytimes.com/1999/09/17/opinion/grasping-the-obvious-pathology.html'
url184='http://www.nytimes.com/1999/09/20/us/fort-worth-remembers-those-killed-at-church.html'
url185='http://www.nytimes.com/1999/09/19/us/mourners-focus-on-joy-of-texas-shooting-victims-lives.html'
url186='http://www.nytimes.com/1999/09/19/weekinreview/september-12-18-and-another-shooting-spree-raises-the-toll-in-the-us.html'
urls=[url174,url175,url176,url177,url178,url178,url179,url180,url181,url182, url183,url184,url185,url186]
Nyt_WBC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WBC= Nyt_WBC.append([[a.title, a.text]], ignore_index=True)
Nyt_WBC.columns=['Title','Article']
Nyt_WBC['Incident Name'] = 'Wedgewood Baptist Church'
Nyt_WBC['Shooter Race']='White'
Nyt_WBC
# Out:
#                                                 Title  \
# 0   DEATH IN A CHURCH: THE KILLER; A Troubled Man ...
# 1   DEATHS IN A CHURCH: THE GOVERNOR; Bush Blames ...
# 2   DEATH IN A CHURCH: THE FAITH; After 7 Are Kill...
# 3   DEATH IN A CHURCH: THE POLITICS; Gore Assails ...
# 4   DEATHS IN A CHURCH: THE VICTIMS; Back to the F...
# 5   DEATHS IN A CHURCH: THE VICTIMS; Back to the F...
# 6   DEATH IN A CHURCH: THE OVERVIEW; With Question...
# 7              Bush Announces Initiative on Gun Crime
# 8   Gunman Kills 7, and Himself, At Baptist Church...
# 9   DEATHS IN A CHURCH: THE OVERVIEW; An Angry Mys...
# 10                     Grasping the Obvious Pathology
# 11        Fort Worth Remembers Those Killed at Church
# 12  Mourners Focus on Joy of Texas Shooting Victim...
# 13  September 12-18; And Another Shooting Spree Ra...
#
#                                               Article  \
# 0   Captain Denney said his department did not tak...
# ...

# %%
#Fort Gibson Middle School
url187='http://www.nytimes.com/1999/12/07/us/boy-shoots-5-schoolmates-in-oklahoma.html'
url188='http://www.nytimes.com/1999/12/12/weekinreview/december-5-11-shots-ring-out-again.html'
urls=[url187,url188]
Nyt_FGMS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FGMS= Nyt_FGMS.append([[a.title, a.text]], ignore_index=True)
Nyt_FGMS.columns=['Title','Article']
Nyt_FGMS['Incident Name'] = 'Fort Gibson Middle School'
Nyt_FGMS['Shooter Race']='White'
Nyt_FGMS
# Out:
#                                   Title  \
# 0  Boy Shoots 5 Schoolmates in Oklahoma
# 1  December 5-11; Shots Ring Out, Again
#
#                                              Article  \
# 0  Four of the victims were taken by ambulance an...
# 1  A 13-year-old boy described by friends as plea...
#
#                Incident Name Shooter Race
# 0  Fort Gibson Middle School        White
# 1  Fort Gibson Middle School        White

# %%
NYT_1990s=pd.concat([Nyt_GLO,Nyt_UofI,Nyt_RPO,Nyt_LC,Nyt_ROPO,Nyt_LHS,Nyt_PDHS,Nyt_SCS, Nyt_SRCB,Nyt_PMLLP, 
                     Nyt_DPO,Nyt_DPPO, Nyt_WSU,Nyt_LFLA, Nyt_CMS,Nyt_LIRR, Nyt_CEC,Nyt_CMHS,Nyt_URKY,Nyt_FAFB,
                     Nyt_WMS,Nyt_DCHUNC, Nyt_MPO,Nyt_WRCC, Nyt_RHS,Nyt_FJHS,Nyt_FtL, Nyt_SDSU,Nyt_BRHS, Nyt_REP,Nyt_PHS, 
                     Nyt_HHS,Nyt_MilPO,Nyt_OCT, Nyt_CTSL, Nyt_WestMS, Nyt_THS, Nyt_MAAC, Nyt_WestProm, Nyt_RBH, Nyt_XHI, Nyt_OAT, Nyt_RCH, Nyt_HerHS, Nyt_WBC, Nyt_FGMS])

# %%
for i in NYT_1990s:
    i.replace('N.R.A.','NRA')

# %%
NYT_1990s.to_csv('NYT 1990s Shootings-3.csv',index=False, encoding='utf-8')
