# %%
import pandas as pd
import newspaper
from newspaper import Article

# %%
#Edgewater Technology
url1='http://www.nytimes.com/2000/12/28/us/man-charged-in-killings-evaded-strict-gun-laws.html'
url2='http://www.nytimes.com/2000/12/27/us/7-die-in-rampage-at-company-co-worker-of-victims-arrested.html'
urls=[url1, url2]
Nyt_ET =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ET= Nyt_ET.append([[a.title, a.text]], ignore_index=True)
Nyt_ET.columns=['Title','Article']
Nyt_ET['Incident Name'] = 'Edgewater Techology'
Nyt_ET['Shooter Race']='White'
Nyt_ET
# Out:
#                                                Title  \
# 0     Man Charged In Killings Evaded Strict Gun Laws
# 1  7 Die in Rampage at Company; Co-Worker of Vict...
#
#                                              Article        Incident Name  \
# 0  If the man accused of killing seven people nea...  Edgewater Techology
# 1  ''There were receptionists, for God's sake!'' ...  Edgewater Techology
#
#   Shooter Race
# 0        White
# 1        White

# %%
url=['No Articles'] # Appalachian School oF Law
Nyt_ASL =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ASL= Nyt_ASL.append([[a.title, a.text]], ignore_index=True)
Nyt_ASL.columns=['Title','Article']
Nyt_ASL['title'] = 'NaN'
Nyt_ASL['article'] = 'NaN'
Nyt_ASL['Incident Name'] = 'Appalachian School of Law'
Nyt_ASL.drop(['Title','Article'], axis=1, inplace=True)
Nyt_ASL.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_ASL
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Navistar International Shooting
url3='http://www.nytimes.com/2001/02/07/us/gunman-s-life-came-undone-in-years-before-the-shootings.html'
url4='http://www.nytimes.com/2001/02/06/us/ex-worker-opens-fire-at-illinois-plant-5-are-killed.html'
urls=[url3, url4]
Nyt_NI =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NI= Nyt_NI.append([[a.title, a.text]], ignore_index=True)
Nyt_NI.columns=['Title','Article']
Nyt_NI['Incident Name'] = 'Navister International'
Nyt_NI['Shooter Race']='African American'
Nyt_NI
# Out:
#                                                Title  \
# 0  Gunman's Life Came Undone In Years Before the ...
# 1  Ex-Worker Opens Fire at Illinois Plant; 5 Are ...
#
#                                              Article           Incident Name  \
# 0  Mr. Baker's lawyer, Charles K. Piet, said he s...  Navister International
# 1  When the security guard refused Mr. Baker entr...  Navister International
#
#        Shooter Race
# 0  African American
# 1  African American

# %%
#Santana HS
url27='http://www.nytimes.com/2001/03/06/us/young-suspect-s-mother-asks-oh-god-why.html'
url28='http://www.nytimes.com/2001/03/06/opinion/guns-in-young-hands.html'
url29='http://www.nytimes.com/2001/03/06/us/shooting-at-school-leaves-2-dead-and-13-hurt.html'
url30='http://www.nytimes.com/2001/03/07/opinion/l-grim-lessons-at-santana-high-284211.html'
url31='http://www.nytimes.com/2001/03/07/opinion/l-grim-lessons-at-santana-high-284238.html'
url32='http://www.nytimes.com/2001/03/07/opinion/l-grim-lessons-at-santana-high-284254.html'
url33='http://www.nytimes.com/2001/03/07/us/shooting-was-planned-and-calmly-carried-out-police-say.html'
url34='http://www.nytimes.com/2001/03/07/opinion/l-grim-lessons-at-santana-high-284203.html'
url35='http://www.nytimes.com/2001/03/07/us/rampage-took-the-lives-of-a-trouper-and-of-the-nicest-guy-in-the-world.html'
url36='http://www.nytimes.com/2001/03/07/opinion/l-grim-lessons-at-santana-high-284220.html'
url37='http://www.nytimes.com/2001/03/07/us/plenty-of-vivid-adjectives-but-no-answers-in-killings.html'
url38='http://www.nytimes.com/2001/03/08/opinion/threats-of-school-violence.html'
url39='http://www.nytimes.com/2001/03/08/us/student-held-in-shootings-is-in-court-as-school-resumes.html'
url40='http://www.nytimes.com/2001/03/09/opinion/l-get-to-troubled-kids-before-they-start-shooting-320196.html'
url41='http://www.nytimes.com/2001/03/09/opinion/l-get-to-troubled-kids-before-they-start-shooting-320200.html'
url42='http://www.nytimes.com/2001/03/09/opinion/l-get-to-troubled-kids-before-they-start-shooting-320226.html'
url43='http://www.nytimes.com/2001/03/09/opinion/l-get-to-troubled-kids-before-they-start-shooting-320218.html'
url44='http://www.nytimes.com/2001/03/09/us/santee-is-latest-blow-to-myth-of-suburbia-s-safer-schools.html'
url45='http://www.nytimes.com/2001/03/10/us/from-almost-famous-to-ordinary-in-3-days.html'
url46='http://www.nytimes.com/2001/03/10/opinion/a-brain-too-young-for-good-judgment.html'
url47='https://learning.blogs.nytimes.com/2001/03/12/big-bang-theory/'
url48='http://www.nytimes.com/2001/03/11/us/others-tragedies-helped-santee-prepare-for-its-own.html'
urls=[url27, url28,url29,url30,url31,url32,url33,url34,url35,url36,url37,url38,url39,url40,url41,url42,
     url43,url44,url45,url46,url47,url48]
Nyt_SHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SHS= Nyt_SHS.append([[a.title, a.text]], ignore_index=True)
Nyt_SHS.columns=['Title','Article']
Nyt_SHS['Incident Name'] = 'Santana High School'
Nyt_SHS['Shooter Race']='White'
Nyt_SHS
# Out:
#                                                 Title  \
# 0        Young Suspect's Mother Asks, 'Oh, God. Why?'
# 1                                 Guns in Young Hands
# 2        Shooting at School Leaves 2 Dead and 13 Hurt
# 3                        Grim Lessons at Santana High
# 4                        Grim Lessons at Santana High
# 5                        Grim Lessons at Santana High
# 6   Shooting Was Planned and Calmly Carried Out, P...
# 7                        Grim Lessons at Santana High
# 8   Rampage Took the Lives of a 'Trouper' and of '...
# 9                        Grim Lessons at Santana High
# 10  Plenty of Vivid Adjectives But No Answers in K...
# 11                         Threats of School Violence
# 12  Student Held in Shootings Is in Court as Schoo...
# 13    Get to Troubled Kids Before They Start Shooting
# 14    Get to Troubled Kids Before They Start Shooting
# 15    Get to Troubled Kids Before They Start Shooting
# ...

# %%
#University of Arizona
url5='http://www.nytimes.com/2002/10/29/us/student-kills-3-instructors-and-himself-at-u-of-arizona.html'
Nyt_UofA =pd.DataFrame()
a=Article(url5, language='en')
a.download()
a.parse()
Nyt_UofA= Nyt_UofA.append([[a.title, a.text]], ignore_index=True)
Nyt_UofA.columns=['Title','Article']
Nyt_UofA['Incident Name'] = 'University of Arizona'
Nyt_UofA['Shooter Race']='Latin American'
Nyt_UofA
# Out:
#                                                Title  \
# 0  Student Kills 3 Instructors and Himself at U. ...
#
#                                              Article          Incident Name  \
# 0  But before they responded, the police said, Mr...  University of Arizona
#
#      Shooter Race
# 0  Latin American

# %%
#Case Western Reserve Shooting
url6='http://www.nytimes.com/2003/05/11/us/ex-employee-held-in-campus-attack.html'
Nyt_CARU =pd.DataFrame()
a=Article(url6, language='en')
a.download()
a.parse()
Nyt_CARU= Nyt_CARU.append([[a.title, a.text]], ignore_index=True)
Nyt_CARU.columns=['Title','Article']
Nyt_CARU['Incident Name'] = 'Case Western Reserve'
Nyt_CARU['Shooter Race']='Asian'
Nyt_CARU
# Out:
#                                Title  \
# 0  Ex-Employee Held in Campus Attack
#
#                                              Article         Incident Name  \
# 0  In letters to Cleveland officials posted on th...  Case Western Reserve
#
#   Shooter Race
# 0        Asian

# %%
#Lockhed Martin Shooting
url7='http://www.nytimes.com/2003/07/09/us/man-kills-5-co-workers-at-plant-and-himself.html'
url8='http://www.nytimes.com/2003/07/10/us/factory-killer-had-a-known-history-of-anger-and-racial-taunts.html'
urls=[url7, url8]
Nyt_LM =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LM= Nyt_LM.append([[a.title, a.text]], ignore_index=True)
Nyt_LM.columns=['Title','Article']
Nyt_LM['Incident Name'] = 'Lockheed Martin'
Nyt_LM['Shooter Race']='White'
Nyt_LM
# Out:
#                                                Title  \
# 0        Man Kills 5 Co-Workers at Plant and Himself
# 1  Factory Killer Had a Known History of Anger an...
#
#                                              Article    Incident Name  \
# 0  ''He was trying to shoot Steve Cobb, the plant...  Lockheed Martin
# 1  Co-workers said Mr. Williams's racial prejudic...  Lockheed Martin
#
#   Shooter Race
# 0        White
# 1        White

# %%
#Windy City Core Supply
url9='http://www.nytimes.com/2003/08/28/us/man-fired-by-warehouse-kills-6-of-its-9-employees.html'
Nyt_WCC =pd.DataFrame()
a=Article(url9, language='en')
a.download()
a.parse()
Nyt_WCC= Nyt_WCC.append([[a.title, a.text]], ignore_index=True)
Nyt_WCC.columns=['Title','Article']
Nyt_WCC['Incident Name'] = 'Windy City Core Supply'
Nyt_WCC['Shooter Race']='Latin American'
Nyt_WCC
# Out:
#                                                Title  \
# 0  Man Fired by Warehouse Kills 6 of Its 9 Employees
#
#                                              Article           Incident Name  \
# 0  The police said Mr. Tapia had made threatening...  Windy City Core Supply
#
#      Shooter Race
# 0  Latin American

# %%
#Birchwood Wisconsin
url=['No Articles'] 
Nyt_BW =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_BW= Nyt_BW.append([[a.title, a.text]], ignore_index=True)
Nyt_BW.columns=['Title','Article']
Nyt_BW['title'] = 'NaN'
Nyt_BW['article'] = 'NaN'
Nyt_BW['Incident Name'] = 'Birchwood, Wisconsin'
Nyt_BW.drop(['Title','Article'], axis=1, inplace=True)
Nyt_BW.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_BW
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Alrosa Villa Shoooting
url10='http://www.nytimes.com/2004/12/10/us/after-a-concert-shooting-a-who-but-not-a-why.html'
url11='http://www.nytimes.com/2004/12/10/arts/music/darrell-abbott-38-a-guitarist-featured-in-heavymetal-bands-dies.html'
url12='http://www.nytimes.com/2004/12/11/us/taped-calls-describe-chaotic-scene-at-ohio-nightclub-shooting.html'
url13='http://www.nytimes.com/2004/12/11/arts/dimebag-darrells-fans-fill-heavymetal-sites-with-internet-eulogies.html'
urls=[url10, url11,url12,url13]
Nyt_AV =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AV= Nyt_AV.append([[a.title, a.text]], ignore_index=True)
Nyt_AV.columns=['Title','Article']
Nyt_AV['Incident Name'] = 'Alrosa Villa'
Nyt_AV['Shooter Race']='White'
Nyt_AV
# Out:
#                                                Title  \
# 0  After a Concert Shooting, a 'Who' but Not a 'Why'
# 1  Darrell Abbott, 38, a Guitarist Featured in He...
# 2  Taped Calls Describe Chaotic Scene at Ohio Nig...
# 3  Dimebag Darrell's Fans Fill Heavy-Metal Sites ...
#
#                                              Article Incident Name  \
# 0  The police said they were chasing down tips th...  Alrosa Villa
# 1  Correction Appended\n\nDarrell Abbott, the bee...  Alrosa Villa
# 2  As a man jumped onto a nightclub stage in Colu...  Alrosa Villa
# 3  The band's official fan Web site, damageplan.n...  Alrosa Villa
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White

# %%
#Brookfield Shooting
url14='http://www.nytimes.com/2005/03/18/us/rampage-puts-spotlight-on-a-church-community.html'
url15='https://query.nytimes.com/gst/fullpage.html?res=9B0CE5DC153CF930A25750C0A9639C8B63'
url16='http://www.nytimes.com/2005/03/14/us/after-shootings-in-wisconsin-a-community-asks-why.html'
url17='http://www.nytimes.com/2005/03/15/us/police-focus-on-religion-in-milwaukee-shootings.html'
urls=[url14, url15,url16,url17]
Nyt_Brook =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Brook= Nyt_Brook.append([[a.title, a.text]], ignore_index=True)
Nyt_Brook.columns=['Title','Article']
Nyt_Brook['Incident Name'] = 'Living Church of God'
Nyt_Brook['Shooter Race']='White'
Nyt_Brook
# Out:
#                                                Title  \
# 0       Rampage Puts Spotlight on a Church Community
# 1      GUNMAN KILLS 7 IN CHURCH GROUP NEAR MILWAUKEE
# 2  After Shootings in Wisconsin, a Community Asks...
# 3    Police Focus on Religion in Milwaukee Shootings
#
#                                              Article         Incident Name  \
# 0  Glen Gilchrist, a church pastor for Arizona an...  Living Church of God
# 1  An evangelical church meeting turned chaotic a...  Living Church of God
# 2  "Sometimes he was up and sometimes he was down...  Living Church of God
# 3  Investigators are combing through some 1,000 e...  Living Church of God
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White

# %%
#RedLake HS
url18='https://query.nytimes.com/gst/fullpage.html?res=9C0CE4DA1F3CF931A15750C0A9639C8B63'
url19='http://www.nytimes.com/2005/03/26/us/family-wonders-if-prozac-prompted-school-shootings.html'
url20='http://www.nytimes.com/2005/03/25/us/survivors-of-high-school-rampage-left-with-injuries-and-questions.html'
url21='http://www.nytimes.com/2005/03/24/us/days-after-killings-a-tribe-seeks-a-cloak-of-privacy-for-its-grief.html'
url22='http://www.nytimes.com/2005/03/24/us/signs-of-danger-were-missed-in-a-troubled-teenagers-life.html'
url23='https://learning.blogs.nytimes.com/2005/03/23/nightmare-in-minnesota/'
url24='http://www.nytimes.com/2005/03/23/us/eerie-parallels-are-seen-to-shootings-at-columbine.html'
url25='http://www.nytimes.com/2005/03/23/us/behind-the-why-of-a-rampage-loner-with-a-taste-for-nazism.html'
url26='http://www.nytimes.com/2005/03/27/us/tribe-buries-3-on-a-long-road-to-healing.html'
urls=[url18, url19,url20,url21,url22,url23,url24,url25,url26]
Nyt_RHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_RHS= Nyt_RHS.append([[a.title, a.text]], ignore_index=True)
Nyt_RHS.columns=['Title','Article']
Nyt_RHS['Incident Name'] = 'Red Lake High School'
Nyt_RHS['Shooter Race']='Native American or Alaska Native'
Nyt_RHS
# Out:
#                                                Title  \
# 0  Shooting Rampage by Student Leaves 10 Dead on ...
# 1  Family Wonders if Prozac Prompted School Shoot...
# 2  Survivors of High School Rampage Left With Inj...
# 3  Days After Killings, a Tribe Seeks a Cloak of ...
# 4  Signs of Danger Were Missed in a Troubled Teen...
# 5                             Nightmare in Minnesota
# 6  Eerie Parallels Are Seen to Shootings at Colum...
# 7  Behind the Why of a Rampage, Loner With a Tast...
# 8           Tribe Buries 3 on a Long Road to Healing
#
#                                              Article         Incident Name  \
# 0  Correction Appended\n\nA high school student w...  Red Lake High School
# 1  The effects of antidepressants on young people...  Red Lake High School
# 2  Cody, who spoke to reporters on Thursday from ...  Red Lake High School
# 3  "We didn't ask for those boundaries -- they we...  Red Lake High School
# ...

# %%
#Goleta PO
url49='http://www.nytimes.com/2006/02/03/us/woman-in-california-postal-shootings-had-history-of-bizarre-behavior.html'
Nyt_GPO =pd.DataFrame()
a=Article(url49, language='en')
a.download()
a.parse()
Nyt_GPO= Nyt_GPO.append([[a.title, a.text]], ignore_index=True)
Nyt_GPO.columns=['Title','Article']
Nyt_GPO['Incident Name'] = 'Goleta Post Office'
Nyt_GPO['Shooter Race']='White'
Nyt_GPO
# Out:
#                                                Title  \
# 0  Woman in California Postal Shootings Had Histo...
#
#                                              Article       Incident Name  \
# 0  "It seemed liked she was acting delusional," M...  Goleta Post Office
#
#   Shooter Race
# 0        White

# %%
#Seattle House Party
url50='http://www.nytimes.com/2006/03/26/us/7-dead-in-shooting-at-seattle-house-party.html'
Nyt_SHP =pd.DataFrame()
a=Article(url50, language='en')
a.download()
a.parse()
Nyt_SHP= Nyt_SHP.append([[a.title, a.text]], ignore_index=True)
Nyt_SHP.columns=['Title','Article']
Nyt_SHP['Incident Name'] = 'Seattle House Party'
Nyt_SHP['Shooter Race']='White'
Nyt_SHP
# Out:
#                                        Title  \
# 0  7 Dead in Shooting at Seattle House Party
#
#                                              Article        Incident Name  \
# 0  He then spotted the gunman standing outside th...  Seattle House Party
#
#   Shooter Race
# 0        White

# %%
#Essex Elementary
url51='http://www.nytimes.com/2006/08/25/us/25brfs-002.html'
Nyt_EES =pd.DataFrame()
a=Article(url51, language='en')
a.download()
a.parse()
Nyt_EES= Nyt_EES.append([[a.title, a.text]], ignore_index=True)
Nyt_EES.columns=['Title','Article']
Nyt_EES['Incident Name'] = 'Essex Elementary School'
Nyt_EES['Shooter Race']='African American'
Nyt_EES
# Out:
#                        Title  \
# 0  Vermont: Gunman Kills Two
#
#                                              Article            Incident Name  \
# 0  Hours after breaking up with his girlfriend, a...  Essex Elementary School
#
#        Shooter Race
# 0  African American

# %%
#Orange HS
url52='http://www.nytimes.com/2006/09/01/us/01shooting.html'
Nyt_OHS =pd.DataFrame()
a=Article(url52, language='en')
a.download()
a.parse()
Nyt_OHS= Nyt_OHS.append([[a.title, a.text]], ignore_index=True)
Nyt_OHS.columns=['Title','Article']
Nyt_OHS['Incident Name'] = 'Orange High School'
Nyt_OHS['Shooter Race']='Latin American'
Nyt_OHS
# Out:
#                                        Title  \
# 0  Teenager Is Accused of Multiple Shootings
#
#                                              Article       Incident Name  \
# 0  HILLSBOROUGH, N.C., Aug. 31 (AP) — A teenager ...  Orange High School
#
#      Shooter Race
# 0  Latin American

# %%
#Duquesne University
url53='http://www.nytimes.com/2006/09/19/us/19duquesne.html'
url54='http://www.nytimes.com/2006/09/19/us/19cnd-shoot.html'
url55='http://www.nytimes.com/2006/09/20/us/20duquesne.html'
url56='http://www.nytimes.com/2006/09/21/us/21duquesne.html'
urls=[url53, url54,url55,url56]
Nyt_DU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_DU= Nyt_DU.append([[a.title, a.text]], ignore_index=True)
Nyt_DU.columns=['Title','Article']
Nyt_DU['Incident Name'] = 'Duquesne University'
Nyt_DU['Shooter Race']='African American'
Nyt_DU
# Out:
#                                                Title  \
# 0  An Eerie Quiet at Duquesne After 5 Students Ar...
# 1                  Suspect Held in Duquesne Shooting
# 2  After Arrest, a 2nd Suspect Is Sought in Duque...
# 3              2nd Arrest Is Made in Duquesne Attack
#
#                                              Article        Incident Name  \
# 0  Mr. Dougherty added that while officials would...  Duquesne University
# 1  PITTSBURGH, Sept. 19 — A man suspected in the ...  Duquesne University
# 2  The other person being sought was identified a...  Duquesne University
# 3  By The New York Times\n\nPITTSBURGH, Sept. 20 ...  Duquesne University
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American
# 3  African American

# %%
#Amish School
url61='http://www.nytimes.com/2006/10/02/us/03amishcnd.html'
url62='http://www.nytimes.com/2006/10/03/us/04amishcnd.html'
url63='http://www.nytimes.com/2006/10/03/opinion/03tue4.html'
url64='http://www.nytimes.com/2006/10/03/us/03amish.html'
url65='http://www.nytimes.com/2006/10/04/us/04amish.html'
url66='http://www.nytimes.com/2006/10/04/us/04children.html'
url67='http://www.nytimes.com/2006/10/05/us/05amish.html'
urls=[url61, url62,url63,url64,url65,url66,url67]
Nyt_Amish =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Amish= Nyt_Amish.append([[a.title, a.text]], ignore_index=True)
Nyt_Amish.columns=['Title','Article']
Nyt_Amish['Incident Name'] = 'West Nickel Mines Amish School'
Nyt_Amish['Shooter Race']='White'
Nyt_Amish
# Out:
#                                                Title  \
# 0     Students Killed by Gunman at Amish Schoolhouse
# 1                      Gunman May Have Planned Abuse
# 2                             Three School Shootings
# 3    Man Shoots 11, Killing 5 Girls, in Amish School
# 4  Strong Faith and Community May Help Amish Cope...
# 5      Police Describe Gunman’s Plan in School Siege
# 6     Amish School Survivors Struggle After Killings
#
#                                              Article  \
# 0  A lone gunman walked into a one-room schoolhou...
# 1  Five more girls were wounded Monday, and some ...
# 2  No one will rise up to defend a man who walks ...
# 3  Mr. Roberts had no criminal record or history ...
# 4  About 28,000 Amish live in Lancaster County, a...
# 5  With their traditional garb and religious dict...
# 6  “They talked with this gunman and asked him wh...
#
#                     Incident Name Shooter Race
# 0  West Nickel Mines Amish School        White
# ...

# %%
#Trolley Square UT
url57='http://www.nytimes.com/2007/02/13/us/14slaycnd.html'
url58='http://www.nytimes.com/2007/02/13/us/13slay.html'
url59='http://www.nytimes.com/2007/02/14/us/14mall.html'
url60='http://www.nytimes.com/2007/02/15/us/15mall.html'
urls=[url57, url58,url59,url60]
Nyt_TSUT =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_TSUT= Nyt_TSUT.append([[a.title, a.text]], ignore_index=True)
Nyt_TSUT.columns=['Title','Article']
Nyt_TSUT['Incident Name'] = 'Trolley Square Utah'
Nyt_TSUT['Shooter Race']='White'
Nyt_TSUT
# Out:
#                                                Title  \
# 0                  Armed Man Kills 5 at Mall in Utah
# 1              Armed Man Kills 5 People at Utah Mall
# 2  Sense of Loss and Unease After Salt Lake Slayings
# 3               Anti-Bosnian Backlash Feared in Utah
#
#                                              Article        Incident Name  \
# 0  Marie Smith, a manager at the Bath and Body Wo...  Trolley Square Utah
# 1  Ms. Smith, 23, said she had made eye contact w...  Trolley Square Utah
# 2  No motive has been established, Chief Burbank ...  Trolley Square Utah
# 3  Ms. Roth said she received six reports on Wedn...  Trolley Square Utah
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White

# %%
#Springwater Trail
url=['No Articles'] 
Nyt_SWT =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SWT= Nyt_SWT.append([[a.title, a.text]], ignore_index=True)
Nyt_SWT.columns=['Title','Article']
Nyt_SWT['title'] = 'NaN'
Nyt_SWT['article'] = 'NaN'
Nyt_SWT['Incident Name'] = 'Springwater Trail'
Nyt_SWT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_SWT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
Nyt_SWT
# Out:
#   Title Article      Incident Name
# 0   NaN     NaN  Springwater Trail

# %%
#Virginia Tech Urls
url68='http://www.nytimes.com/2007/04/16/us/16cnd-shooting.html'
url69='http://www.nytimes.com/2007/04/16/washington/17attorneyscnd.html'
url70='http://www.nytimes.com/2007/04/17/us/17scene.html'
url71='https://thelede.blogs.nytimes.com/2007/04/16/shooting-at-virginia-tech/'
url72='https://query.nytimes.com/gst/fullpage.html?res=9D03E4D8113FF934A25757C0A9619C8B63'
url73='http://www.nytimes.com/2007/04/17/opinion/17tue1.html'
url74='http://www.nytimes.com/2007/04/17/us/17cnd-ROOMMATE.html'
url75='http://www.nytimes.com/2007/04/17/us/17cnd-shooter.html'
url76='http://www.nytimes.com/2007/04/17/us/17tvwatch.html'
url77='http://www.nytimes.com/2007/04/17/us/17cnd-virginia.html'
url78='https://query.nytimes.com/gst/fullpage.html?res=9F01E1D7113FF934A25757C0A9619C8B63'
url79='http://www.nytimes.com/2007/04/17/us/18bloggerscnd.html'
url80='http://www.nytimes.com/2007/04/17/us/17cnd-victims.html'
url81='http://www.nytimes.com/2007/04/17/us/17virginia.html'
url82='http://www.nytimes.com/2007/04/17/us/shootings-timeline.html'
url83='http://www.nytimes.com/2007/04/17/us/18gunmanCND.html'
url84='http://www.nytimes.com/2007/04/17/us/17victims.html'
url85='https://thecaucus.blogs.nytimes.com/2007/04/17/obama-postpones-speech/'
url86='https://empirezone.blogs.nytimes.com/2007/04/17/bloomberg-a-day-to-grieve-and-pray/'
url87='https://learning.blogs.nytimes.com/2007/04/18/campus-catastrophe/'
url88='http://www.nytimes.com/2007/04/18/us/18campus.html'
url89='http://www.nytimes.com/2007/04/18/us/18mental.html'
url90='http://www.nytimes.com/2007/04/18/opinion/l18virginia.html'
url91='http://www.nytimes.com/2007/04/18/us/18pistols.html'
url92='http://www.nytimes.com/2007/04/18/us/18virginia.html'
url93='https://query.nytimes.com/gst/fullpage.html?res=9807E6DC1E3FF93BA25757C0A9619C8B63'
url94='https://query.nytimes.com/gst/fullpage.html?res=9E04E6DB1E3FF93BA25757C0A9619C8B63'
url95='http://www.nytimes.com/2007/04/18/world/asia/18cnd-korea.html'
url96='https://query.nytimes.com/gst/fullpage.html?res=9C0DE1DC1E3FF93BA25757C0A9619C8B63'
url97='http://www.nytimes.com/2007/04/18/us/18school.html'
url98='http://www.nytimes.com/2007/04/18/us/18cnd-virginia.html'
url99='https://thelede.blogs.nytimes.com/2007/04/18/updates-on-virginia-tech/'
url100='https://opinionator.blogs.nytimes.com/2007/04/18/searching-for-a-scapegoat/'
url101='http://www.nytimes.com/2007/04/19/us/19gunman.html'
url102='http://www.nytimes.com/2007/04/19/opinion/l19virginia.html'
url103='http://www.nytimes.com/2007/04/19/arts/19scre.html'
url104='http://www.nytimes.com/2007/04/19/arts/television/19watc.html'
url105='http://www.nytimes.com/2007/04/19/us/19cnd-Virginia.html'
url106='http://www.nytimes.com/2007/04/19/us/19korea.html'
url107='http://www.nytimes.com/2007/04/19/us/19professor.html'
url108='http://www.nytimes.com/2007/04/19/us/19grief.html'
url109='https://query.nytimes.com/gst/fullpage.html?res=9B05E0D81E3FF93AA25757C0A9619C8B63'
url110='http://www.nytimes.com/2007/04/19/us/19nbc.html'
url111='https://thelede.blogs.nytimes.com/2007/04/19/chos-manifesto-everywhere/'
url112='http://www.nytimes.com/2007/04/20/us/20cnd-virginia.html'
url113='http://www.nytimes.com/2007/04/20/us/20radio.html'
url114='http://www.nytimes.com/2007/04/20/us/20virginia.html'
url115='http://www.nytimes.com/2007/04/20/us/20english.html'
url116='http://www.nytimes.com/2007/04/20/opinion/20whitcomb.html'
url117='https://learning.blogs.nytimes.com/2007/04/20/feeling-for-answers/'
url118='https://thegraduates.blogs.nytimes.com/2007/04/20/a-killers-media-wish-fulfilled/'
url119='http://www.nytimes.com/2007/04/21/us/21virginia.html'
url120='http://www.nytimes.com/2007/04/22/us/22vatech.html'
url121='http://www.nytimes.com/2007/04/22/education/edlife/pappano.html'
url122='http://www.nytimes.com/2007/04/22/weekinreview/22carey.html'
url123='http://www.nytimes.com/2007/04/23/us/23church.html'
url124='http://www.nytimes.com/2007/04/23/movies/23movi.html'
url125='http://www.nytimes.com/2007/04/23/us/23cnd-virginia.html'

# %%
#Virginia Tech
urls=[url68, url69,url70,url71,url72,url73,url74,url75,url76,url77,url78,url79,url80,url81,url82,url83,url84,url85,
     url86,url87,url88,url89,url90,url91,url92,url93,url94,url95,url96,url97,url98,url99,url100,url101,url102,url103
     ,url104,url105,url106,url107,url108,url109,url110,url111,url112,url113,url114,url115,url116,url117,url118,url119,
     url120,url121,url122,url123,url124,url125]
Nyt_VT =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_VT= Nyt_VT.append([[a.title, a.text]], ignore_index=True)
Nyt_VT.columns=['Title','Article']
Nyt_VT['Incident Name'] = 'Virginia Tech University'
Nyt_VT['Shooter Race']='Asian'
Nyt_VT
# Out:
#                                                 Title  \
# 0               Virginia Tech Shooting Leaves 33 Dead
# 1   Gonzales Hearing Delayed After Virginia Tech S...
# 2       Drumbeat of Shots, Broken by Pauses to Reload
# 3                           Shooting at Virginia Tech
# 4                                QUOTATION OF THE DAY
# 5                         Eight Years After Columbine
# 6                  Roommates Describe Gunman as Loner
# 7   Gunman Is Described as Quiet and 'Always by Hi...
# 8                Deadly Rampage and No Loss for Words
# 9                  Faculty Was Concerned About Gunman
# 10                           32 Shot Dead in Virginia
# 11     Campus Goes Online for Information and Comfort
# 12                              Virginia Tech Victims
# 13            Virginia Gunman Identified as a Student
# 14                       Major Fatal Campus Shootings
# 15                     Gunman Was ‘Always by Himself’
# ...

# %%
#Crandon WI
url126='http://www.nytimes.com/2007/10/08/us/08wisconsin.html'
url127='http://www.nytimes.com/2007/10/08/us/08cnd-shoot.html'
url128='http://www.nytimes.com/2007/10/09/us/09rampage.html'
url129='http://www.nytimes.com/2007/10/10/us/10rampage.html'
urls=[url126,url127,url128,url129]
Nyt_CWI =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CWI= Nyt_CWI.append([[a.title, a.text]], ignore_index=True)
Nyt_CWI.columns=['Title','Article']
Nyt_CWI['Incident Name'] = 'Apt in Crandon, WI'
Nyt_CWI['Shooter Race']='White'
Nyt_CWI
# Out:
#                                                Title  \
# 0                 Gunman Kills Six in Wisconsin Town
# 1             Dispute Is Cited in Wisconsin Shooting
# 2  A Tiny Town, Suddenly Smaller by Seven, Mourns...
# 3  Gunman in Rampage Had Been Certified to Be an ...
#
#                                              Article       Incident Name  \
# 0  CRANDON, Wis., Oct. 7 (AP) — An off-duty sheri...  Apt in Crandon, WI
# 1  Some kind of dispute was behind the massacre e...  Apt in Crandon, WI
# 2  Before 3 a.m. Sunday, state authorities said, ...  Apt in Crandon, WI
# 3  But state officials, who are leading the inves...  Apt in Crandon, WI
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White

# %%
#Cleveland HS
url130='http://www.nytimes.com/2007/10/11/us/11cleveland.html'
url131='http://www.nytimes.com/2007/10/12/us/12cleveland.html'
urls=[url130,url131]
Nyt_CHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CHS= Nyt_CHS.append([[a.title, a.text]], ignore_index=True)
Nyt_CHS.columns=['Title','Article']
Nyt_CHS['Incident Name'] = 'SuccessTech Academy'
Nyt_CHS['Shooter Race']='White'
Nyt_CHS
# Out:
#                                                Title  \
# 0  Student, 14, Shoots 4 and Kills Himself in Cle...
# 1  Short but Troubled Life Ended in Shooting and ...
#
#                                              Article        Incident Name  \
# 0  Mychael said she darted down a flight of stair...  SuccessTech Academy
# 1  After looking at the swarm of police cars arri...  SuccessTech Academy
#
#   Shooter Race
# 0        White
# 1        White

# %%
#Sagina MI
url132='https://query.nytimes.com/gst/fullpage.html?res=9A03EED91230F936A15753C1A9619C8B63'
Nyt_SMI =pd.DataFrame()
a=Article(url132, language='en')
a.download()
a.parse()
Nyt_SMI= Nyt_SMI.append([[a.title, a.text]], ignore_index=True)
Nyt_SMI.columns=['Title','Article']
Nyt_SMI['Incident Name'] = 'South Middle School Football Game'
Nyt_SMI['Shooter Race']='African American'
Nyt_SMI
# Out:
#                                      Title  \
# 0  4 ARE SHOT AT FOOTBALL GAME IN MICHIGAN
#
#                                              Article  \
# 0  \n\n\n\nPhoto: Four students at a middle schoo...
#
#                        Incident Name      Shooter Race
# 0  South Middle School Football Game  African American

# %%
#Westroads Mall
url244='http://www.nytimes.com/2007/12/09/us/09mall.html'
url245='http://www.nytimes.com/2007/12/06/us/06omaha.html'
url246='http://www.nytimes.com/2007/12/06/us/06cnd-shoot.html'
url247='http://www.nytimes.com/2007/12/07/us/07store.html'
url248='http://www.nytimes.com/2007/12/07/us/07mall.html'
urls=[url244,url245,url246,url247,url248]
Nyt_WM =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_WM= Nyt_WM.append([[a.title, a.text]], ignore_index=True)
Nyt_WM.columns=['Title','Article']
Nyt_WM['Incident Name'] = 'Westroads Mall'
Nyt_WM['Shooter Race']='White'
Nyt_WM
# Out:
#                                                Title  \
# 0  Three Days After Killings, Mall Re-Opens for B...
# 1        Gunman at an Omaha Mall Kills 8 and Himself
# 2                   Details of Omaha Shooting Emerge
# 3     Stylish Surroundings Are Shattered by Killings
# 4  Searching for Clues to a Young Killer’s Motiva...
#
#                                              Article   Incident Name  \
# 0  OMAHA, Dec. 8 (AP) — With extra security on ha...  Westroads Mall
# 1  The group pushed every table, rack and garbage...  Westroads Mall
# 2  “These were innocent people going about their ...  Westroads Mall
# 3  Janice Hopkins, who had taken a seasonal job w...  Westroads Mall
# 4  In the aftermath of the shooting, the picture ...  Westroads Mall
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White
# 4        White

# %%
#Arvada, CO
url133='http://www.nytimes.com/2007/12/10/us/10shooting.html'
url134='http://www.nytimes.com/2007/12/10/us/10cnd-shoot.html'
url135='http://www.nytimes.com/2007/12/11/us/11churches.html'
urls=[url133,url134,url135]
Nyt_ACO =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_ACO= Nyt_ACO.append([[a.title, a.text]], ignore_index=True)
Nyt_ACO.columns=['Title','Article']
Nyt_ACO['Incident Name'] = 'Youth with a Mission and New Life Church'
Nyt_ACO['Shooter Race']='White'
Nyt_ACO
# Out:
#                                                Title  \
# 0      2 Fatal Shootings at Colorado Religious Sites
# 1     Man Committed Both Colo. Shootings, Police Say
# 2  Police Tie Colorado Church Shootings to One Gu...
#
#                                              Article  \
# 0  Photo\n\nA gunman and four people were killed ...
# 1  The security guard who shot and killed Mr. Mur...
# 2  Officials said they were still investigating w...
#
#                               Incident Name Shooter Race
# 0  Youth with a Mission and New Life Church        White
# 1  Youth with a Mission and New Life Church        White
# 2  Youth with a Mission and New Life Church        White

# %%
#Tyler Tex 
url136='http://www.nytimes.com/2005/02/27/national/killings-rattle-an-east-texas-town-better-known-for-its-roses.html?mcubz=0&_r=0'
Nyt_SCC =pd.DataFrame()
a=Article(url136, language='en')
a.download()
a.parse()
Nyt_SCC= Nyt_SCC.append([[a.title, a.text]], ignore_index=True)
Nyt_SCC.columns=['Title','Article']
Nyt_SCC['Incident Name'] = 'Smith County Courthouse'
Nyt_SCC['Shooter Race']='Latin American'
Nyt_SCC
# Out:
#                                                Title  \
# 0  Killings Rattle an East Texas Town Better Know...
#
#                                              Article            Incident Name  \
# 0  >\n\nTYLER, Tex., Feb. 26 (AP) - Blake Bailey ...  Smith County Courthouse
#
#      Shooter Race
# 0  Latin American

# %%
#Lakewood Coffee Shop
url137='https://query.nytimes.com/gst/fullpage.html?res=9D01E5DA1E3DF933A05752C1A96F9C8B63'
url138='http://www.nytimes.com/2009/12/01/us/01tacoma.html'
url139='http://www.nytimes.com/2009/12/02/us/02tacoma.html'
url140='http://www.nytimes.com/2009/12/04/us/04brfs-CHARGEDINPOL_BRF.html'
urls=[url137,url138,url139,url140]
Nyt_LC =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_LC= Nyt_LC.append([[a.title, a.text]], ignore_index=True)
Nyt_LC.columns=['Title','Article']
Nyt_LC['Incident Name'] = 'Parkland Coffee Shop'
Nyt_LC['Shooter Race']='African American'
Nyt_LC
# Out:
#                                                Title  \
# 0        4 Police Officers Die in Coffee Shop Ambush
# 1  Tacoma Suspect Said to Threaten to Shoot Officers
# 2  Suspect Slain in Seattle; 4 Are Held as Flight...
# 3              Washington: Charged in Police Killing
#
#                                              Article         Incident Name  \
# 0  Four uniformed police officers were shot to de...  Parkland Coffee Shop
# 1  The police offered a reward of $125,000 for in...  Parkland Coffee Shop
# 2  Charging documents describe a series of car ri...  Parkland Coffee Shop
# 3  A half brother of the man accused of gunning d...  Parkland Coffee Shop
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American
# 3  African American

# %%
#Fort Hood URLS
url141='https://thelede.blogs.nytimes.com/2009/11/05/reports-of-mass-shooting-at-fort-hood/'
url142='http://www.nytimes.com/2009/11/06/us/06forthood.html'
url143='http://www.nytimes.com/2009/11/06/us/06suspect.html'
url144='http://www.nytimes.com/2009/11/06/us/06victims.html'
url145='https://thelede.blogs.nytimes.com/2009/11/06/latest-updates-on-shootings-at-fort-hood/'
url146='https://learning.blogs.nytimes.com/2009/11/06/responding-to-news-of-the-shootings-at-fort-hood/'
url147='http://www.nytimes.com/2009/11/07/us/07forthood.html'
url148='http://www.nytimes.com/2009/11/07/us/07suspect.html'
url149='https://atwar.blogs.nytimes.com/2009/11/06/coverage-of-the-fort-hood-shootings/'
url150='http://www.nytimes.com/2009/11/07/us/07victims.html'
url151='http://www.nytimes.com/2009/11/07/us/07police.html'
url152='https://mediadecoder.blogs.nytimes.com/2009/11/06/fox-news-channel-draws-a-large-audience-for-coverage-of-fort-hood-shootings/'
url153='https://roomfordebate.blogs.nytimes.com/2009/11/06/combat-stress-and-the-fort-hood-gunman/'
url154='http://www.nytimes.com/2009/11/07/us/07scene.html'
url155='http://www.nytimes.com/2009/11/07/opinion/07cleland.html'
url156='http://www.nytimes.com/2009/11/07/us/07muslim.html'
url157='http://www.nytimes.com/2009/11/08/us/politics/08address.html'
url158='https://thecaucus.blogs.nytimes.com/2009/11/07/saturday-word-fort-hood-and-health-care/'
url159='https://prescriptions.blogs.nytimes.com/2009/11/07/obamas-in-the-house/'
url160='http://www.nytimes.com/2009/11/08/weekinreview/08goode.html'
url161='http://www.nytimes.com/2009/11/08/us/08forthood.html'
url162='http://www.nytimes.com/2009/11/08/us/08stress.html'
url163='http://www.nytimes.com/2009/11/08/us/08victims.html'
url164='http://www.nytimes.com/2009/11/08/us/08investigate.html'
url165='http://www.nytimes.com/2009/11/08/world/asia/08troops.html'
url166='http://www.nytimes.com/2009/11/09/us/politics/09casey.html'
url167='http://www.nytimes.com/2009/11/09/us/09muslim.html'
url168='http://www.nytimes.com/2009/11/09/us/09reconstruct.html'
url169='http://www.nytimes.com/2009/11/10/us/10hood.html'
url170='http://www.nytimes.com/2009/11/10/us/10inquire.html'
url171='https://opinionator.blogs.nytimes.com/2009/11/09/the-meaning-of-fort-hood/'
url172='http://www.nytimes.com/2009/11/10/opinion/l10hood.html'
url173='https://query.nytimes.com/gst/fullpage.html?res=980CE0DA1339F933A25752C1A96F9C8B63'
url174='http://www.nytimes.com/2009/11/11/opinion/l11hood.html'
url175='https://thecaucus.blogs.nytimes.com/2009/11/11/the-early-word-soldiers-and-wars/'
url176='http://www.nytimes.com/2009/11/12/us/12inquire.html'
url177='http://www.nytimes.com/2009/11/12/us/12hood.html'

# %%
#Fort Hood
urls=[url141,url142,url143,url144,url145,url146,url147,url148,url149,url150,url151,url152,url153,url154,url155,url156,
     url157,url158,url159,url160,url161,url162,url163,url164,url165,url166,url167,url168,url169,url170,url171,
     url172,url173,url174,url175,url176,url177]
Nyt_FtH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_FtH= Nyt_FtH.append([[a.title, a.text]], ignore_index=True)
Nyt_FtH.columns=['Title','Article']
Nyt_FtH['Incident Name'] = 'Fort Hood'
Nyt_FtH['Shooter Race']='White'
Nyt_FtH
# Out:
#                                                 Title  \
# 0                          Mass Shooting at Fort Hood
# 1      Army Doctor Held as Fort Hood Rampage Kills 12
# 2   Fort Hood Suspect Was ‘Mortified’ About Deploy...
# 3              Shooting Victims Flood Local Hospitals
# 4               Updates on the Shootings at Fort Hood
# 5    Responding to News of the Shootings at Fort Hood
# 6     Army Tests Sole-Killer Theory as Details Emerge
# 7   Neighbor Says Hasan Gave Belongings Away Befor...
# 8                 Coverage of the Fort Hood Shootings
# 9        Dedicated, Caring, and Suddenly Lost at Home
# 10        Highly Trained Sergeant Brought Down Gunman
# 11  Fox News Channel Draws Large Audience for Cove...
# 12             Combat Stress and the Fort Hood Gunman
# 13               From Humdrum Day to a Scene of Chaos
# 14                        The Forever War of the Mind
# 15    Muslims at Fort Voice Outrage and Ask Questions
# ...

# %%
#Binghampton URLS
url178='https://thelede.blogs.nytimes.com/2009/04/03/shooting-in-binghamton/'
url179='http://www.nytimes.com/2009/04/04/nyregion/04hostage.html'
url180='http://www.nytimes.com/2009/04/04/nyregion/04civic.html'
url181='http://www.nytimes.com/2009/04/05/nyregion/05shoot.html'
url182='http://www.nytimes.com/2009/04/05/nyregion/05suspect.html'
url183='http://www.nytimes.com/2009/04/06/nyregion/06teacher.html'
url184='http://www.nytimes.com/2009/04/06/nyregion/06victims.html'
url185='http://www.nytimes.com/2009/04/07/nyregion/07binghamton.html'
url186='http://www.nytimes.com/2009/04/08/nyregion/08binghamton.html'

# %%
#BingHampton Citizens Meeting
urls=[url178,url179,url180,url181,url182,url183,url184,url185,url186]
Nyt_Bing =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Bing= Nyt_Bing.append([[a.title, a.text]], ignore_index=True)
Nyt_Bing.columns=['Title','Article']
Nyt_Bing['Incident Name'] = 'Binghamton Citizens Meeting'
Nyt_Bing['Shooter Race']='Asian'
Nyt_Bing
# Out:
#                                                Title  \
# 0                       Shooting in Binghamton, N.Y.
# 1  Gunman Kills 13 and Wounds 4 at Binghamton, N....
# 2  In a Town With Few Immigrants, an Unlikely Horror
# 3  Amid Binghamton Gunfire, Pleas to Police and t...
# 4      Before Killings, Hints of Plans and Grievance
# 5  Teacher Was Absent for Binghamton Shootings, N...
# 6  Binghamton Shooting Victims Shared a Dream of ...
# 7  Letter, Believed to Be From Binghamton Gunman,...
# 8  Police Report Few Contacts With Binghamton Gun...
#
#                                              Article  \
# 0  For more information and further developments,...
# 1  It was the nation’s worst mass shooting since ...
# 2  By the end of the brief but terrifying episode...
# 3  Binghamton’s American Civic Association was fo...
# 4  Chief Zikuski said that to people close to Mr....
# 5  On Sunday morning, amid the quiet of her Bingh...
# 6  Mr. Wong married and divorced in California, b...
# ...

# %%
#PineLake Nursing HOme
url187='http://www.nytimes.com/2009/03/30/us/30shooting.html'
url188='http://www.nytimes.com/2009/03/31/us/31shooting.html'
urls=[url187,url188]
Nyt_PNH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_PNH= Nyt_PNH.append([[a.title, a.text]], ignore_index=True)
Nyt_PNH.columns=['Title','Article']
Nyt_PNH['Incident Name'] = 'PineLake Nursing Home'
Nyt_PNH['Shooter Race']='White'
Nyt_PNH
# Out:
#                                           Title  \
# 0  Gunman Kills 8 at a N. Carolina Nursing Home
# 1  Alleged Gunman’s Wife Worked at Nursing Home
#
#                                              Article          Incident Name  \
# 0  “He just lay down his life to protect the resi...  PineLake Nursing Home
# 1  According to records at the Moore County Sheri...  PineLake Nursing Home
#
#   Shooter Race
# 0        White
# 1        White

# %%
#Santa Clara
url189='http://www.nytimes.com/2009/03/31/us/31brfs-MOTIVESOUGHT_BRF.html'
Nyt_SC =pd.DataFrame()
a=Article(url136, language='en')
a.download()
a.parse()
Nyt_SC= Nyt_SC.append([[a.title, a.text]], ignore_index=True)
Nyt_SC.columns=['Title','Article']
Nyt_SC['Incident Name'] = 'Santa Clara'
Nyt_SC['Shooter Race']='Asian'
Nyt_SC
# Out:
#                                                Title  \
# 0  Killings Rattle an East Texas Town Better Know...
#
#                                              Article Incident Name  \
# 0  >\n\nTYLER, Tex., Feb. 26 (AP) - Blake Bailey ...   Santa Clara
#
#   Shooter Race
# 0        Asian

# %%
#Geneva County, AL
url190='http://www.nytimes.com/2009/03/12/us/12alabama.html'
url191='http://www.nytimes.com/2009/03/11/us/11alabama.html'
url192='https://thelede.blogs.nytimes.com/2009/03/11/the-aftermath-in-samson-ala/'
urls=[url190,url191,url192]
Nyt_GCAL =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_GCAL= Nyt_GCAL.append([[a.title, a.text]], ignore_index=True)
Nyt_GCAL.columns=['Title','Article']
Nyt_GCAL['Incident Name'] = 'Geneva County, Alabama'
Nyt_GCAL['Shooter Race']='White'
Nyt_GCAL
# Out:
#                                              Title  \
# 0                Officials Identify Alabama Gunman
# 1  Gunman Kills 10 in Alabama, Then Takes His Life
# 2                    The Aftermath in Samson, Ala.
#
#                                              Article           Incident Name  \
# 0  Photo\n\nSAMSON, Ala. — The gunman, wearing a ...  Geneva County, Alabama
# 1  Photo\n\nA gunman shot and killed at least 10 ...  Geneva County, Alabama
# 2  This post will follow today’s developments fro...  Geneva County, Alabama
#
#   Shooter Race
# 0        White
# 1        White
# 2        White

# %%
#Covina Party
url193='http://www.nytimes.com/2008/12/30/us/30brfs-005.html'
url194='http://www.nytimes.com/2008/12/26/us/26Santa.html'
url195='http://www.nytimes.com/2008/12/27/us/27shooting.html'
url196='http://www.nytimes.com/2008/12/27/us/27shoot.html'
urls=[url193,url194,url195,url196]
Nyt_Cov =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_Cov= Nyt_Cov.append([[a.title, a.text]], ignore_index=True)
Nyt_Cov.columns=['Title','Article']
Nyt_Cov['Incident Name'] = 'Covina, California'
Nyt_Cov['Shooter Race']='White'
Nyt_Cov
# Out:
#                                              Title  \
# 0  California: Canada Not in Killer’s Escape Plans
# 1  Man in a Santa Suit Kills at Least 8 at a Party
# 2        Gunman in Santa Suit Had Ticket to Canada
# 3    Attacker at Party Had Escape Plan, Police Say
#
#                                              Article       Incident Name  \
# 0  The authorities have corrected a detail in the...  Covina, California
# 1  Photo\n\nCOVINA, Calif. — A man in a Santa Cla...  Covina, California
# 2  Chief Raney said Mr. Pardo and his wife had fi...  Covina, California
# 3  On Friday, 9 of the 25 guests at the Christmas...  Covina, California
#
#   Shooter Race
# 0        White
# 1        White
# 2        White
# 3        White

# %%
#University of Central Arkansas
url197='http://www.nytimes.com/2008/10/28/us/28arkansas.html'
url198='http://www.nytimes.com/2008/10/27/us/27campus.html'
urls=[url197,url198]
Nyt_UCA =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_UCA= Nyt_UCA.append([[a.title, a.text]], ignore_index=True)
Nyt_UCA.columns=['Title','Article']
Nyt_UCA['Incident Name'] = 'University of Central Arkansas'
Nyt_UCA['Shooter Race']='African American'
Nyt_UCA
# Out:
#                                               Title  \
# 0  2 Are Killed in Shooting on a Campus in Arkansas
# 1                    Two Dead in Shooting on Campus
#
#                                              Article  \
# 0  Numerous witnesses at the scene provided accou...
# 1  LITTLE ROCK, Ark. — Two people were reported s...
#
#                     Incident Name      Shooter Race
# 0  University of Central Arkansas  African American
# 1  University of Central Arkansas  African American

# %%
#South Mountain Trail
url=['No Articles'] 
Nyt_SMT =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_SMT= Nyt_SMT.append([[a.title, a.text]], ignore_index=True)
Nyt_SMT.columns=['Title','Article']
Nyt_SMT['title'] = 'NaN'
Nyt_SMT['article'] = 'NaN'
Nyt_SMT['Incident Name'] = 'South Mountain Trail'
Nyt_SMT.drop(['Title','Article'], axis=1, inplace=True)
Nyt_SMT.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
Nyt_SMT
# Out:
#   Title Article         Incident Name
# 0   NaN     NaN  South Mountain Trail

# %%
#Altantis Plastics
url199='http://www.nytimes.com/2008/06/25/us/26kentuckycnd.html'
url200='http://www.nytimes.com/2008/06/26/us/26factory.html'
urls=[url199,url200]
Nyt_AP =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_AP= Nyt_AP.append([[a.title, a.text]], ignore_index=True)
Nyt_AP.columns=['Title','Article']
Nyt_AP['Incident Name'] = 'Atlantis Plastics'
Nyt_AP['Shooter Race']='White'
Nyt_AP
# Out:
#                                                Title  \
# 0                 Man in Kentucky Kills 5 Co-Workers
# 1  Man Who Killed Five People in Kentucky Had Cal...
#
#                                              Article      Incident Name  \
# 0  HENDERSON, Ky. — A man who worked at a Henders...  Atlantis Plastics
# 1  HENDERSON, Ky. — A man who killed five people ...  Atlantis Plastics
#
#   Shooter Race
# 0        White
# 1        White

# %%
#Northern Illinois Univeristy
url208='http://www.nytimes.com/2008/02/14/us/15cnd-shooting.html'
url209='http://www.nytimes.com/2008/02/15/us/15shoot.html'
url210='http://www.nytimes.com/2008/02/15/us/15cnd-victims.html'
url211='http://www.nytimes.com/2008/02/15/us/15cnd-shoot.html'
url212='https://thelede.blogs.nytimes.com/2008/02/15/a-string-of-campus-gun-rampages/'
url213='https://cityroom.blogs.nytimes.com/2008/02/15/bloomberg-on-illegal-guns-and-rampages/'
url214='https://thelede.blogs.nytimes.com/2008/02/15/digital-traces-of-the-niu-shooting/'
url215='https://thelede.blogs.nytimes.com/2008/02/15/blogging-to-grips-with-a-massacre/'
url216='http://www.nytimes.com/2008/02/16/us/16campus.html'
url217='http://www.nytimes.com/2008/02/16/us/16gunman.html'
url218='http://www.nytimes.com/2008/02/16/us/16shooting.html'
url219='http://www.nytimes.com/2008/02/17/us/17illinois.html'
url220='http://www.nytimes.com/2008/02/18/movies/18arts-CAMPUSVIOLEN_BRF.html'
url221='http://www.nytimes.com/2008/02/18/business/media/18college.html'
url222='http://www.nytimes.com/2008/02/19/us/19depress.html'
url223='http://www.nytimes.com/2008/02/20/us/20shooter.html'
urls=[url208,url209,url210,url211,url212,url213,url214,url215,url216,url217,url218,url219,url220,
     url221,url222,url223]
Nyt_NIU =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_NIU= Nyt_NIU.append([[a.title, a.text]], ignore_index=True)
Nyt_NIU.columns=['Title','Article']
Nyt_NIU['Incident Name'] = 'Northern Illinois University'
Nyt_NIU['Shooter Race']='White'
Nyt_NIU
# Out:
#                                                 Title  \
# 0                   Gunman Kills 5 on Illinois Campus
# 1            Gunman Slays 6 at N. Illinois University
# 2                             Profiles of the Victims
# 3                 Gunman Was Once ‘Revered’ on Campus
# 4                     A String of Campus Gun Rampages
# 5              Bloomberg on Illegal Guns and Rampages
# 6               Digital Traces of the N.I.U. Shooting
# 7              Coming to Grips (Online) With Shooting
# 8           Gaps Likely to Persist in Campus Security
# 9                  Gunman Showed Few Hints of Trouble
# 10         Grief and Questions After Deadly Shootings
# 11  After Shootings, Illinois Campus Prepares to M...
# 12              Campus Violence Film Has Release Date
# 13  First on the Scene, Again, Is the College News...
# 14  Reports of Gunman’s Use of Antidepressant Rene...
# 15               Gunman Hid His Tracks, Officials Say
#
# ...

# %%
#Kirkwood City Hall
url204='http://www.nytimes.com/2008/02/09/us/09missouri.html'
url205='http://www.nytimes.com/2008/02/08/us/08cnd-missouri.html'
url206='http://www.nytimes.com/2008/02/08/us/08missouri.html'
url207='http://www.nytimes.com/2008/02/07/us/07cnd-shoot.html'
urls=[url204,url205,url206,url207]
Nyt_KCH =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_KCH= Nyt_KCH.append([[a.title, a.text]], ignore_index=True)
Nyt_KCH.columns=['Title','Article']
Nyt_KCH['Incident Name'] = 'Kirkwood City Hall'
Nyt_KCH['Shooter Race']='African American'
Nyt_KCH
# Out:
#                                               Title  \
# 0      In Missouri, City Asks What Made Killer Snap
# 1  Mourning in Missouri as Shooter’s Motives Emerge
# 2     Gunman Kills 5 People at City Council Meeting
# 3                  Officer Killed in Armed Standoff
#
#                                              Article       Incident Name  \
# 0  The authorities said Mr. Thornton arrived at C...  Kirkwood City Hall
# 1  Mr. Thornton appeared to have hit a tipping po...  Kirkwood City Hall
# 2  The authorities would not identify the dead la...  Kirkwood City Hall
# 3  Photo\n\nKIRKWOOD, Mo. (AP) -- Five people, an...  Kirkwood City Hall
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American
# 3  African American

# %%
#Carnation, Washington
url=['No Articles'] 
Nyt_CW =pd.DataFrame()
for i in url: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_CW= Nyt_CW.append([[a.title, a.text]], ignore_index=True)
Nyt_CW.columns=['Title','Article']
Nyt_CW['title'] = 'NaN'
Nyt_CW['article'] = 'NaN'
Nyt_CW['Incident Name'] = 'Carnation, Washington'
Nyt_CW.drop(['Title','Article'], axis=1, inplace=True)
Nyt_CW.rename(index=str, columns={'title':'Title','article':'Article'}, inplace=True)
Nyt_CW
# Out:
# Traceback (most recent call last):
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/newspaper/parsers.py", line 54, in fromstring
#     cls.doc = lxml.html.fromstring(html)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 706, in fromstring
#     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#   File "/Users/ThomasPLapinger/anaconda/lib/python2.7/site-packages/lxml/html/__init__.py", line 600, in document_fromstring
#     value = etree.fromstring(html, parser, **kw)
#   File "lxml.etree.pyx", line 3032, in lxml.etree.fromstring (src/lxml/lxml.etree.c:68121)
#   File "parser.pxi", line 1786, in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:102470)
#   File "parser.pxi", line 1667, in lxml.etree._parseDoc (src/lxml/lxml.etree.c:101229)
#   File "parser.pxi", line 1035, in lxml.etree._BaseParser._parseUnicodeDoc (src/lxml/lxml.etree.c:96139)
# ...

# %%
#Mojave HS
url201='http://www.nytimes.com/2007/12/12/us/12vegas.html'
url202='http://www.nytimes.com/2007/12/13/us/13vegas.html'
url203='http://www.nytimes.com/2007/12/14/us/14vegas.html'
urls=[url201,url202,url203]
Nyt_MHS =pd.DataFrame()
for i in urls: 
    a=Article(i, language='en')
    a.download()
    a.parse()
    Nyt_MHS= Nyt_MHS.append([[a.title, a.text]], ignore_index=True)
Nyt_MHS.columns=['Title','Article']
Nyt_MHS['Incident Name'] = 'Mojave High School'
Nyt_MHS['Shooter Race']='African American'
Nyt_MHS
# Out:
#                                                Title  \
# 0  6 People Shot After Exiting a School Bus in La...
# 1                 Gunmen Sought in Bus Stop Shooting
# 2                     Arrest Is Made in Bus Shooting
#
#                                              Article       Incident Name  \
# 0  LAS VEGAS (AP) — Assailants on Tuesday shot si...  Mojave High School
# 1  LAS VEGAS (AP) — The police continued to searc...  Mojave High School
# 2  LAS VEGAS (AP) — An 18-year-old man was arrest...  Mojave High School
#
#        Shooter Race
# 0  African American
# 1  African American
# 2  African American

# %%
NYT_2000s=pd.concat([Nyt_ET, Nyt_ASL, Nyt_NI, Nyt_SHS, Nyt_UofA, Nyt_CARU, Nyt_LM, Nyt_WCC, Nyt_BW, Nyt_AV, Nyt_Brook,
                     Nyt_RHS, Nyt_GPO, Nyt_SHP, Nyt_EES, Nyt_OHS, Nyt_DU, Nyt_Amish, Nyt_TSUT, Nyt_SWT, Nyt_VT, Nyt_CWI,
                     Nyt_CHS, Nyt_SMI, Nyt_ACO, Nyt_WM, Nyt_SCC, Nyt_LC, Nyt_FtH, Nyt_PNH, Nyt_SC, Nyt_GCAL, Nyt_Cov, Nyt_UCA, Nyt_SMT, Nyt_AP, Nyt_NIU, Nyt_KCH, 
                     Nyt_CW, Nyt_MHS, Nyt_Bing])

# %%
for i in NYT_2000s:
    i.replace('N.R.A.','NRA')

# %%
NYT_2000s.to_csv('NYT 2000s Shootings-2.csv',index=False, encoding='utf-8')
